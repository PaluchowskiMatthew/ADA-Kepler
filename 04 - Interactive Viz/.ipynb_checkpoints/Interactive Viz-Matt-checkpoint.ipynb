# %% [markdown]
# # Interactive Visualization

# %%
import folium

# Normal stack of pandas, numpy, matplotlib and seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# For handeling the web requests
import requests
from collections import defaultdict
from pprint import *

# Statistical test library
import scipy.stats as stats
from helpers import *
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# Folium: https://github.com/python-visualization/folium
#
#  Documentation:
#  1. https://folium.readthedocs.io/en/latest/
#  2. https://media.readthedocs.org/pdf/folium/latest/folium.pdf

# %%
#Folium test
map_osm = folium.Map(location=[46.8076878,7.1004592], zoom_start=10)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# # Data wrangling

# %% [markdown]
# Data source (P3_GrantExport.csv)
# and description of the columns: http://p3.snf.ch/Pages/DataAndDocumentation.aspx

# %%
# Load the data we need. (Columns: Insti)
columns = ['Institution', 'University','Approved Amount']
p3 = pd.read_csv("P3_GrantExport.csv", delimiter=';', usecols=columns, na_values=['data not included in P3', 'nan'])

# %% [markdown]
# To be able to work with the data, we have to filter out the values where we have enough information.
#
# We start by filtering out the projects where we know at least the University or the institution related to the project

# %%
missing__info = p3[p3[['Institution', 'University']].isnull().all(axis=1)].index
has_info = p3.drop(missing__info, axis=0)

print('Dropped from original:', get_dropped_perc(p3, has_info))
print(has_info.shape)
# Out:
# Dropped from original: 2.3261267176288514
# (62481, 3)

# %% [markdown]
# As we can see, this leaves out 2.33% of the original data.

# %%
grant_info =  has_info.copy()
grant_info = grant_info[grant_info[['Approved Amount']].isnull().all(axis=1) == False]
grants_data = grant_info.loc[grant_info.index]
grants_data.head()
# Out:
#                                          Institution  \
# 0                                                NaN
# 1  Faculté de Psychologie et des Sciences de l'Ed...
# 2  Kommission für das Corpus philosophorum medii ...
# 3  Abt. Handschriften und Alte Drucke Bibliothek ...
# 4                       Schweiz. Thesauruskommission
#
#                                 University  Approved Amount
# 0                     Nicht zuteilbar - NA          11619.0
# 1                Université de Genève - GE          41022.0
# 2  NPO (Biblioth., Museen, Verwalt.) - NPO          79732.0
# 3                   Universität Basel - BS          52627.0
# 4  NPO (Biblioth., Museen, Verwalt.) - NPO         120042.0

# %%
print('Dropped from original:', get_dropped_perc(p3, grants_data))
print('Dropped from last step:', get_dropped_perc(has_info, grants_data))
# Out:
# Dropped from original: 18.340133502165113
# Dropped from last step: 16.395384196795824

# %% [markdown]
# So, for about 16.4% of the data, we don't have any information about the grant given.

# %% [markdown]
# # Get the geo info
#
# From the description of the dataset, we have the folloring description:
# > ### Institution
# > According to the information submitted by the responsible applicant, this is the research institution where the project will largely be carried out. Typically, this is the institution or specific lab where the responsible applicant works. The institution is therefore linked to the application. This field is not structured, but its content is consolidated internally. There is no link in the database to the field University.
#
# > ### University
# > This is the institution where the project will largely be carried out according to the application. Pick list. This field is only filled if the research is carried out at a Swiss institution, otherwise the field remains blank. In the case of mobility fellowships, it is generally left empty.
#
#
# So, we know that for the rows where the university is given, the grant was awarded to a swizz university. However, we do not know much about the cases where we only have the institution information. We descided to look into these cases further.

# %%
has_uni = has_info[has_info['University'].isnull() == False]

has_uni[has_uni['University'] == 'Eidg. Material und Prüfungsanstalt - EMPA']
print(has_uni.shape)
has_uni.head()
# Out:
# (50988, 3)
#                                          Institution  \
# 0                                                NaN
# 1  Faculté de Psychologie et des Sciences de l'Ed...
# 2  Kommission für das Corpus philosophorum medii ...
# 3  Abt. Handschriften und Alte Drucke Bibliothek ...
# 4                       Schweiz. Thesauruskommission
#
#                                 University  Approved Amount
# 0                     Nicht zuteilbar - NA          11619.0
# 1                Université de Genève - GE          41022.0
# 2  NPO (Biblioth., Museen, Verwalt.) - NPO          79732.0
# 3                   Universität Basel - BS          52627.0
# 4  NPO (Biblioth., Museen, Verwalt.) - NPO         120042.0

# %%
print('Dropped from original:', get_dropped_perc(p3, has_uni))
print('Dropped from last step:', get_dropped_perc(grants_data, has_uni))
# Out:
# Dropped from original: 20.292641748346853
# Dropped from last step: 2.3910255183107743

# %%
uni_grouped = has_uni.groupby(['University'])

# %%
res, err = get_geo_dict(uni_grouped)
# Out:
# Exception: occidentale 'adminCode1'

# %%
geolocalized_df = pd.DataFrame.from_dict(res).T
geolocalized_df[['lat','long']] = geolocalized_df[['lat','long']].apply(pd.to_numeric)
geolocalized_df.describe()
# Out:
#              lat       long
# count  52.000000  52.000000
# mean   46.979432   8.187044
# std     0.535848   0.909123
# min    46.010080   6.145690
# 25%    46.648202   7.544882
# 50%    47.050480   8.306350
# 75%    47.425245   8.917410
# max    47.697320   9.837230

# %% [markdown]
# Standard deviation for latitude and longitude is less than 1 so we are still operating within Swiss boarders ;)

# %%
geolocalized_df = geolocalized_df.reset_index()
geolocalized_df.columns = ['University', 'Canton', 'Lat', 'Lon']
geolocalized_df.head()
# Out:
#                                           University Canton       Lat      Lon
# 0                       AO Research Institute - AORI     BS  47.56639  7.60247
# 1                        Berner Fachhochschule - BFH     BL  47.53443  7.63886
# 2             Biotechnologie Institut Thurgau - BITG     TG  47.55620  9.07686
# 3  Centre de rech. sur l'environnement alpin - CR...     BE  46.72809  8.18586
# 4                                EPF Lausanne - EPFL     VD  46.51600  6.63282

# %%
has_code = has_uni['University'].str.extract('(?P<University_name>.*?(?= -))(?P<delim>\ -\ )(?P<Canton>.*)', expand=True).drop('delim', axis=1)
combined = has_uni.join(has_code, how="left")

# For the rest, we will try to get the canton code by requesting the GeoNames web service
combined_is_canton_code = combined[combined['Canton'].apply(is_canton_code) == True]
geolocalized_1 = geolocalized_df.append(combined_is_canton_code[['University', 'Canton']])
geolocalized_final = geolocalized_1.drop_duplicates(['University'])

# %%
geo_uni = has_uni.merge(geolocalized_final, on='University', how='left')
geo_uni
# Out:
#                                              Institution  \
# 0                                                    NaN
# 1      Faculté de Psychologie et des Sciences de l'Ed...
# 2      Kommission für das Corpus philosophorum medii ...
# 3      Abt. Handschriften und Alte Drucke Bibliothek ...
# 4                           Schweiz. Thesauruskommission
# 5      Séminaire de politique économique, d'économie ...
# 6      Institut für ökumenische Studien Université de...
# 7              Ostasiatisches Seminar Universität Zürich
# 8                                                    NaN
# 9      Laboratoire de Didactique et Epistémologie des...
# 10     Klinische Psychologie und Psychotherapie Insti...
# 11     Schweizerische Rechtsquellen c/o Universität Z...
# 12     Département de Sociologie Faculté des Sciences...
# 13     Institut für Volkswirtschaft WWZ / FGS Univers...
# 14            Soziologisches Institut Universität Zürich
# 15                                 Forschungszentrum FAL
# 16     Faculté de Psychologie et des Sciences de l'Ed...
# 17            Soziologisches Institut Universität Zürich
# 18                                                   NaN
# 19                                                   NaN
# 20     Faculté de Psychologie et des Sciences de l'Ed...
# 21                                                   NaN
# 22     Forschungsbereich Politisches Verhalten und Oe...
# 23     Département des langues et des littératures fr...
# 24                                                   NaN
# 25                                                   NaN
# 26            Schweizerische Gesellschaft für Volkskunde
# 27                         Kuratorium Carl J. Burckhardt
# 28                                                   NaN
# 29     Eidg. Forschungsanstalt für Wald, Schnee und L...
# ...                                                  ...
# 50958  Istituto di Studi Italiani Facoltà di Scienze ...
# 50959  Institut Ethique Histoire Humanités - iEH2 Fac...
# 50960  Institut d'Archéologie et des Sciences de l'An...
# 50961  Pädagogische Hochschule Fachhochschule Nordwes...
# 50962    Seminar für Filmwissenschaft Universität Zürich
# 50963                      Theologische Hochschule Basel
# 50964                Deutsches Seminar Universität Basel
# 50965               Englisches Seminar Universität Basel
# 50966                     Centro Stefano Franscini (CSF)
# 50967             Romanisches Seminar Universität Zürich
# 50968             Romanisches Seminar Universität Zürich
# 50969  Institut d'études politiques, historiques et i...
# 50970           Theologische Fakultät Universität Zürich
# 50971  Institut des Sciences sociales du Politique IS...
# 50972  Département d'Informatique Université de Fribourg
# 50973         Institut für Tieranatomie Universität Bern
# 50974  Institut für Germanistik Philosophisch-histori...
# 50975  Centre interfacultaire en droits de l'enfant  ...
# 50976                         Haute Ecole Pédagogique VD
# 50977  Institut Sozialmanagement und Sozialpolitik Ho...
# 50978  Fondation Jean Monnet pour l'Europe Centre de ...
# 50979  Planning of Landscape and Urban Systems Instit...
# 50980  Forschungsanstalt Agroscope Reckenholz-Tänikon...
# 50981  Forschung und Beratung in Wirtschaft und Polit...
# 50982  Zentrum für Religion, Wirtschaft und Politik T...
# 50983         Abteilung für Indologie Universität Zürich
# 50984  Institut Religions, Cultures, Modernité FTSR U...
# 50985     Haute École d'art et de design - Genève HES-SO
# 50986  Departement Design Zürcher Hochschule der Küns...
# 50987  Institute Performing Arts and Film Zürcher Hoc...
#
#                                               University  Approved Amount  \
# 0                                   Nicht zuteilbar - NA          11619.0
# 1                              Université de Genève - GE          41022.0
# 2                NPO (Biblioth., Museen, Verwalt.) - NPO          79732.0
# 3                                 Universität Basel - BS          52627.0
# 4                NPO (Biblioth., Museen, Verwalt.) - NPO         120042.0
# 5                            Université de Fribourg - FR          53009.0
# 6                            Université de Fribourg - FR          25403.0
# 7                                Universität Zürich - ZH          47100.0
# 8                            Université de Lausanne - LA          25814.0
# 9                              Université de Genève - GE         360000.0
# 10                           Université de Fribourg - FR         153886.0
# 11               NPO (Biblioth., Museen, Verwalt.) - NPO         862200.0
# 12                             Université de Genève - GE         116991.0
# 13                                Universität Basel - BS         112664.0
# 14                               Universität Zürich - ZH           5000.0
# 15                           Université de Fribourg - FR         204018.0
# 16                             Université de Genève - GE         149485.0
# 17                               Universität Zürich - ZH          83983.0
# 18                                  Nicht zuteilbar - NA          38152.0
# 19                           Université de Lausanne - LA          14138.0
# 20                             Université de Genève - GE         164602.0
# 21                                 Universität Bern - BE         147795.0
# 22                               Universität Zürich - ZH          24552.0
# 23                             Université de Genève - GE          44802.0
# 24                                  Nicht zuteilbar - NA          56000.0
# 25                                  Nicht zuteilbar - NA         152535.0
# 26               NPO (Biblioth., Museen, Verwalt.) - NPO         225000.0
# 27               NPO (Biblioth., Museen, Verwalt.) - NPO         179124.0
# 28                               Universität Zürich - ZH          20000.0
# 29     Eidg. Forschungsanstalt für Wald,Schnee,Land -...         445198.0
# ...                                                  ...              ...
# 50958           Università della Svizzera italiana - USI         251554.0
# 50959                          Université de Genève - GE           5700.0
# 50960                        Université de Lausanne - LA          10000.0
# 50961   Pädagogische Hochschule Nordwestschweiz - PHFHNW           7990.0
# 50962                            Universität Zürich - ZH          12416.0
# 50963                               Nicht zuteilbar - NA          10378.0
# 50964                             Universität Basel - BS           1600.0
# 50965                             Universität Basel - BS           3200.0
# 50966                                  ETH Zürich - ETHZ         120000.0
# 50967                            Universität Zürich - ZH           6300.0
# 50968                            Universität Zürich - ZH           1500.0
# 50969                        Université de Lausanne - LA          11782.0
# 50970                            Universität Zürich - ZH           2600.0
# 50971                        Université de Fribourg - FR           7700.0
# 50972                        Université de Fribourg - FR           2500.0
# 50973                              Universität Bern - BE           5900.0
# 50974                              Universität Bern - BE           7500.0
# 50975                          Université de Genève - GE           3000.0
# 50976   Haute école pédagogique du canton de Vaud - HEPL           3600.0
# 50977                           Hochschule Luzern - HSLU           1898.0
# 50978            NPO (Biblioth., Museen, Verwalt.) - NPO           2800.0
# 50979                                  ETH Zürich - ETHZ          99952.0
# 50980                Forschungsanstalten Agroscope - AGS          98040.0
# 50981                       Firmen/Privatwirtschaft - FP         100000.0
# 50982                             Universität Basel - BS          10030.0
# 50983                            Universität Zürich - ZH          10600.0
# 50984                        Université de Lausanne - LA           2515.0
# 50985                 HES de Suisse occidentale - HES-SO           3000.0
# 50986             Zürcher Fachhochschule (ohne PH) - ZFH           1000.0
# 50987             Zürcher Fachhochschule (ohne PH) - ZFH           2000.0
#
#       Canton       Lat      Lon
# 0        NaN       NaN      NaN
# 1         GE  46.20222  6.14569
# 2        NaN       NaN      NaN
# 3         BS  47.55832  7.58403
# 4        NaN       NaN      NaN
# 5         FR  46.80237  7.15128
# 6         FR  46.80237  7.15128
# 7         ZH  47.37092  8.53434
# 8         VD  46.52376  6.58409
# 9         GE  46.20222  6.14569
# 10        FR  46.80237  7.15128
# 11       NaN       NaN      NaN
# 12        GE  46.20222  6.14569
# 13        BS  47.55832  7.58403
# 14        ZH  47.37092  8.53434
# 15        FR  46.80237  7.15128
# 16        GE  46.20222  6.14569
# 17        ZH  47.37092  8.53434
# 18       NaN       NaN      NaN
# 19        VD  46.52376  6.58409
# 20        GE  46.20222  6.14569
# 21        BE  46.95096  7.43548
# 22        ZH  47.37092  8.53434
# 23        GE  46.20222  6.14569
# 24       NaN       NaN      NaN
# 25       NaN       NaN      NaN
# 26       NaN       NaN      NaN
# 27       NaN       NaN      NaN
# 28        ZH  47.37092  8.53434
# 29       NaN       NaN      NaN
# ...      ...       ...      ...
# 50958     TI  46.02394  8.91741
# 50959     GE  46.20222  6.14569
# 50960     VD  46.52376  6.58409
# 50961     BL  47.53378  7.63856
# 50962     ZH  47.37092  8.53434
# 50963    NaN       NaN      NaN
# 50964     BS  47.55832  7.58403
# 50965     BS  47.55832  7.58403
# 50966     ZH  47.37630  8.54805
# 50967     ZH  47.37092  8.53434
# 50968     ZH  47.37092  8.53434
# 50969     VD  46.52376  6.58409
# 50970     ZH  47.37092  8.53434
# 50971     FR  46.80237  7.15128
# 50972     FR  46.80237  7.15128
# 50973     BE  46.95096  7.43548
# 50974     BE  46.95096  7.43548
# 50975     GE  46.20222  6.14569
# 50976     VD  46.61671  6.64496
# 50977     LU  47.05048  8.30635
# 50978    NaN       NaN      NaN
# 50979     ZH  47.37630  8.54805
# 50980     FR  46.77051  7.10525
# 50981    NaN       NaN      NaN
# 50982     BS  47.55832  7.58403
# 50983     ZH  47.37092  8.53434
# 50984     VD  46.52376  6.58409
# 50985    NaN       NaN      NaN
# 50986     VS  46.10805  7.92741
# 50987     VS  46.10805  7.92741
#
# [50988 rows x 6 columns]

# %%
geo_uni = geo_uni[['Canton','Lat','Lon']]
geo_all = has_info.join(geo_uni, how='left')
print(geo_all.shape)
geo_all
# Out:
# (62481, 6)
#                                              Institution  \
# 0                                                    NaN
# 1      Faculté de Psychologie et des Sciences de l'Ed...
# 2      Kommission für das Corpus philosophorum medii ...
# 3      Abt. Handschriften und Alte Drucke Bibliothek ...
# 4                           Schweiz. Thesauruskommission
# 5      Séminaire de politique économique, d'économie ...
# 6      Institut für ökumenische Studien Université de...
# 7              Ostasiatisches Seminar Universität Zürich
# 8                                                    NaN
# 9      Laboratoire de Didactique et Epistémologie des...
# 10     Klinische Psychologie und Psychotherapie Insti...
# 11     Schweizerische Rechtsquellen c/o Universität Z...
# 12     Département de Sociologie Faculté des Sciences...
# 13     Institut für Volkswirtschaft WWZ / FGS Univers...
# 14            Soziologisches Institut Universität Zürich
# 15                                 Forschungszentrum FAL
# 16     Faculté de Psychologie et des Sciences de l'Ed...
# 17            Soziologisches Institut Universität Zürich
# 18                                                   NaN
# 19                                                   NaN
# 20     Faculté de Psychologie et des Sciences de l'Ed...
# 21                                                   NaN
# 22     Forschungsbereich Politisches Verhalten und Oe...
# 23     Département des langues et des littératures fr...
# 24                                                   NaN
# 25                                                   NaN
# 26            Schweizerische Gesellschaft für Volkskunde
# 27                         Kuratorium Carl J. Burckhardt
# 28                                                   NaN
# 29     Eidg. Forschungsanstalt für Wald, Schnee und L...
# ...                                                  ...
# 63927  Département d'Informatique Université de Fribourg
# 63928         Institut für Tieranatomie Universität Bern
# 63931  School of Chemistry University of New South Wales
# 63932  Institut für Germanistik Philosophisch-histori...
# 63934  Centre interfacultaire en droits de l'enfant  ...
# 63935                         Haute Ecole Pédagogique VD
# 63939  Institut Sozialmanagement und Sozialpolitik Ho...
# 63940                Stiftung Bibliothek Werner Oechslin
# 63941  School of Geographical Sciences University of ...
# 63943              CSIRO Marine and Atmospheric Research
# 63945     Departement Geographie, SIE Universität Zürich
# 63946  CReAM Department of Economics University Colle...
# 63948                                              Eawag
# 63949                      Catholic University of Bukavu
# 63950  Fondation Jean Monnet pour l'Europe Centre de ...
# 63951  Planning of Landscape and Urban Systems Instit...
# 63952  Forschungsanstalt Agroscope Reckenholz-Tänikon...
# 63953  Forschung und Beratung in Wirtschaft und Polit...
# 63954            Zoologisches Institut Universität Basel
# 63955  Zentrum für Religion, Wirtschaft und Politik T...
# 63956  Abteilung für Neuropsychologie Zentrum für Kog...
# 63958         Abteilung für Indologie Universität Zürich
# 63959  Institut Religions, Cultures, Modernité FTSR U...
# 63961  Department of Physics University of Massachusetts
# 63963     Haute École d'art et de design - Genève HES-SO
# 63964  Departement Design Zürcher Hochschule der Küns...
# 63965  Institute Performing Arts and Film Zürcher Hoc...
# 63966  Department of Electrical Engineering and Compu...
# 63967  Département de Biologie Faculté des Sciences U...
# 63968  The Forsyth Institute Department of Microbiolo...
#
#                                               University  Approved Amount  \
# 0                                   Nicht zuteilbar - NA          11619.0
# 1                              Université de Genève - GE          41022.0
# 2                NPO (Biblioth., Museen, Verwalt.) - NPO          79732.0
# 3                                 Universität Basel - BS          52627.0
# 4                NPO (Biblioth., Museen, Verwalt.) - NPO         120042.0
# 5                            Université de Fribourg - FR          53009.0
# 6                            Université de Fribourg - FR          25403.0
# 7                                Universität Zürich - ZH          47100.0
# 8                            Université de Lausanne - LA          25814.0
# 9                              Université de Genève - GE         360000.0
# 10                           Université de Fribourg - FR         153886.0
# 11               NPO (Biblioth., Museen, Verwalt.) - NPO         862200.0
# 12                             Université de Genève - GE         116991.0
# 13                                Universität Basel - BS         112664.0
# 14                               Universität Zürich - ZH           5000.0
# 15                           Université de Fribourg - FR         204018.0
# 16                             Université de Genève - GE         149485.0
# 17                               Universität Zürich - ZH          83983.0
# 18                                  Nicht zuteilbar - NA          38152.0
# 19                           Université de Lausanne - LA          14138.0
# 20                             Université de Genève - GE         164602.0
# 21                                 Universität Bern - BE         147795.0
# 22                               Universität Zürich - ZH          24552.0
# 23                             Université de Genève - GE          44802.0
# 24                                  Nicht zuteilbar - NA          56000.0
# 25                                  Nicht zuteilbar - NA         152535.0
# 26               NPO (Biblioth., Museen, Verwalt.) - NPO         225000.0
# 27               NPO (Biblioth., Museen, Verwalt.) - NPO         179124.0
# 28                               Universität Zürich - ZH          20000.0
# 29     Eidg. Forschungsanstalt für Wald,Schnee,Land -...         445198.0
# ...                                                  ...              ...
# 63927                        Université de Fribourg - FR           2500.0
# 63928                              Universität Bern - BE           5900.0
# 63931                                                NaN          11000.0
# 63932                              Universität Bern - BE           7500.0
# 63934                          Université de Genève - GE           3000.0
# 63935   Haute école pédagogique du canton de Vaud - HEPL           3600.0
# 63939                           Hochschule Luzern - HSLU           1898.0
# 63940                                                NaN           9300.0
# 63941                                                NaN           9500.0
# 63943                                                NaN          11000.0
# 63945                                                NaN           8000.0
# 63946                                                NaN           9300.0
# 63948                                                NaN           6000.0
# 63949                                                NaN           4500.0
# 63950            NPO (Biblioth., Museen, Verwalt.) - NPO           2800.0
# 63951                                  ETH Zürich - ETHZ          99952.0
# 63952                Forschungsanstalten Agroscope - AGS          98040.0
# 63953                       Firmen/Privatwirtschaft - FP         100000.0
# 63954                                                NaN          10500.0
# 63955                             Universität Basel - BS          10030.0
# 63956                                                NaN           7870.0
# 63958                            Universität Zürich - ZH          10600.0
# 63959                        Université de Lausanne - LA           2515.0
# 63961                                                NaN           4000.0
# 63963                 HES de Suisse occidentale - HES-SO           3000.0
# 63964             Zürcher Fachhochschule (ohne PH) - ZFH           1000.0
# 63965             Zürcher Fachhochschule (ohne PH) - ZFH           2000.0
# 63966                                                NaN          10500.0
# 63967                                                NaN           9500.0
# 63968                                                NaN           7000.0
#
#       Canton       Lat      Lon
# 0        NaN       NaN      NaN
# 1         GE  46.20222  6.14569
# 2        NaN       NaN      NaN
# 3         BS  47.55832  7.58403
# 4        NaN       NaN      NaN
# 5         FR  46.80237  7.15128
# 6         FR  46.80237  7.15128
# 7         ZH  47.37092  8.53434
# 8         VD  46.52376  6.58409
# 9         GE  46.20222  6.14569
# 10        FR  46.80237  7.15128
# 11       NaN       NaN      NaN
# 12        GE  46.20222  6.14569
# 13        BS  47.55832  7.58403
# 14        ZH  47.37092  8.53434
# 15        FR  46.80237  7.15128
# 16        GE  46.20222  6.14569
# 17        ZH  47.37092  8.53434
# 18       NaN       NaN      NaN
# 19        VD  46.52376  6.58409
# 20        GE  46.20222  6.14569
# 21        BE  46.95096  7.43548
# 22        ZH  47.37092  8.53434
# 23        GE  46.20222  6.14569
# 24       NaN       NaN      NaN
# 25       NaN       NaN      NaN
# 26       NaN       NaN      NaN
# 27       NaN       NaN      NaN
# 28        ZH  47.37092  8.53434
# 29       NaN       NaN      NaN
# ...      ...       ...      ...
# 63927    NaN       NaN      NaN
# 63928    NaN       NaN      NaN
# 63931    NaN       NaN      NaN
# 63932    NaN       NaN      NaN
# 63934    NaN       NaN      NaN
# 63935    NaN       NaN      NaN
# 63939    NaN       NaN      NaN
# 63940    NaN       NaN      NaN
# 63941    NaN       NaN      NaN
# 63943    NaN       NaN      NaN
# 63945    NaN       NaN      NaN
# 63946    NaN       NaN      NaN
# 63948    NaN       NaN      NaN
# 63949    NaN       NaN      NaN
# 63950    NaN       NaN      NaN
# 63951    NaN       NaN      NaN
# 63952    NaN       NaN      NaN
# 63953    NaN       NaN      NaN
# 63954    NaN       NaN      NaN
# 63955    NaN       NaN      NaN
# 63956    NaN       NaN      NaN
# 63958    NaN       NaN      NaN
# 63959    NaN       NaN      NaN
# 63961    NaN       NaN      NaN
# 63963    NaN       NaN      NaN
# 63964    NaN       NaN      NaN
# 63965    NaN       NaN      NaN
# 63966    NaN       NaN      NaN
# 63967    NaN       NaN      NaN
# 63968    NaN       NaN      NaN
#
# [62481 rows x 6 columns]

# %% [markdown]
# ### For the rest, we will try to get the canton code by parsing city name from university/institution column

# %%
# Load data for swiss # Load data for swiss cities (german names)
columns = ['Name', 'Kanton']
swiss_cities = pd.read_csv("swiss_cities.csv", delimiter='\t', usecols=columns, na_values=['data not included in P3', 'nan'])
swiss_cities['Kanton'] = swiss_cities['Kanton'].str.split().str[2]
swiss_cities.head(10)
# Out:
#           Name       Kanton
# 0       Zürich       Zürich
# 1         Genf         Genf
# 2        Basel  Basel-Stadt
# 3     Lausanne        Waadt
# 4         Bern         Bern
# 5   Winterthur       Zürich
# 6       Luzern       Luzern
# 7   St. Gallen       Gallen
# 8       Lugano       Tessin
# 9  Biel/Bienne         Bern

# %%
# Load data for swiss cantons
columns = ['Code', 'Kanton', 'Sprache']
swiss_cantons_full = pd.read_csv("swiss_cantons_full.csv", delimiter='\t', usecols=columns, na_values=['data not included in P3', 'nan'])
swiss_cantons_full['Kanton'] = swiss_cantons_full['Kanton'].str.split().str[2]
swiss_cantons_full.head(10)

# %%
# Load data for swiss towns (english names)
columns = ['Town', 'Canton']
swiss_cities_english = pd.read_csv("swiss_towns.csv", delimiter='\t', usecols=columns, na_values=['data not included in P3', 'nan'])
swiss_cities_english.columns = ['Name', 'Canton']
swiss_cities_english.head(10)
# Out:
#                  Name Canton
# 0               Aarau     AG
# 1             Aarberg     BE
# 2             Aarburg     AG
# 3            Adliswil     ZH
# 4          Aesch (BL)     BL
# 5  Affoltern am Albis     ZH
# 6                Agno     TI
# 7               Aigle     VD
# 8           Allschwil     BL
# 9        Altdorf (UR)     UR

# %%
#Add canton code to our loaded cities
swiss_cities_german = swiss_cities.merge(swiss_cantons_full, on='Kanton')
del swiss_cities_german['Kanton']
swiss_cities_german.columns = ['Name', 'Canton']
swiss_cities_german.head(20)
# Out:
#                  Name Canton
# 0              Zürich     ZH
# 1          Winterthur     ZH
# 2               Uster     ZH
# 3           Dübendorf     ZH
# 4            Dietikon     ZH
# 5            Wetzikon     ZH
# 6           Wädenswil     ZH
# 7              Horgen     ZH
# 8              Bülach     ZH
# 9            Adliswil     ZH
# 10         Volketswil     ZH
# 11             Kloten     ZH
# 12          Schlieren     ZH
# 13            Thalwil     ZH
# 14         Regensdorf     ZH
# 15            Opfikon     ZH
# 16  Illnau-Effretikon     ZH
# 17        Wallisellen     ZH
# 18              Stäfa     ZH
# 19           Küsnacht     ZH

# %%
# Load data for swiss towns (French names)
columns = ['Ville']
swiss_cities_french = pd.read_csv("swiss_cities_french.csv", delimiter='\t', usecols=columns, na_values=['french nan', 'nan'])
swiss_cities_french = swiss_cities_french['Ville'].str.split(', ', expand=True)
swiss_cities_french.columns = ['Name', 'Canton']
swiss_cities_french.head(10)
# Out:
#           Name Canton
# 0       Zurich     ZH
# 1       Genève     GE
# 2         Bâle     BS
# 3     Lausanne     VD
# 4        Berne     BE
# 5  Winterthour     ZH
# 6      Lucerne     LU
# 7   Saint-Gall     SG
# 8       Lugano     TI
# 9       Bienne     BE

# %%
# Create data frame containing city names in all available languages:
# (german, english and french)
swiss_cities_dict = pd.concat([swiss_cities_english, swiss_cities_german, swiss_cities_french])
swiss_cities_dict.drop_duplicates('Name', inplace=True)
swiss_cities_dict.set_index('Name', inplace=True)
swiss_cities_dict.head(10)
# Out:
#                    Canton
# Name
# Aarau                  AG
# Aarberg                BE
# Aarburg                AG
# Adliswil               ZH
# Aesch (BL)             BL
# Affoltern am Albis     ZH
# Agno                   TI
# Aigle                  VD
# Allschwil              BL
# Altdorf (UR)           UR

# %%
geo_all_copy = geo_all.copy()

# %%
# Direct mapping of canton with our Switzerland town list 

def map_inst_canton(df, column):
    for place in df[column].unique():
        place = str(place)
        if place == np.nan:
            continue
        for word in place.split():
            if word in swiss_cities_dict.index:
                p = swiss_cities_dict.loc[word]['Canton']
                #print(place, " -> ", p)
                df['Canton'][df[column] == place] = p

map_inst_canton(geo_all_copy, 'Institution')
map_inst_canton(geo_all_copy, 'University')

# %%
# Check how many entries still don't have a canton assigned
geo_all[geo_all['Canton'].isnull()].shape
# Out:
# (18212, 6)

# %%
# Drop all the entries that don't have a canton
dropped = geo_all_copy[geo_all_copy['Canton'].isnull()]

# %%
print('Coverage so far from original data containing set: ', get_dropped_perc(has_info, dropped))
# Out:
# Coverage so far from original data containing set:  88.46529344920856

# %%
dropped['University'].value_counts()
# Out:
# Nicht zuteilbar - NA                                  921
# NPO (Biblioth., Museen, Verwalt.) - NPO               597
# Firmen/Privatwirtschaft - FP                          213
# Paul Scherrer Institut - PSI                          211
# Università della Svizzera italiana - USI              149
# Eidg. Anstalt für Wasserversorgung - EAWAG            130
# Zürcher Fachhochschule (ohne PH) - ZFH                118
# Eidg. Material und Prüfungsanstalt - EMPA             117
# Inst. de Hautes Etudes Internat. et du Dév - IHEID    106
# Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL    105
# Universität St. Gallen - SG                           101
# Fachhochschule Nordwestschweiz (ohne PH) - FHNW        92
# HES de Suisse occidentale - HES-SO                     81
# Forschungsanstalten Agroscope - AGS                    43
# Friedrich Miescher Institute - FMI                     37
# Weitere Spitäler - ASPIT                               36
# Idiap Research Institute - IDIAP                       34
# SUP della Svizzera italiana - SUPSI                    33
# Berner Fachhochschule - BFH                            30
# Pädagogische Hochschule Nordwestschweiz - PHFHNW       19
# Kantonsspital St. Gallen - KSPSG                       19
# Swiss Center for Electronics and Microtech. - CSEM     18
# Allergie- und Asthmaforschung - SIAF                   18
# Institut Universitaire Kurt Bösch - IUKB               15
# Inst. universit. romand de Santé au Travail - IST      12
# Schweiz. Institut für Kunstwissenschaft - SIK-ISEA     12
# Forschungsinstitut für biologischen Landbau - FIBL     11
# Interkant. Hochschule für Heilpädagogik ZH - HfH       11
# Eidg. Hochschulinstitut für Berufsbildung - EHB        11
# Weitere Institute - FINST                              11
# Haute école pédagogique du canton de Vaud - HEPL       10
# Schweizer Paraplegiker Forschung - SPF                  8
# Ente Ospedaliero Cantonale - EOC                        8
# Swiss Institute of Bioinformatics - SIB                 8
# Fachhochschule Ostschweiz - FHO                         7
# Pädagogische Hochschule St. Gallen - PHSG               6
# AO Research Institute - AORI                            5
# Franklin University Switzerland - FUS                   3
# Haute école pédagogique BE, JU, NE - HEPBEJUNE          3
# Centre de rech. sur l'environnement alpin - CREALP      2
# Forschungsinstitut für Opthalmologie - IRO              2
# Biotechnologie Institut Thurgau - BITG                  2
# Schweizer Kompetenzzentrum Sozialwissensch. - FORS      2
# Haute école pédagogique fribourgeoise - HEPFR           1
# Pädagogische Hochschule Thurgau - PHTG                  1
# Institut für Kulturforschung Graubünden - IKG           1
# Fachhochschule Kalaidos - FHKD                          1
# Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS      1
# Name: University, dtype: int64

# %% [markdown]
# ## Manual labour

# %%
geo_all[(geo_all['University'] == 'Paul Scherrer Institut') & (geo_all['Canton'] == np.nan)]['Canton'] = 'AG'
geo_all[(geo_all['University'] == 'Università della Svizzera italiana - USI') & (geo_all['Canton'] == np.nan)]['Canton'] = 'TI'
geo_all[(geo_all['University'] == 'Eidg. Anstalt für Wasserversorgung') & (geo_all['Canton'] == np.nan)]['Canton'] = 'ZH'
geo_all[(geo_all['University'] == 'Zürcher Fachhochschule (ohne PH) - ZFH') & (geo_all['Canton'] == np.nan)]['Canton'] = 'ZH'
geo_all[(geo_all['University'] == 'Eidg. Material und Prüfungsanstalt - EMPA') & (geo_all['Canton'] == np.nan)]['Canton'] = 'ZH'
geo_all[(geo_all['University'] == 'Institut Universitaire Kurt Bösch - IUKB') & (geo_all['Canton'] == np.nan)]['Canton'] = 'VS'
geo_all[(geo_all['University'] == 'Allergie- und Asthmaforschung - SIAF') & (geo_all['Canton'] == np.nan)]['Canton'] = 'GR'
geo_all[(geo_all['University'] == 'Swiss Center for Electronics & Microtech. - CSEM') & (geo_all['Canton'] == np.nan)]['Canton'] = 'NE'
geo_all[(geo_all['University'] == 'Pädagogische Hochschule Nordwestschweiz - PHFHNW') & (geo_all['Canton'] == np.nan)]['Canton'] = 'AG'
geo_all[(geo_all['University'] == 'Kantonsspital St. Gallen - KSPSG') & (geo_all['Canton'] == np.nan)]['Canton'] = 'SG'
geo_all[(geo_all['University'] == 'Berner Fachhochschule - BFH') & (geo_all['Canton'] == np.nan)]['Canton'] = 'BE'
geo_all[(geo_all['University'] == 'SUP della Svizzera italiana - SUPSI') & (geo_all['Canton'] == np.nan)]['Canton'] = 'TI'
geo_all[(geo_all['University'] == 'Idiap Research Institute - IDIAP') & (geo_all['Canton'] == np.nan)]['Canton'] = 'VS'
geo_all[(geo_all['University'] == 'Inst. de Hautes Etudes Internat. et du Dév - IHEID') & (geo_all['Canton'] == np.nan)]['Canton'] = 'GE'
geo_all[(geo_all['University'] == 'Friedrich Miescher Institute - FMI ') & (geo_all['Canton'] == np.nan)]['Canton'] = 'BS'
geo_all[(geo_all['University'] == 'Forschungsanstalten Agroscope - AGS') & (geo_all['Canton'] == np.nan)]['Canton'] = 'VD'
geo_all[(geo_all['University'] == 'HES de Suisse occidentale - HES-SO') & (geo_all['Canton'] == np.nan)]['Canton'] = 'JU'
geo_all[(geo_all['University'] == 'Fachhochschule Nordwestschweiz (ohne PH) - FHNW') & (geo_all['Canton'] == np.nan)]['Canton'] = 'SO'
geo_all[(geo_all['University'] == 'Universität St. Gallen') & (geo_all['Canton'] == np.nan)]['Canton'] = 'SG'
geo_all[(geo_all['University'] == 'Eidg. Forschungsanstalt für Wald,Schnee,L& - WSL') & (geo_all['Canton'] == np.nan)]['Canton'] = 'ZH'

# %%
clean_cantons = geo_all.dropna(subset = ['Canton'])
clean_cantons.head()
# Out:
#                                          Institution  \
# 1  Faculté de Psychologie et des Sciences de l'Ed...
# 3  Abt. Handschriften und Alte Drucke Bibliothek ...
# 5  Séminaire de politique économique, d'économie ...
# 6  Institut für ökumenische Studien Université de...
# 7          Ostasiatisches Seminar Universität Zürich
#
#                     University  Approved Amount Canton       Lat      Lon
# 1    Université de Genève - GE          41022.0     GE  46.20222  6.14569
# 3       Universität Basel - BS          52627.0     BS  47.55832  7.58403
# 5  Université de Fribourg - FR          53009.0     FR  46.80237  7.15128
# 6  Université de Fribourg - FR          25403.0     FR  46.80237  7.15128
# 7      Universität Zürich - ZH          47100.0     ZH  47.37092  8.53434

# %%
print(clean_cantons.shape)
print(has_info.shape)
print('Dropped from original:', get_dropped_perc(has_info, clean_cantons))
# Out:
# (44269, 6)
# (62481, 3)
# Dropped from original: 29.14806101054721

# %% [markdown]
# We are going to parse more results than that but lets work on this small dataset for now.

# %%
# List of parsed cantons (Note that some are missing! We will handle that!) 
clean_cantons['Canton'].unique()
# Out:
# array(['GE', 'BS', 'FR', 'ZH', 'VD', 'BE', 'NE', 'SG', 'GR', 'LU', 'TI',
#        'ZG', 'BL', 'VS', 'SZ', 'TG', 'SH'], dtype=object)

# %%
#Lets get the amount of subsidy for each canton
grouped_cantons = clean_cantons.groupby('Canton')['Approved Amount'].sum()
grants_cantons = pd.DataFrame(grouped_cantons)
grants_cantons = grants_cantons.reset_index()
grants_cantons.head(26)
# Out:
#    Canton  Approved Amount
# 0      BE     1.139640e+09
# 1      BL     3.523765e+07
# 2      BS     9.757944e+08
# 3      FR     4.186820e+08
# 4      GE     1.260034e+09
# 5      GR     1.356294e+07
# 6      LU     5.313610e+07
# 7      NE     3.012267e+08
# 8      SG     9.812618e+07
# 9      SH     1.403220e+05
# 10     SZ     4.216980e+05
# 11     TG     2.910188e+06
# 12     TI     9.592494e+07
# 13     VD     1.724402e+09
# 14     VS     1.011429e+08
# 15     ZG     1.116501e+08
# 16     ZH     2.476990e+09

# %%
# Load data for all swiss cantons
columns = ['Name', 'Canton']
swiss_cantons = pd.read_csv("swiss_cantons.csv", delimiter='\t', usecols=columns, na_values=['Not there', 'nan'])
swiss_cantons.set_index('Canton', inplace=True)
swiss_cantons = swiss_cantons.reset_index()
swiss_cantons.head(26)
# Out:
#    Canton                    Name
# 0      ZH                  Zürich
# 1      BE                    Bern
# 2      LU                  Luzern
# 3      UR                     Uri
# 4      SZ                  Schwyz
# 5      OW                Obwalden
# 6      NW               Nidwalden
# 7      GL                  Glarus
# 8      ZG                     Zug
# 9      FR                Fribourg
# 10     SO               Solothurn
# 11     BS              Basel-City
# 12     BL           Basel-Country
# 13     SH            Schaffhausen
# 14     AR  Appenzell Ausserrhoden
# 15     AI   Appenzell Innerrhoden
# 16     SG              St. Gallen
# 17     GR              Graubünden
# 18     AG                  Aargau
# 19     TG                 Thurgau
# 20     TI                  Ticino
# 21     VD                    Vaud
# 22     VS                  Valais
# 23     NE               Neuchâtel
# 24     GE                  Geneva
# 25     JU                    Jura

# %%
# Lets merge our parsed cantons with all cantons in CH
grants_cantons = swiss_cantons.merge(grants_cantons, how='left')
grants_cantons.head(26)
# Out:
#    Canton                    Name  Approved Amount
# 0      ZH                  Zürich     2.476990e+09
# 1      BE                    Bern     1.139640e+09
# 2      LU                  Luzern     5.313610e+07
# 3      UR                     Uri              NaN
# 4      SZ                  Schwyz     4.216980e+05
# 5      OW                Obwalden              NaN
# 6      NW               Nidwalden              NaN
# 7      GL                  Glarus              NaN
# 8      ZG                     Zug     1.116501e+08
# 9      FR                Fribourg     4.186820e+08
# 10     SO               Solothurn              NaN
# 11     BS              Basel-City     9.757944e+08
# 12     BL           Basel-Country     3.523765e+07
# 13     SH            Schaffhausen     1.403220e+05
# 14     AR  Appenzell Ausserrhoden              NaN
# 15     AI   Appenzell Innerrhoden              NaN
# 16     SG              St. Gallen     9.812618e+07
# 17     GR              Graubünden     1.356294e+07
# 18     AG                  Aargau              NaN
# 19     TG                 Thurgau     2.910188e+06
# 20     TI                  Ticino     9.592494e+07
# 21     VD                    Vaud     1.724402e+09
# 22     VS                  Valais     1.011429e+08
# 23     NE               Neuchâtel     3.012267e+08
# 24     GE                  Geneva     1.260034e+09
# 25     JU                    Jura              NaN

# %%
#Fill out those NaN's
grants_cantons.fillna(0, inplace=True)
grants_cantons
# Out:
#    Canton                    Name  Approved Amount
# 0      ZH                  Zürich     2.476990e+09
# 1      BE                    Bern     1.139640e+09
# 2      LU                  Luzern     5.313610e+07
# 3      UR                     Uri     0.000000e+00
# 4      SZ                  Schwyz     4.216980e+05
# 5      OW                Obwalden     0.000000e+00
# 6      NW               Nidwalden     0.000000e+00
# 7      GL                  Glarus     0.000000e+00
# 8      ZG                     Zug     1.116501e+08
# 9      FR                Fribourg     4.186820e+08
# 10     SO               Solothurn     0.000000e+00
# 11     BS              Basel-City     9.757944e+08
# 12     BL           Basel-Country     3.523765e+07
# 13     SH            Schaffhausen     1.403220e+05
# 14     AR  Appenzell Ausserrhoden     0.000000e+00
# 15     AI   Appenzell Innerrhoden     0.000000e+00
# 16     SG              St. Gallen     9.812618e+07
# 17     GR              Graubünden     1.356294e+07
# 18     AG                  Aargau     0.000000e+00
# 19     TG                 Thurgau     2.910188e+06
# 20     TI                  Ticino     9.592494e+07
# 21     VD                    Vaud     1.724402e+09
# 22     VS                  Valais     1.011429e+08
# 23     NE               Neuchâtel     3.012267e+08
# 24     GE                  Geneva     1.260034e+09
# 25     JU                    Jura     0.000000e+00

# %%
# And make a first sketch on the map
cantons_topo = 'ch-cantons.topojson.json'

main_map = folium.Map(location=[46.50,8.20], zoom_start=8)
main_map.choropleth(geo_path=cantons_topo, 
                     data=grants_cantons,
                     columns=['Canton', 'Approved Amount'],
                     key_on='feature.id',
                     topojson='objects.cantons',
                     fill_color='YlGnBu',
                     legend_name = 'Random numbers'
                    )
main_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# ## TODO's
# * merge geolocalized_df with has_uni
# * supply it to chris's method
# * display on map
# * do a bonus exercise

# %%
grants_cantons
