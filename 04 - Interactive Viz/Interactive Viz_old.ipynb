# %% [markdown]
# # Interactive Visualization

# %%
#WARNING guys! In order to use folium you are gonna need to run
# pip install folium
#in your terminal.
import folium

#Probably gonna use this:

# Normal stack of pandas, numpy, matplotlib and seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# For handeling the web requests
import requests
from collections import defaultdict
from pprint import *

# Statistical test library
import scipy.stats as stats
from helpers import *

# %matplotlib inline

# %% [markdown]
# Folium: https://github.com/python-visualization/folium
#
#  Documentation:
#  1. https://folium.readthedocs.io/en/latest/
#  2. https://media.readthedocs.org/pdf/folium/latest/folium.pdf

# %%
#Folium test
map_osm = folium.Map(location=[46.8076878,7.1004592], zoom_start=10)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# # Data wrangeling

# %% [markdown]
# Data source (P3_GrantExport.csv)
# and description of the columns: http://p3.snf.ch/Pages/DataAndDocumentation.aspx

# %%
# Load the data we need. (Columns: Insti)
columns = ['Institution', 'University','Approved Amount']
p3 = pd.read_csv("P3_GrantExport.csv", delimiter=';', usecols=columns, na_values=['data not included in P3', 'nan'])
p3.describe()
# Out:
# /home/raccct/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        Approved Amount
# count     5.305900e+04
# mean      2.454877e+05
# std       3.183416e+05
# min       0.000000e+00
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max       1.548775e+07

# %% [markdown]
# To be able to work with the data, we have to filter out the values where we have enough information.
#
# We start by filtering out the projects where we know at least the University or the institution related to the project

# %%
missing__info = p3[p3[['Institution', 'University']].isnull().all(axis=1)].index
has_info = p3.drop(missing__info, axis=0)
print(has_info.shape)
print('Dropped from original:', get_dropped_perc(p3, has_info))
# Out:
# (62481, 3)
# Dropped from original: 2.3261267176288514

# %% [markdown]
# As we can see, this leaves out 2.33% of the original data.

# %%
grant_info = has_info[has_info[['Approved Amount']].isnull().all(axis=1) == False]
grants_data = has_info.loc[grant_info.index]
grants_data.head()
# Out:
#                                          Institution  \
# 0                                                NaN
# 1  Faculté de Psychologie et des Sciences de l'Ed...
# 2  Kommission für das Corpus philosophorum medii ...
# 3  Abt. Handschriften und Alte Drucke Bibliothek ...
# 4                       Schweiz. Thesauruskommission
#
#                                 University  Approved Amount
# 0                     Nicht zuteilbar - NA          11619.0
# 1                Université de Genève - GE          41022.0
# 2  NPO (Biblioth., Museen, Verwalt.) - NPO          79732.0
# 3                   Universität Basel - BS          52627.0
# 4  NPO (Biblioth., Museen, Verwalt.) - NPO         120042.0

# %%
print('Dropped from original:', get_dropped_perc(p3, grants_data))
print('Dropped from last step:', get_dropped_perc(has_info, grants_data))
# Out:
# Dropped from original: 18.340133502165113
# Dropped from last step: 16.395384196795824

# %% [markdown]
# So, for about 16.4% of the data, we don't have any information about the grant given.

# %% [markdown]
# # Get the geo info
#
# From the description of the dataset, we have the folloring description:
# > ### Institution
# > According to the information submitted by the responsible applicant, this is the research institution where the project will largely be carried out. Typically, this is the institution or specific lab where the responsible applicant works. The institution is therefore linked to the application. This field is not structured, but its content is consolidated internally. There is no link in the database to the field University.
#
# > ### University
# > This is the institution where the project will largely be carried out according to the application. Pick list. This field is only filled if the research is carried out at a Swiss institution, otherwise the field remains blank. In the case of mobility fellowships, it is generally left empty.
#
#
# So, we know that for the rows where the university is given, the grant was awarded to a swizz university. However, we do not know much about the cases where we only have the institution information. We descided to look into these cases further.

# %%
has_uni = has_info[has_info['University'].isnull() == False]
has_uni.head()
# Out:
#                                          Institution  \
# 0                                                NaN
# 1  Faculté de Psychologie et des Sciences de l'Ed...
# 2  Kommission für das Corpus philosophorum medii ...
# 3  Abt. Handschriften und Alte Drucke Bibliothek ...
# 4                       Schweiz. Thesauruskommission
#
#                                 University  Approved Amount
# 0                     Nicht zuteilbar - NA          11619.0
# 1                Université de Genève - GE          41022.0
# 2  NPO (Biblioth., Museen, Verwalt.) - NPO          79732.0
# 3                   Universität Basel - BS          52627.0
# 4  NPO (Biblioth., Museen, Verwalt.) - NPO         120042.0

# %%
print('Dropped from original:', get_dropped_perc(p3, has_uni))
print('Dropped from last step:', get_dropped_perc(grants_data, has_uni))
# Out:
# Dropped from original: 20.292641748346853
# Dropped from last step: 2.3910255183107743

# %%
has_code = has_uni['University'].str.extract('(?P<University>.*?(?= -))(?P<delim>\ -\ )(?P<Code>.*)', expand=True).drop('delim', axis=1)
has_code.head()
# Out:
#                           University Code
# 0                    Nicht zuteilbar   NA
# 1               Université de Genève   GE
# 2  NPO (Biblioth., Museen, Verwalt.)  NPO
# 3                  Universität Basel   BS
# 4  NPO (Biblioth., Museen, Verwalt.)  NPO

# %%
# Drop NAs and NPOs in Canton Codes (not avaialable and NGOs)
has_code = has_code[has_code.Code != 'NPO']
has_code = has_code[has_code.Code != 'NA']
has_code.head()
# Out:
#                University Code
# 1    Université de Genève   GE
# 3       Universität Basel   BS
# 5  Université de Fribourg   FR
# 6  Université de Fribourg   FR
# 7      Universität Zürich   ZH

# %%
# For these rows, we allready have the canton code
has_canton_code = has_code['Code'][has_code['Code'].apply(is_canton_code)].rename('Canton code')

has_canton_code.index
# Out:
# Int64Index([    1,     3,     5,     6,     7,     9,    10,    12,    13,
#                14,
#             ...
#             63918, 63919, 63921, 63922, 63927, 63928, 63932, 63934, 63955,
#             63958],
#            dtype='int64', length=27702)

# %%
# For the rest, we will try to get the canton code by requesting the GeoNames web service
has_uni_code = has_code['Code'][has_code['Code'].apply(is_canton_code) == False]

has_uni_no_cantoncode = has_uni.loc[has_uni_code.index]
has_uni_no_cantoncode.head()
# Out:
#                                           Institution  \
# 8                                                 NaN
# 19                                                NaN
# 29  Eidg. Forschungsanstalt für Wald, Schnee und L...
# 47            Chair of English Literature ETH-Zentrum
# 51         Faculté des lettres Université de Lausanne
#
#                                            University  Approved Amount
# 8                         Université de Lausanne - LA          25814.0
# 19                        Université de Lausanne - LA          14138.0
# 29  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         445198.0
# 47                                  ETH Zürich - ETHZ          46200.0
# 51                        Université de Lausanne - LA          74617.0

# %%
for place in has_uni_no_cantoncode['University'].unique():
    if place:
        p = geo_lookup(place)
    if p:
        print(place)
        pprint(p)
# Out:
# For qurery parmas:
# 'name=Universit%C3%A9+de+Lausanne+-+LA&country=ch&username=username&maxRows=1'
# {'status': {'message': 'user account not enabled to use the free webservice. '
#                        'Please enable it on your account page: '
#                        'http://www.geonames.org/manageaccount ',
#             'value': 10}}
# For qurery parmas:
# 'name=Eidg.+Forschungsanstalt+f%C3%BCr+Wald%2CSchnee%2CLand+-+WSL&country=ch&username=username&maxRows=1'
# {'status': {'message': 'user account not enabled to use the free webservice. '
#                        'Please enable it on your account page: '
#                        'http://www.geonames.org/manageaccount ',
#             'value': 10}}
# For qurery parmas:
# 'name=ETH+Z%C3%BCrich+-+ETHZ&country=ch&username=username&maxRows=1'
# {'status': {'message': 'user account not enabled to use the free webservice. '
#                        'Please enable it on your account page: '
#                        'http://www.geonames.org/manageaccount ',
#             'value': 10}}
# For qurery parmas:
# 'name=Inst.+de+Hautes+Etudes+Internat.+et+du+D%C3%A9v+-+IHEID&country=ch&username=username&maxRows=1'
# {'status': {'message': 'user account not enabled to use the free webservice. '
#                        'Please enable it on your account page: '
#                        'http://www.geonames.org/manageaccount ',
#             'value': 10}}
# For qurery parmas:
# 'name=Weitere+Institute+-+FINST&country=ch&username=username&maxRows=1'
# {'status': {'message': 'user account not enabled to use the free webservice. '
#                        'Please enable it on your account page: '
#                        'http://www.geonames.org/manageaccount ',
#             'value': 10}}
# For qurery parmas:
# 'name=Firmen%2FPrivatwirtschaft+-+FP&country=ch&username=username&maxRows=1'
# {'status': {'message': 'user account not enabled to use the free webservice. '
#                        'Please enable it on your account page: '
#                        'http://www.geonames.org/manageaccount ',
#             'value': 10}}
# For qurery parmas:
# 'name=P%C3%A4dagogische+Hochschule+Graub%C3%BCnden+-+PHGR&country=ch&username=username&maxRows=1'
# {'status': {'message': 'user account not enabled to use the free webservice. '
#                        'Please enable it on your account page: '
#                        'http://www.geonames.org/manageaccount ',
#             'value': 10}}
# For qurery parmas:
# 'name=EPF+Lausanne+-+EPFL&country=ch&username=username&maxRows=1'
# {'status': {'message': 'user account not enabled to use the free webservice. '
#                        'Please enable it on your account page: '
#                        'http://www.geonames.org/manageaccount ',
#             'value': 10}}
# For qurery parmas:
# 'name=P%C3%A4dagogische+Hochschule+Z%C3%BCrich+-+PHZFH&country=ch&username=username&maxRows=1'
# {'status': {'message': 'user account not enabled to use the free webservice. '
#                        'Please enable it on your account page: '
#                        'http://www.geonames.org/manageaccount ',
#             'value': 10}}
# For qurery parmas:
# 'name=Schweiz.+Institut+f%C3%BCr+Kunstwissenschaft+-+SIK-ISEA&country=ch&username=username&maxRows=1'
# {'status': {'message': 'user account not enabled to use the free webservice. '
#                        'Please enable it on your account page: '
#                        'http://www.geonames.org/manageaccount ',
#             'value': 10}}
# For qurery parmas:
# 'name=SUP+della+Svizzera+italiana+-+SUPSI&country=ch&username=username&maxRows=1'
# {'status': {'message': 'user account not enabled to use the free webservice. '
#                        'Please enable it on your account page: '
#                        'http://www.geonames.org/manageaccount ',
#             'value': 10}}
# For qurery parmas:
# 'name=HES+de+Suisse+occidentale+-+HES-SO&country=ch&username=username&maxRows=1'
# {'status': {'message': 'user account not enabled to use the free webservice. '
#                        'Please enable it on your account page: '
#                        'http://www.geonames.org/manageaccount ',
#             'value': 10}}
# For qurery parmas:
# 'name=Robert+Walser-Stiftung+Bern+-+RWS&country=ch&username=username&maxRows=1'
# {'status': {'message': 'user account not enabled to use the free webservice. '
#                        'Please enable it on your account page: '
#                        'http://www.geonames.org/manageaccount ',
#             'value': 10}}
# For qurery parmas:
# 'name=Paul+Scherrer+Institut+-+PSI&country=ch&username=username&maxRows=1'
# {'status': {'message': 'user account not enabled to use the free webservice. '
#                        'Please enable it on your account page: '
#                        'http://www.geonames.org/manageaccount ',
#             'value': 10}}
# For qurery parmas:
# 'name=P%C3%A4dagogische+Hochschule+St.+Gallen+-+PHSG&country=ch&username=username&maxRows=1'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384             try:  # Python 2.7, use buffering of HTTP responses
# --> 385                 httplib_response = conn.getresponse(buffering=True)
#     386             except TypeError:  # Python 2.6 and older
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /mnt/DATA/Dropbox/!!EPFL/16hs/Courses/ADA/ADA-Kepler/04 - Interactive Viz/helpers.py in geo_lookup(name)
#      52     try:
# ---> 53         r = requests.get(url + encoded_args)
#      54
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      70     kwargs.setdefault('allow_redirects', True)
# ---> 71     return request('get', url, params=params, **kwargs)
#      72
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     with sessions.Session() as session:
# ---> 57         return session.request(method=method, url=url, **kwargs)
#      58
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     584         # Send the request
# --> 585         r = adapter.send(request, **kwargs)
#     586
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     402                     retries=self.max_retries,
# --> 403                     timeout=timeout
#     404                 )
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     577                                                   body=body, headers=headers,
# --> 578                                                   chunked=chunked)
#     579
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386             except TypeError:  # Python 2.6 and older
# --> 387                 httplib_response = conn.getresponse()
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /home/raccct/anaconda3/lib/python3.5/http/client.py in getresponse(self)
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#
# /home/raccct/anaconda3/lib/python3.5/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /home/raccct/anaconda3/lib/python3.5/http/client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# /home/raccct/anaconda3/lib/python3.5/socket.py in readinto(self, b)
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-13-4d48f12d302b> in <module>()
#       1 for place in has_uni_no_cantoncode['University'].unique():
#       2     if place:
# ----> 3         p = geo_lookup(place)
#       4     if p:
#       5         print(place)
#
# /mnt/DATA/Dropbox/!!EPFL/16hs/Courses/ADA/ADA-Kepler/04 - Interactive Viz/helpers.py in geo_lookup(name)
#      62         print('For qurery parmas:')
#      63         pprint(encoded_args)
# ---> 64         pprint(r.json())
#      65
#      66
#
# UnboundLocalError: local variable 'r' referenced before assignment

# %%
def map_institution_canton(df):
    for place in df['Institution'].unique():
        if str(place) == 'nan':
            continue
        if str(place).startswith('Uni'):
            continue
        #c = get_canton(place)
        #if c == '':
        p = geo_lookup(place)
        if p:
            print('found', p, 'in the api')
            canton_dict[place] = p
        else:
            has_looked_up[place] = True
            print(place, p)


map_institution_canton(has_info)
# Out:
# For qurery parmas:
# 'name=Facult%C3%A9+de+Psychologie+et+des+Sciences+de+l%27Education+Universit%C3%A9+de+Gen%C3%A8ve&country=ch&username=username&maxRows=1'
# {'status': {'message': 'user account not enabled to use the free webservice. '
#                        'Please enable it on your account page: '
#                        'http://www.geonames.org/manageaccount ',
#             'value': 10}}
# Faculté de Psychologie et des Sciences de l'Education Université de Genève None
# For qurery parmas:
# 'name=Kommission+f%C3%BCr+das+Corpus+philosophorum+medii+aevi+der+SGG&country=ch&username=username&maxRows=1'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /mnt/DATA/Dropbox/!!EPFL/16hs/Courses/ADA/ADA-Kepler/04 - Interactive Viz/helpers.py in geo_lookup(name)
#      52     try:
# ---> 53         r = requests.get(url + encoded_args)
#      54
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      70     kwargs.setdefault('allow_redirects', True)
# ---> 71     return request('get', url, params=params, **kwargs)
#      72
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     with sessions.Session() as session:
# ---> 57         return session.request(method=method, url=url, **kwargs)
#      58
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     584         # Send the request
# --> 585         r = adapter.send(request, **kwargs)
#     586
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     402                     retries=self.max_retries,
# --> 403                     timeout=timeout
#     404                 )
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     577                                                   body=body, headers=headers,
# --> 578                                                   chunked=chunked)
#     579
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     361         else:
# --> 362             conn.request(method, url, **httplib_request_kw)
#     363
#
# /home/raccct/anaconda3/lib/python3.5/http/client.py in request(self, method, url, body, headers)
#    1105         """Send a complete request to the server."""
# -> 1106         self._send_request(method, url, body, headers)
#    1107
#
# /home/raccct/anaconda3/lib/python3.5/http/client.py in _send_request(self, method, url, body, headers)
#    1150             body = _encode(body, 'body')
# -> 1151         self.endheaders(body)
#    1152
#
# /home/raccct/anaconda3/lib/python3.5/http/client.py in endheaders(self, message_body)
#    1101             raise CannotSendHeader()
# -> 1102         self._send_output(message_body)
#    1103
#
# /home/raccct/anaconda3/lib/python3.5/http/client.py in _send_output(self, message_body)
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#
# /home/raccct/anaconda3/lib/python3.5/http/client.py in send(self, data)
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     166     def connect(self):
# --> 167         conn = self._new_conn()
#     168         self._prepare_conn(conn)
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     141             conn = connection.create_connection(
# --> 142                 (self.host, self.port), self.timeout, **extra_kw)
#     143
#
# /home/raccct/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      66     err = None
# ---> 67     for res in socket.getaddrinfo(host, port, 0, socket.SOCK_STREAM):
#      68         af, socktype, proto, canonname, sa = res
#
# /home/raccct/anaconda3/lib/python3.5/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     731     addrlist = []
# --> 732     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     733         af, socktype, proto, canonname, sa = res
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-14-1299549f7f64> in <module>()
#      16
#      17
# ---> 18 map_institution_canton(has_info)
#
# <ipython-input-14-1299549f7f64> in map_institution_canton(df)
#       7         #c = get_canton(place)
#       8         #if c == '':
# ----> 9         p = geo_lookup(place)
#      10         if p:
#      11             print('found', p, 'in the api')
#
# /mnt/DATA/Dropbox/!!EPFL/16hs/Courses/ADA/ADA-Kepler/04 - Interactive Viz/helpers.py in geo_lookup(name)
#      62         print('For qurery parmas:')
#      63         pprint(encoded_args)
# ---> 64         pprint(r.json())
#      65
#      66
#
# UnboundLocalError: local variable 'r' referenced before assignment

# %%
# Load data for swiss cities
columns = ['Name', 'Kanton']
swiss_cities = pd.read_csv("swiss_cities.csv", delimiter='\t', usecols=columns, na_values=['data not included in P3', 'nan'])
swiss_cities['Kanton'] = swiss_cities['Kanton'].str.split().str[2]
swiss_cities.head(10)
# Out:
#           Name       Kanton
# 0       Zürich       Zürich
# 1         Genf         Genf
# 2        Basel  Basel-Stadt
# 3     Lausanne        Waadt
# 4         Bern         Bern
# 5   Winterthur       Zürich
# 6       Luzern       Luzern
# 7   St. Gallen       Gallen
# 8       Lugano       Tessin
# 9  Biel/Bienne         Bern

# %%
# Load data for swiss cities
columns = ['Code', 'Kanton']
swiss_cantons_full = pd.read_csv("swiss_cantons_full.csv", delimiter='\t', usecols=columns, na_values=['data not included in P3', 'nan'])
swiss_cantons_full['Kanton'] = swiss_cantons_full['Kanton'].str.split().str[2]
swiss_cantons_full.head(10)
# Out:
#   Code     Kanton
# 0   ZH     Zürich
# 1   BE       Bern
# 2   LU     Luzern
# 3   UR        Uri
# 4   SZ     Schwyz
# 5   OW   Obwalden
# 6   NW  Nidwalden
# 7   GL     Glarus
# 8   ZG        Zug
# 9   FR   Freiburg

# %%
swiss_cities_german = swiss_cities.merge(swiss_cantons_full, on='Kanton')
del swiss_cities_german['Kanton']
swiss_cities_german.columns = ['Name', 'Canton']
swiss_cities_german.head(20)
# Out:
#                  Name Canton
# 0              Zürich     ZH
# 1          Winterthur     ZH
# 2               Uster     ZH
# 3           Dübendorf     ZH
# 4            Dietikon     ZH
# 5            Wetzikon     ZH
# 6           Wädenswil     ZH
# 7              Horgen     ZH
# 8              Bülach     ZH
# 9            Adliswil     ZH
# 10         Volketswil     ZH
# 11             Kloten     ZH
# 12          Schlieren     ZH
# 13            Thalwil     ZH
# 14         Regensdorf     ZH
# 15            Opfikon     ZH
# 16  Illnau-Effretikon     ZH
# 17        Wallisellen     ZH
# 18              Stäfa     ZH
# 19           Küsnacht     ZH

# %%
# # Clean Kantons up
# swiss_cities['Kanton'] = swiss_cities['Kanton'].apply(lambda x:get_canton_code(x.rsplit()[-1])) #str.rsplit(None, 1)[0]) # = swiss_cities['Kanton'].map(.str.rsplit(None, 1)[0]
# swiss_cities.head(20)

# %%
# Load data for swiss towns
columns = ['Town', 'Canton']
swiss_cities_english = pd.read_csv("swiss_towns.csv", delimiter='\t', usecols=columns, na_values=['data not included in P3', 'nan'])
#swiss_towns.set_index('Town', inplace=True)
swiss_cities_english.columns = ['Name', 'Canton']
swiss_cities_english.head(10)
# Out:
#                  Name Canton
# 0               Aarau     AG
# 1             Aarberg     BE
# 2             Aarburg     AG
# 3            Adliswil     ZH
# 4          Aesch (BL)     BL
# 5  Affoltern am Albis     ZH
# 6                Agno     TI
# 7               Aigle     VD
# 8           Allschwil     BL
# 9        Altdorf (UR)     UR

# %%
# Load data for swiss towns
columns = ['Ville']
swiss_cities_french = pd.read_csv("swiss_cities_french.csv", delimiter='\t', usecols=columns, na_values=['french nan', 'nan'])
#swiss_towns.set_index('Ville', inplace=True)
swiss_cities_french = swiss_cities_french['Ville'].str.split(', ', expand=True)
swiss_cities_french.columns = ['Name', 'Canton']
swiss_cities_french.head(10)
# Out:
#           Name Canton
# 0       Zurich     ZH
# 1       Genève     GE
# 2         Bâle     BS
# 3     Lausanne     VD
# 4        Berne     BE
# 5  Winterthour     ZH
# 6      Lucerne     LU
# 7   Saint-Gall     SG
# 8       Lugano     TI
# 9       Bienne     BE

# %%
swiss_cities_dict = pd.concat([swiss_cities_english, swiss_cities_german, swiss_cities_french])
swiss_cities_dict.drop_duplicates('Name', inplace=True)
swiss_cities_dict.set_index('Name', inplace=True)
swiss_cities_dict.head(10)
# gd = swiss_cities_dict.groupby('Canton')
# gd.get_group('GE')
# Out:
#                    Canton
# Name
# Aarau                  AG
# Aarberg                BE
# Aarburg                AG
# Adliswil               ZH
# Aesch (BL)             BL
# Affoltern am Albis     ZH
# Agno                   TI
# Aigle                  VD
# Allschwil              BL
# Altdorf (UR)           UR

# %%
# Test for particular town
#swiss_towns.loc[swiss_towns.Town == 'Basel']
#swiss_towns.loc['Basel']['Canton']
has_info.shape
# Out:
# (62481, 3)

# %%
# Direct mapping of canton with Switzerland town list from wikipedia https://en.wikipedia.org/wiki/List_of_cities_in_Switzerland

has_info['Canton'] = np.nan

def map_inst_canton(df, column):
    for place in df[column].unique():
        if str(place) == 'nan':
            continue
        for word in place.split():
            if word in swiss_cities_dict.index:
                p = swiss_cities_dict.loc[word]['Canton']
                print(place, " -> ", p)
                df['Canton'][df[column] == place] = p

map_inst_canton(has_info, 'Institution')
map_inst_canton(has_info, 'University')
# Out:
# Faculté de Psychologie et des Sciences de l'Education Université de Genève  ->  GE
# Abt. Handschriften und Alte Drucke Bibliothek der Universität Basel  ->  BS
# Institut für ökumenische Studien Université de Fribourg  ->  FR
# /home/raccct/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Ostasiatisches Seminar Universität Zürich  ->  ZH
# Laboratoire de Didactique et Epistémologie des Sciences Université de Genève  ->  GE
# Klinische Psychologie und Psychotherapie Institut für Psychologie Universität Bern  ->  BE
# Schweizerische Rechtsquellen c/o Universität Zürich / RWI  ->  ZH
# Département de Sociologie Faculté des Sciences de la Société Université de Genève  ->  GE
# Institut für Volkswirtschaft WWZ / FGS Universität Basel  ->  BS
# Soziologisches Institut Universität Zürich  ->  ZH
# Département des langues et des littératures françaises et latines médiévales Faculté des Lettres / Université de Genève  ->  GE
# Schweizerisches Nationalmuseum Landesmuseum Zürich  ->  ZH
# Institut für Iberoromanistik Universität Basel  ->  BS
# Historische und Antiquarische Gesellschaft zu Basel  ->  BS
# Faculté de Théologie Université de Genève  ->  GE
# Bibliothèque de Genève Département des périodiques  ->  GE
# Unité d'anthropologie Département de génétique et évolution Université de Genève  ->  GE
# Universitätsbibliothek Basel Pressestelle  ->  BS
# Ägyptologisches Seminar Departement Altertumswissenschaften Universität Basel  ->  BS
# Klassische Archäologie Departement Altertumswissenschaft Universität Basel  ->  BS
# Institut d'architecture Université de Genève  ->  GE
# Faculté des lettres Université de Lausanne  ->  VD
# Institut de sociologie et de sciences politiques Université de Neuchâtel  ->  NE
# Département de science politique SES Université de Genève  ->  GE
# Section de français et de littérature comparée Université de Lausanne  ->  VD
# Institut für Philosophie Universität Bern  ->  BE
# Département de droit constitutionnel Faculté de droit Université de Genève  ->  GE
# Seminar für Rechnungswesen und Finanzmanagement Universität Freiburg  ->  FR
# Institut d'Ethnologie Université de Neuchâtel  ->  NE
# Institut de pédagogie Université de Fribourg  ->  FR
# Institut international des sciences sociales et politiques Université de Fribourg  ->  FR
# Département des sciences de l'antiquité Faculté des lettres Université de Genève  ->  GE
# Musikethnologisches Archiv der Univ. Zürich  ->  ZH
# Deutsches Seminar Universität Zürich  ->  ZH
# Erziehungsberatungsstelle Pädagogisches Institut Universität Zürich  ->  ZH
# Philosophische Fakultät I Universität Zürich  ->  ZH
# Pädagogisches Institut Universität Zürich  ->  ZH
# Fachrichtung Angewandte Psychologie Psychologisches Institut Universität Zürich  ->  ZH
# Romanisches Seminar Universität Zürich  ->  ZH
# Ethnologisches Seminar Universität Basel  ->  BS
# Medizinhistorisches Institut Universität Zürich  ->  ZH
# Englisches Seminar Universität Basel  ->  BS
# Universität Bern Institut für Archäologische Wissenschaften Ur- & Frühgesch. & Arch. der Römischen Prov.  ->  BE
# Séminaire de français moderne Université de Neuchâtel  ->  NE
# Büro für Archäologie der Stadt Zürich  ->  ZH
# Institut de psychologie Faculté des sciences sociales et politiques Université de Lausanne  ->  VD
# Institut de linguistique Faculté des lettres et sciences humaines Université de Neuchâtel  ->  NE
# Institut du monde antique et byzantin Faculté des lettres Université de Fribourg  ->  FR
# Vorderasiatische Archäologie Institut für Archäologische Wissenschaften Universität Bern  ->  BE
# Theologische Fakultät Universität Zürich  ->  ZH
# Institut d'études médiévales Université de Fribourg  ->  FR
# Faculté des lettres et sciences humaines Université de Neuchâtel  ->  NE
# Kantonsschule Sargans  ->  SG
# Chaire de Science des Religions Université de Fribourg  ->  FR
# Slavisches Seminar Universität Zürich  ->  ZH
# Kuratorium der Helvetia Sacra c/o Staatsarchiv Basel  ->  BS
# Séminaire de philologie classique Université de Neuchâtel  ->  NE
# Departement Volkswirtschaftslehre Universität Bern  ->  BE
# Université de Genève  ->  GE
# Servicezentrum Zeitschriften SZ ZS / B460 Universitätsbibliothek Bern  ->  BE
# Centre universitaire d'étude des problèmes de l'énergie (CUEPE) Université de Genève  ->  GE
# Chaire d'histoire de l'art médiéval Université de Fribourg  ->  FR
# Institut des sciences sociales Université de Lausanne  ->  VD
# Germanistische Mediävistik Departement Sprachen und Literaturen Universität Freiburg  ->  FR
# Institut für Soziologie Universität Bern  ->  BE
# Dépt d'Histoire de l'art & de Musicologie Faculté des Lettres Université de Fribourg  ->  FR
# Institut de littérature française Faculté des lettres et sciences humaines Université de Neuchâtel  ->  NE
# Kunstgeschichtliches Seminar Universität Zürich  ->  ZH
# Unité d'histoire médiévale Département d'Histoire générale Faculté des Lettres / Université de Genève  ->  GE
# Seminar für Sprache und Kulturen Universität Freiburg  ->  FR
# Departement für Sprach- und Literaturwissensch. II, Jaberg-Bibliothek Univ. Bern  ->  BE
# Institut für Geschichte & Theorie der Architektur (gta) / D-ARCH ETH Zürich  ->  ZH
# Departement für Philosophie Philosophische Fakultät Universität Freiburg  ->  FR
# Zivilistisches Seminar Universität Bern  ->  BE
# Kriminalistisches Seminar Universität Bern  ->  BE
# Pädagogische Hochschule Zürich Bibliothek PH Zürich / ZS  ->  ZH
# Pädagogische Hochschule Zürich Bibliothek PH Zürich / ZS  ->  ZH
# Dépt d'économétrie et économie politique Faculté des Hautes Etudes Commerciales (HEC) Université de Lausanne  ->  VD
# Seminar für Kooperation und Distribution Universität Freiburg  ->  FR
# Fondation Archives Jean Piaget Université de Genève  ->  GE
# Section Linguistique Faculté des lettres Université de Lausanne  ->  VD
# Ecole Suisse d'archéologie en Grèce  Univ. de Lausanne  ->  VD
# Institut für Sozialanthropologie Universität Bern  ->  BE
# Kommission des Phonogrammarchivs Universität Zürich  ->  ZH
# Rectorat de l'Université de Lausanne  ->  VD
# Forschungsstelle für Sozial- und Wirtschaftsgeschichte Universität Zürich  ->  ZH
# Faculté des Sciences Sociales et Politiques Université de Lausanne  ->  VD
# Département de patristique et d'histoire de l'Eglise Université de Fribourg  ->  FR
# KOF - Konjunkturforschungsstelle ETH Zürich  ->  ZH
# Tschudi-Kommission der AGGS Staatsarchiv Zürich  ->  ZH
# Seminar für Ur- und Frühgeschichte Universität Basel  ->  BS
# Abteilung Ur- und Frühgeschichte Historisches Seminar Universität Zürich  ->  ZH
# Droit international public Faculté de droit et des sciences criminelles Université de Lausanne  ->  VD
# Institut des sciences économiques et sociales Université de Fribourg  ->  FR
# Section des Hautes Études Commerciales HEC-FSES Université de Genève  ->  GE
# Institut de Théologie morale Université de Fribourg  ->  FR
# Département d'économétrie METRI - SES Université de Genève  ->  GE
# Historisches Seminar Universität Luzern  ->  LU
# Historisches Institut Philosophisch-historische Fakultät Universität Bern  ->  BE
# Musikwissenschaftliches Institut Universität Zürich  ->  ZH
# Musikwissenschaftliches Seminar Universität Basel  ->  BS
# Rechtswissenschaftliches Institut Universität Zürich  ->  ZH
# Sprachlabor Universität Zürich  ->  ZH
# Institut d'archéologie & d'histoire ancienne Université de Lausanne  ->  VD
# Deutsches Seminar Universität Basel  ->  BS
# Centre de recherches d'histoire économique et sociale Université de Lausanne  ->  VD
# Centre de recherche en économie de l'espace Université de Fribourg  ->  FR
# Séminaire de littérature française Université de Fribourg  ->  FR
# Séminaire de linguistique comparée et de langues indoeuropéennes Université de Fribourg  ->  FR
# Archives d'Etat de Genève  ->  GE
# Institut für Föderalismus Universität Freiburg  ->  FR
# Lehrstuhl für Zivil- und Handelsrecht Universität Freiburg  ->  FR
# Ethnologisches Seminar Universität Zürich  ->  ZH
# Institut de psychologie et éducation Faculté des lettres et sciences humaines Université de Neuchâtel  ->  NE
# Institut des sciences sociales Faculté des sciences sociales et politiques Université de Lausanne  ->  VD
# Domaine Sociologie et Médias Département des Sciences de la Société Université de Fribourg  ->  FR
# Institut d'Histoire Faculté des Lettres et des Sciences Humaines Université de Neuchâtel  ->  NE
# Département de Physique Théorique Université de Genève  ->  GE
# Wirtschaftswissenschaftliches Zentrum, WWZ Universität Basel  ->  BS
# École des Hautes Études Commerciales Université de Lausanne  ->  VD
# IPMZ - Institut für Publizistikwissenschaft und Medienforschung Universität Zürich  ->  ZH
# Institut de droit de la santé Faculté de droit Université de Neuchâtel  ->  NE
# Département de Philosophie Faculté des Lettres Université de Fribourg  ->  FR
# Klassische Archäologie Institut für Archäologische Wissenschaften Universität Bern  ->  BE
# Departement Geschichte Universität Basel  ->  BS
# Rektorat Universität Zürich  ->  ZH
# Institut für Empirische Wirtschaftsforschung Universität Zürich  ->  ZH
# Lehrstuhl für Steuer-, Finanz- und Verwaltungsrecht Universität Zürich  ->  ZH
# Kantonsschule Appenzell A.Rh.  ->  AI
# Institut für öffentliches Recht Universität Bern  ->  BE
# Bibliothek Kantonsschule Luzern  ->  LU
# Minéralogie et Pétrographie Département des Géosciences Université de Fribourg  ->  FR
# Fakultät für Psychologie Universität Basel  ->  BS
# Musées d'art et d'histoire de Genève  ->  GE
# Sozialökonomisches Institut Universität Zürich  ->  ZH
# Centre de Dialectologie Université de Neuchâtel  ->  NE
# Slavisches Seminar Universität Basel  ->  BS
# Historisches Seminar Universität Zürich  ->  ZH
# Département des Sciences de l'Antiquité Faculté des Lettres Université de Genève  ->  GE
# Institut de langue et littérature allemandes Faculté des lettres et sciences humaines Université de Neuchâtel  ->  NE
# Geographisches Institut Universität Zürich  ->  ZH
# Kantonsschule Baden  ->  AG
# Département d'histoire de l'art et de musicologie Université de Genève  ->  GE
# Séminaire d'anglais Université de Neuchâtel  ->  NE
# Seminar für Kirchengeschichte Universität Freiburg  ->  FR
# Erziehungsdirektion des Kantons Appenzell A.Rh.  ->  AI
# Centre Universitaire d'Informatique Université de Genève  ->  GE
# Rechtswissenschaftliche Fakultät Universität Zürich  ->  ZH
# Chaire de pédagogie et didactique EPF de Lausanne  ->  VD
# Juristische Fakultät Universität Basel  ->  BS
# Section d'Italien Faculté des Lettres Université de Lausanne  ->  VD
# Institut für Populäre Kulturen Universität Zürich  ->  ZH
# Biblisches Institut der Universität Freiburg  ->  FR
# Institut für Atmosphäre und Klima ETH Zürich  ->  ZH
# Bereich Sonderpädagogik Institut für Erziehungswissenschaft Universität Zürich  ->  ZH
# Interfakultäre Koordinationsstelle für Allgemeine Ökologie (IKAÖ) Universität Bern  ->  BE
# Departement Geowissenschaften Universität Basel  ->  BS
# Institut für Praktische Theologie Evangelisch-theologische Fakultät Universität Bern  ->  BE
# Liceo di Lugano 2  ->  TI
# Institut für Betriebswirtschaft Universität Basel  ->  BS
# Département de Psychologie Université de Fribourg  ->  FR
# Laténium Parc et musée d'archéologie de Neuchâtel  ->  NE
# Institut für Veterinärphysiologie Vetsuisse-Fakultät Universität Zürich  ->  ZH
# Faculté des lettres Université de Genève  ->  GE
# Institut für Archäologie - Fachbereich Klassische Archäologie und Archäologische Sammlung, Universität Zürich  ->  ZH
# Seminar für Vergleichende Literaturwissenschaften Universität Zürich  ->  ZH
# Institut de pédagogie curative Université de Fribourg  ->  FR
# Archives de l'Etat de Fribourg  ->  FR
# Institut für Soziologie Universität Basel  ->  BS
# Mineralogisch-Petrographisches Institut Universität Basel  ->  BS
# Philosophisches Seminar Universität Zürich  ->  ZH
# Section de langues et civilisations slaves Faculté des lettres Université de Lausanne  ->  VD
# Kunsthistorisches Seminar Universität Bern  ->  BE
# Institut für Denkmalpflege und Bauforschung ETH Zürich  ->  ZH
# Institut européen de l'Université de Genève  ->  GE
# Département de droit civil Université de Genève  ->  GE
# Section d'Histoire de l'Art Faculté des Lettres Université de Lausanne  ->  VD
# CETEL Faculté de droit Université de Genève  ->  GE
# Institut für Germanistik Philosophisch-historische Fakultät Universität Bern  ->  BE
# Institut für englische Sprachen und Literaturen Universität Bern  ->  BE
# Division Economique et Sociale Université de Neuchâtel  ->  NE
# Faculté de Théologie Université de Fribourg  ->  FR
# Phonetisches Laboratorium Universität Zürich  ->  ZH
# Institut d'histoire moderne et contemporaine Université de Fribourg  ->  FR
# Robert Walser-Stiftung Zürich  ->  ZH
# Psychologisches Institut Universität Zürich  ->  ZH
# Völkerkundemuseum Universität Zürich  ->  ZH
# Département des sciences de la Terre Université de Genève  ->  GE
# Service archéologique Canton de Fribourg  ->  FR
# Europainstitut Universität Basel  ->  BS
# Institut d'histoire économique et sociale Université de Lausanne  ->  VD
# Faculté de droit Université de Lausanne  ->  VD
# Philosophisches Seminar Universität Basel  ->  BS
# Institut d'informatique et Intelligence artificielle Université de Neuchâtel  ->  NE
# Unité de Musicologie Faculté des Lettres Université de Genève  ->  GE
# Geographisches Institut Universität Bern  ->  BE
# Kantonale Denkmalpflege Zug  ->  ZG
# Séminaire de philologie classique Université de Fribourg  ->  FR
# Departement für Biblische Studien Universität Freiburg  ->  FR
# Bâtiment du Rectorat et de l'administration centrale Université de Lausanne  ->  VD
# Centre de recherches sur les lettres romandes (CRLR) Université de Lausanne  ->  VD
# Departement Forschung Kantonsspital Basel  ->  BS
# Englisches Seminar Universität Zürich  ->  ZH
# Séminaire de préhistoire Université de Neuchâtel  ->  NE
# Institut de Police Scientifique Ecole des Sciences Criminelles Université de Lausanne  ->  VD
# Archäologischer Dienst des Kantons Bern  ->  BE
# Slavisches Seminar Universität Freiburg  ->  FR
# Institut für klassische Philologie und antike Philosophie Universität Bern  ->  BE
# Institut für Völkerrecht und ausländisches Verfassungsrecht Universität Zürich  ->  ZH
# Arbeitslehrerinnenseminar des Kantons Zürich  ->  ZH
# Section de français Faculté des lettres Université de Lausanne  ->  VD
# Centre de droit comparé, européen et international Université de Lausanne  ->  VD
# Pädagogisches Institut Universität Bern  ->  BE
# Section d'Histoire Faculté des Lettres Université de Lausanne  ->  VD
# Département d'Electricité  (DE) EL - Ecublens  ->  VD
# Faculté de théologie Université de Neuchâtel  ->  NE
# Séminaire de linguistique française Université de Fribourg  ->  FR
# Institut d'histoire économique et sociale (IHES) Université de Lausanne  ->  VD
# Institut für Sozialethik Ethik-Zentrum Universität Zürich  ->  ZH
# Section de Philosophie Faculté des Lettres Université de Lausanne  ->  VD
# BFF Bern Berufs-, Fach- und Fortbildungsschule  ->  BE
# Division de Neuropsychiatrie Hôpitaux Universitaires de Genève  ->  GE
# Département d'économie Université de Genève  ->  GE
# Abteilung Information Engineering Institut für Wirtschaftsinformatik Universität Bern  ->  BE
# Département de Linguistique Française Faculté des Lettres Université de Genève  ->  GE
# Mathematisch-naturwissensch. Gymnasium Kantonsschule Rämibühl Zürich  ->  ZH
# Dekanat Theologische Fakultät Universität Basel  ->  BS
# ETI / TIM / ISSCO Université de Genève  ->  GE
# Centre d'Histoire Economique Internationale Université de Genève  ->  GE
# Heilpädagogisches Institut Universität Freiburg  ->  FR
# Institut de recherches économiques Université de Neuchâtel  ->  NE
# Abteilung Unternehmensführung Inst. für Marketing und Unternehmensführung Universität Bern  ->  BE
# Institut für Musikwissenschaft Universität Bern  ->  BE
# Institut de sociologie Université de Fribourg  ->  FR
# Institut interdisciplinaire d'éthique et des droits de l'homme Université de Fribourg  ->  FR
# Musée d'ethnographie de Genève  ->  GE
# Centre d'études juridiques européennes Faculté de droit Université de Genève  ->  GE
# Séminaire de littérature française Universität Bern  ->  BE
# Section des Sciences de l'Antiquité Faculté des Lettres Université de Lausanne  ->  VD
# Rectorat de l'Université de Fribourg  ->  FR
# Inst. für Pädagogik und Schulpädagogik AAP Universität Bern  ->  BE
# Sozialpsychologie Psychologisches Institut Universität Zürich  ->  ZH
# Géologie et Paléontologie Département des Géosciences Université de Fribourg  ->  FR
# Volkswirtschaftliches Institut Abteilung Wirtschaftstheorie Universität Bern  ->  BE
# Institut de Géographie Université de Lausanne  ->  VD
# Institut Religions, Cultures, Modernité Faculté de Théologie Université de Lausanne  ->  VD
# Stiftschule Einsiedeln Rektorat  ->  SZ
# Literargymnasium Kantonsschule Rämibühl Zürich  ->  ZH
# Institut de Minéralogie et Pétrographie Centre d'Analyse Minérale Université de Lausanne  ->  VD
# IPTO Université de Neuchâtel  ->  NE
# Forschungsstelle Arbeitsmarkt- und Industrieökonomik (FAI), WWZ Universität Basel  ->  BS
# Centre de Linguistique Appliquée Université de Neuchâtel  ->  NE
# Centre Interfacultaire de Gérontologie Université de Genève  ->  GE
# Staatsarchiv Basel Stadt  ->  BS
# Stadtbibliothek Schaffhausen  ->  SH
# Département d'Histoire de l'Eglise Faculté de Théologie Université de Fribourg  ->  FR
# Abteilung Pädagogische Psychologie Institut für Erziehungswissenschaft Universität Bern  ->  BE
# Université de Fribourg Chaire de Finance et Gouvernance d`Entrepris Prof. D. Isakov  ->  FR
# Liceo Cantonale Locarno  ->  TI
# Département d'Informatique Université de Fribourg  ->  FR
# Section d'espagnol Faculté des Lettres Université de Lausanne  ->  VD
# Département de Géographie et Environnement Faculté des Sciences de la Société Université de Genève  ->  GE
# Dépt de langue & littérature allemandes Faculté des lettres Université de Genève  ->  GE
# Institut de Logique Université de Neuchâtel  ->  NE
# Institut romand des sciences bibliques(IRSB) Université de Lausanne  ->  VD
# Département de droit international public et organisation internationale Université de Genève  ->  GE
# Département de Philosophie Faculté des Lettres Université de Genève  ->  GE
# Section d'anglais Faculté des lettres Université de Lausanne  ->  VD
# Département de Chimie Organique Université de Genève  ->  GE
# Laboratorium für Physikalische Chemie ETH Zürich  ->  ZH
# Physikalische Chemie Departement Chemie Universität Basel  ->  BS
# Département de Chimie Université de Fribourg  ->  FR
# Inst. f. Techn. Physik ETH - Zürich  ->  ZH
# Groupe Limnoceane Institut de géologie Université de Neuchâtel  ->  NE
# Departement Physik Universität Basel  ->  BS
# Institut de Physique Université de Neuchâtel  ->  NE
# Observatoire de Genève Université de Genève  ->  GE
# Observatoire de Genève Université de Genève  ->  GE
# Laboratoire d'astrophysique Observatoire de Genève EPFL - SB - IPEP - LASTRO  ->  GE
# Institut für Geologie Universität Bern  ->  BE
# Laboratorium für Festkörperphysik ETH Zürich  ->  ZH
# Inst. f. Reaktortechnik ETH - Zürich  ->  ZH
# Institut de Mathématiques Université de Lausanne  ->  VD
# Laboratorium für Anorganische Chemie ETH Zürich  ->  ZH
# Botanisches Institut Universität Basel  ->  BS
# Institut für Physikalische Chemie Universität Zürich  ->  ZH
# Institut für angewandte Physik Universität Bern  ->  BE
# Institut de Physique Théorique Département de Physique EPF - Ecublens  ->  VD
# Institut für Teilchenphysik ETH Zürich  ->  ZH
# Institut de Géologie Université de Neuchâtel  ->  NE
# Institut für Chemie Universität Zürich  ->  ZH
# Institut für Anorganische Chemie Universität Freiburg  ->  FR
# Institut für Verfahrenstechnik ETH Zürich  ->  ZH
# Institut de Physique Théorique Université de Lausanne  ->  VD
# Département de physique nucléaire et corpusculaire Université de Genève  ->  GE
# Section de mathématiques Université de Genève  ->  GE
# Hochalpine Forschungsstationen Jungfraujoch & Gornergrat Universität Bern  ->  BE
# Département de Chimie Physique Faculté des Sciences Université de Genève  ->  GE
# Département de Chimie Minérale et Analytique Université de Genève  ->  GE
# Institut für Mineralogie und Petrographie ETH Zürich  ->  ZH
# Institut de Physique de la Matière Condensée (IPMC) Université de Lausanne  ->  VD
# Laboratorium für Organische Chemie ETH Zürich  ->  ZH
# Section des Sciences Pharmaceutiques Faculté des Sciences Université de Genève  ->  GE
# Organisch-chemisches Institut Universität Zürich  ->  ZH
# Institut für Organische Chemie Universität Bern  ->  BE
# Département de Physique de la Matière Condensée Université de Genève  ->  GE
# Astronomisches Institut Universität Bern  ->  BE
# Geologisches Institut ETH Zürich  ->  ZH
# Institut für Geophysik ETH Zürich  ->  ZH
# Versuchsanstalt für Wasserbau, Hydrologie und Glaziologie ETH Zürich  ->  ZH
# Institut für Chemie- und Bioingenieurwissenschaften ETH Zürich  ->  ZH
# Institut für Farbenchemie Universität Basel  ->  BS
# Institut für Theoretische Physik ETH Zürich  ->  ZH
# Institut für Anorganische Chemie Universität Basel  ->  BS
# Forschungsinstitut für Mathematik ETH Zürich  ->  ZH
# Institut für Anorganische, Ana- lytische und Physikalische Chemie Universität Bern  ->  BE
# Organische Chemie Departement Chemie Universität Basel  ->  BS
# Institut de chimie Université de Neuchâtel  ->  NE
# Département de Physique Université de Fribourg  ->  FR
# Institut für Theoretische Physik Universität Zürich  ->  ZH
# Institut für Theoretische Physik Universität Bern  ->  BE
# Groupe de Géomagnétisme Université de Neuchâtel  ->  NE
# Physik-Institut Universität Zürich  ->  ZH
# Laboratoire de Chimie Technique LCT Département de Chimie EPF - Ecublens  ->  VD
# Inst. de génie de l'environnement IGE - Département de Génie rural EPF - Ecublens  ->  VD
# Physikalisches Institut Universität Bern  ->  BE
# Institut de Physique des Hautes Energies Université de Lausanne  ->  VD
# Laboratorium für Hochenergiephysik Albert Einstein Center Universität Bern  ->  BE
# Klima- und Umweltphysik Physikalisches Institut Universität Bern  ->  BE
# Photografisches Institut ETH - Zürich  ->  ZH
# Institut F.-A. Forel Université de Genève  ->  GE
# Institut für Baustatik und Konstruktion ETH Zürich  ->  ZH
# Institut für Mathematik Universität Zürich  ->  ZH
# Institut für Geochemie und Petrologie ETH Zürich  ->  ZH
# Departement Mathematik ETH Zürich  ->  ZH
# Institut de Métallurgie Structurale Université de Neuchâtel  ->  NE
# Seminar für Angewandte Mathematik ETH Zürich  ->  ZH
# Departement für Physik und Astronomie Astronomisches Institut Universität Basel  ->  BS
# Institut für Feldtheorie und Höchstfrequenztechnik ETH Zürich  ->  ZH
# Departement Chemie und Angewandte Biowissenschaften ETH  Zürich  ->  ZH
# Physikalisch-Meteorologisches Observatorium Davos und Weltstrahlungszentrum  ->  GR
# Institut de Minéralogie et Pétrographie Université de Lausanne  ->  VD
# Institut für Geodäsie und Photogrammetrie ETH Zürich  ->  ZH
# Departement Umweltsystemwissenschaften ETH Zürich  ->  ZH
# Gruppe Isotopengeologie Institut für Geologie Universität Bern  ->  BE
# Institut für Elektrische Energieübertragung und Hochspannungstechnik ETH Zürich  ->  ZH
# Naturhistorisches Museum Basel  ->  BS
# Centre de Recherche de Genève  ->  GE
# Institut für Fluiddynamik ETH Zürich  ->  ZH
# Abteilung Biophysikalische Chemie Biozentrum der Universität Basel  ->  BS
# Geologisch-Paläontologisches Institut Universität Basel  ->  BS
# Musée Cantonal de Géologie Université de Lausanne  ->  VD
# Laboratoire de Cristallographie Université de Genève  ->  GE
# Institut für Werkzeugmaschinen und Fertigung ETH Zürich  ->  ZH
# Institut für Pharmakologie Medizinische Fakultät Universität Bern  ->  BE
# Institut für Elektronik ETH Zürich  ->  ZH
# Fachbereich Mathematik Departement Mathematik und Informatik Universität Basel  ->  BS
# Mathematisches Institut Universität Bern  ->  BE
# Institut für Polymere ETH Zürich  ->  ZH
# Institut für Astronomie ETH Zürich  ->  ZH
# Institut de géologie et de paléontologie Université de Lausanne  ->  VD
# Institut de mathématiques Université de Neuchâtel  ->  NE
# Ingenieurschule Burgdorf  ->  BE
# Institut für Informationssysteme ETH Zürich  ->  ZH
# Paläontologisches Institut und Museum Universität Zürich  ->  ZH
# Laboratorium für chemische und mineralogische Kristallographie Universität Bern  ->  BE
# Institut de géophysique Université de Lausanne  ->  VD
# Institut für Informatik Universität Zürich  ->  ZH
# Ecole supérieur de commerce de la ville de Sion  ->  VS
# Institut für Angewandte Physik ETH Zürich  ->  ZH
# Departement Informatik ETH Zürich  ->  ZH
# Institut de Pharmacognosie et Phytochimie Université de Lausanne  ->  VD
# Laboratoire de spectrométrie de masse Université de Genève  ->  GE
# Institut für pharmazeutische Technologie Departement Pharmazie Universität Basel  ->  BS
# Institut für mathematische Statistik und Versicherungslehre Universität Bern  ->  BE
# Institut für Terrestrische Ökosysteme ETH Zürich  ->  ZH
# Département de Mathématiques Université de Fribourg  ->  FR
# Institut de géographie Université de Neuchâtel  ->  NE
# Centre d'hydrogéologie et de géothermie Université de Neuchâtel  ->  NE
# Institut Universitaire de Médecine Sociale et Préventive - IUMSP CHUV et Université de Lausanne  ->  VD
# Labor für Metallphysik und Technologie ETH Zürich  ->  ZH
# Institut für Theoretische Informatik ETH Zürich  ->  ZH
# Institut für Operations Research ETH Zürich  ->  ZH
# Département de Morphologie Faculté de Médecine Université de Genève  ->  GE
# Institut für Angewandte Mathematik Universität Zürich - Irchel  ->  ZH
# Institut für Operations Research und Math. Methoden der Wirtschaft-Wissenschaft Universität Zürich  ->  ZH
# Institut für Mechanische Systeme ETH Zürich  ->  ZH
# Institut für Automatik ETH Zürich  ->  ZH
# Institut für Informatik Universität Bern  ->  BE
# Laboratoire de compilation Département d'informatique EPF - Ecublens (MA)  ->  VD
# Seminar für Statistik Universität Freiburg  ->  FR
# Institut für Energietechnik ETH Zürich  ->  ZH
# Institut de statistique Faculté des sciences économiques Universite de Neuchâtel  ->  NE
# Institut für Technische Informatik und Kommunikationsnetze ETH Zürich  ->  ZH
# Institut für Quantenelektronik ETH Zürich  ->  ZH
# Global Studies Institute Université de Genève  ->  GE
# Institut für Terrestrische Ökosysteme ITES Forstliches Ingenieurwesen ETH Zürich  ->  ZH
# Institut für Baustoffe ETH Zürich  ->  ZH
# Institut de Microtechnique  (IMT) Département de Microtechnique EPF - Ecublens  ->  VD
# Naturforschende Gesellschaft Basel Naturhistorisches Museum  ->  BS
# Institut de Biologie et de Physiologie végétales Université de Lausanne  ->  VD
# Chirurgische Universitätsklinik Tiefenauspital der Stadt Bern  ->  BE
# Institut für Anatomie Medizinische Fakultät Universität Bern  ->  BE
# Abteilung Mikrobiologie Biozentrum Universität Basel  ->  BS
# Physiologisches Institut Universität Zürich  ->  ZH
# Universitätsinstitut für Immunologie Universität Bern  ->  BE
# Service d'Immunologie et d'Allergologie Département de Médecine Interne Hôpitaux Universitaires de Genève  ->  GE
# Institut für Molekulare Biologie Universität Zürich  ->  ZH
# Kardiovaskuläre Abteilung Departement für Innere Medizin Kantonsspital Zürich  ->  ZH
# Dépt des Neurosciences Fondamentales Faculté de Médecine Université de Genève  ->  GE
# Institut für Mikrobiologie Departement Biologie ETH Zürich  ->  ZH
# Département de Botanique et de Biologie végétale Université de Genève  ->  GE
# Département de Biologie Moléculaire Faculté des Sciences Université de Genève  ->  GE
# Université de Lausanne Institut d'Anatomie  ->  VD
# Kantonsspital Luzern Medizinische Klinik  ->  LU
# Fondation pour Recherches Médicales Université de Genève  ->  GE
# Abteilung Zellbiologie Biozentrum Universität Basel  ->  BS
# Institut für Zellbiologie Departement Biologie Universität Bern  ->  BE
# Institut für klin. Eiweissforschung Universität Bern Tiefenauspital  ->  BE
# Centre Integratif de Genomique Faculté de Biologie et Médecine Université de Lausanne  ->  VD
# Departement für Chemie und Biochemie Universität Bern  ->  BE
# Institut für Pathologie Medizinische Fakultät Universität Bern  ->  BE
# Institut für Toxikologie der ETH und der Universität Zürich  ->  ZH
# Universitätsklinik Balgrist Departement für Orthopädie Universität Zürich  ->  ZH
# Biochemisches Institut Universität Zürich  ->  ZH
# Biomolekulare Tumordiagnostik Universitätsspital Basel  ->  BS
# Zoologisches Institut der Uni- versität Bern Abteilung Neurobiologie  ->  BE
# Département de Biologie Cellulaire Faculté des Sciences Université de Genève  ->  GE
# Urologische Klinik und Poliklinik Universitätsspital Zürich  ->  ZH
# Institut für Pflanzenbiologie Universität Zürich  ->  ZH
# Recteur de l'Université de Genève  ->  GE
# Dépt Microbiologie et Médecine Moléculaire Faculté de Médecine Université de Genève  ->  GE
# Institut de Zoologie Faculté des Sciences Université de Neuchâtel  ->  NE
# Institut für Medizinische Radiobiologie Universität Zürich  ->  ZH
# Medizinische Universitätspoliklinik Universitätsspital Basel  ->  BS
# Zoologisches Institut Universität Freiburg  ->  FR
# Institut für Dynamische Systeme und Regelungstechnik ETH Zürich  ->  ZH
# Institut für Biochemie Departement Biologie ETH Zürich  ->  ZH
# Abteilung Strukturbiologie und Biophysik Biozentrum Universität Basel  ->  BS
# Institut für Zellbiologie ETH Zürich  ->  ZH
# Neurochirurgische Klinik Universitätsspital Zürich  ->  ZH
# Abteilung Pharmakologie/Neurobiologie Biozentrum der Universität Basel  ->  BS
# Hämostase- Hämatologielabor Departement Zentrallaboratorium Universitätsspital Basel  ->  BS
# Institut für Systematische Botanik und Botanischer Garten Universität Zürich  ->  ZH
# Klinik für Endokrinologie, Diabetologie und Klinische Ernährung Universitätsspital Zürich  ->  ZH
# Institut für Biochemie und Genetik Universität Basel  ->  BS
# Laboratoire de Bioénergétique Dépt. de Botanique et Biologie Végétale Université de Genève  ->  GE
# Institut für Pflanzenwissenschaften Universität Bern  ->  BE
# Institut für Hirnforschung Universität Zürich  ->  ZH
# Institut für Medizinische Mikrobiologie Universität Zürich  ->  ZH
# Departement Magen-Darm-, Leber- und Lungenkrankheiten Universitätsspital Bern  ->  BE
# Inselspital Universitätsspital Bern  ->  BE
# Département de Pharmacologie & Toxicologie Faculté de Biologie et de Médecine Université de Lausanne  ->  VD
# Section de Médecine Dentaire Faculté de Médecine Université de Genève  ->  GE
# Theodor Kocher Institut Medizinische Fakultät Universität Bern  ->  BE
# Klinik für Rheumatologie Universitätsspital Zürich  ->  ZH
# Neurologische Klinik Universitätsspital Zürich  ->  ZH
# Kinderspital Zürich Universitäts-Kinderklinik  ->  ZH
# Département d'Ecologie et d'Evolution Faculté de Biologie et de Médecine Université de Lausanne  ->  VD
# Lab. d'Ecologie et de Biologie Aquatique Institut des Sciences de l'Environnement Université de Genève  ->  GE
# Institut für Parasitologie Vetsuisse-Fakultät Universität Zürich  ->  ZH
# Virologisches Institut Vetsuisse Fakultät Universität Zürich  ->  ZH
# Département de Génétique et Evolution Faculté des Sciences Université de Genève  ->  GE
# Abt. Plastische & Rekonstruktive Chirurgie Uniklinik für Wiederherstellende Chirurgie Kantonsspital Basel  ->  BS
# Département de biochimie médicale Faculté de médecine Université de Genève  ->  GE
# Département de Médecine Université de Fribourg  ->  FR
# Klinik für Angiologie Departement Innere Medizin Universitätsspital Zürich  ->  ZH
# Institut für Molekularbiologie und Biophysik ETH Zürich  ->  ZH
# Institut für Pathologie Universitätsspital Basel  ->  BS
# Service de Néphrologie Département de Médecine Interne Hôpitaux Universitaires de Genève  ->  GE
# Institut für Veterinär-Bakteriologie Vetsuisse-Fakultät Universität Bern  ->  BE
# Département de Physiologie Faculté de Biologie et de Médecine Université de Lausanne  ->  VD
# Institut für Klinische Pharmakologie Universität Bern  ->  BE
# Laboratoire d'Analyse Ultrastructurale et Centre de Microscopie Electronique Université de Lausanne  ->  VD
# Institut für Physiologie Medizinische Fakultät Universität Bern  ->  BE
# Institut für Klinische Chemie Universitätsspital Zürich  ->  ZH
# Limnologische Station Universität Zürich  ->  ZH
# Klinik für Immunologie Departement Innere Medizin Universitätsspital Zürich  ->  ZH
# Hals-Nasen-Ohrenklinik Kantonsspital Basel  ->  BS
# Laboratoire de Physiologie végétale Université de Neuchâtel  ->  NE
# Département de Pathologie et Immunologie Faculté de Médecine / CMU Université de Genève  ->  GE
# Natur-Museum Luzern  ->  LU
# Laboratoire de Botanique Évolutive Institut de Biologie Université de Neuchâtel  ->  NE
# Steroidlabor / Abt. Endokr. und Stoffwechsel Departement für Innere Medizin Univ.sspital Zürich  ->  ZH
# Abteilung für Transplantationsimmunologie und Nephrologie Universitätsspital Basel  ->  BS
# Departement Klinische Forschung Inselspital Bern Universität Bern  ->  BE
# Departement Klinische Forschung Inselspital Bern Universität Bern  ->  BE
# Département de Biochimie Faculté des Sciences II Université de Genève  ->  GE
# Centre Médical Universitaire Université de Genève  ->  GE
# Service de médecine interne générale Hôpitaux Universitaires de Genève  ->  GE
# Institut für Genetik Vetsuisse-Fakultät Universität Bern  ->  BE
# Institut für Physiologie der Universität Basel Vesalianum  ->  BS
# Biologisches Zentrallaboratorium Kantonsspital Zürich  ->  ZH
# Service de Cardiologie Département de Médecine Interne Hôpitaux Universitaires de Genève  ->  GE
# Forschungsbereich Klinische und Experimentelle Psychopathologie Psychiatrische Universitätsklinik Zürich  ->  ZH
# Universitäts-Kinderspital beider Basel  ->  BS
# Klinik für Wiederkäuer Vetsuisse Universität Bern  ->  BE
# Zentrum für Zahnmedizin Universität Zürich  ->  ZH
# Abteilung Psychosoziale Medizin Universitätsspital Zürich  ->  ZH
# Medizinische Genetik Universitätsspital Basel  ->  BS
# Institut für Sozial- und Präventivmedizin Universität Bern  ->  BE
# Service de Médecine Nucléaire Département de Radiologie Hôpitaux Universitaires de Genève  ->  GE
# Dermatologische Klinik Universitätsspital Zürich  ->  ZH
# Veterinär-Pharmakologisches Institut Vetsuisse-Fakultät Universität Bern  ->  BE
# Laboratoire de Microbiologie Institut de Biologie Université de Neuchâtel  ->  NE
# Institut für Medizinische Mikrobiologie Universität Basel  ->  BS
# Institut für Biomedizinische Technik Universität Zürich und ETHZ  ->  ZH
# Institut für botanische Biologie Departement für Biologie Universität Freiburg  ->  FR
# Abteilung Virologie Inst. für Med. Mikrobiologie und Hygiene Albert-Ludwigs-Universität Freiburg  ->  FR
# Unité de Microbiologie BIVEG - Faculté des Sciences III Universié de Genève  ->  GE
# Service de Rhumatologie Département de Médecine Interne Hôpital Cantonal Universitaire de Genève  ->  GE
# Abteilung Biochemie Biozentrum Universität Basel  ->  BS
# Institut für Experimentelle Immunologie Departement Pathologie Universität Zürich  ->  ZH
# Ethologische Station Hasli Institut für Ökologie und Evolution Universität Bern  ->  BE
# Institut für Medizinische Virologie Universität Zürich  ->  ZH
# Institut für Tierpathologie Vetsuisse-Fakultät Universität Bern  ->  BE
# Département de Microbiologie Fondamentale Faculté de Biologie et de Médecine Université de Lausanne  ->  VD
# Institut für allgemeine Botanik ETH Zürich  ->  ZH
# Theodor Kocher Institut Universität Bern  ->  BE
# Augenklinik Universitätsspital Zürich  ->  ZH
# Institut für Hochbauforschung ETH Zürich Hönggerberg  ->  ZH
# Endocrinologie, Diabétologie et Nutrition Département de Médecine Interne Hôpitaux Universitaires de Genève  ->  GE
# Abteilung Endokrinologie, Diabetologie und Metabolismus Universitätsspital Basel  ->  BS
# ORL-Klinik Universitätsspital Zürich  ->  ZH
# Institut für Lebensmittelwissenschaften, Ernährung und Gesundheit ETH Zürich  ->  ZH
# Klinik für Parodontologie Zahnmedizinische Kliniken Universität Bern  ->  BE
# Abteilung für Hämatologie Universitätsspital Basel  ->  BS
# Institut für Diagnostische Radiologie Departement Medizinische Radiologie Universitätsspital Zürich  ->  ZH
# Universitätsklinik für Nuklearmedizin Inselspital Bern  ->  BE
# Institut de génétique et de biolo- gie microbiennes Université de Lausanne  ->  VD
# Abteilung Anatomie Departement für Medizin Universität Freiburg  ->  FR
# Zoologisches Institut Bio-/Pharmazentrum Universität Basel  ->  BS
# Laboratoire de Génétique Sciences III Université de Genève  ->  GE
# Conservatoire et jardin botaniques de la Ville de Genève  ->  GE
# Psychiatrische Universitätspoliklinik Allg. Psychiatrie ambulant c/o Universitätsspital Basel  ->  BS
# Klinik für Viszeral- und Transplantationschirurgie Universitätsspital Zürich  ->  ZH
# Institut für Biomechanik ETH Zürich  ->  ZH
# Institut de Médecine Sociale et Préventive Faculté de Médecine Université de Genève  ->  GE
# Institut für Lebensmittelchemie der Universität Bern  ->  BE
# Dermatologische Universitätsklinik Universitätsspital Basel  ->  BS
# Abteilung für Klinische Neurophysiologie Neurologische Universitätsklinik Kantonsspital Basel  ->  BS
# Institut für Nuklearmedizin Universitätsspital Basel  ->  BS
# Labor für Elektronenmikroskopie Veterinär-Medizinische Fakultät Universität Zürich  ->  ZH
# Departement Umweltsystemwissenschaften ETH Zürich IBP / D-USYS  ->  ZH
# WHO Immun. Research & Training Ctr. Institute of Biochemistry Université de Lausanne  ->  VD
# Registre Genevois des Tumeurs Université de Genève  ->  GE
# Abteilung für Klinische Physiologie Klinik für Herz-& Thoraxchirurgie Universitätskliniken Basel  ->  BS
# Forschung Geburtshilfe Universitätsspital Zürich  ->  ZH
# Veterinärmedizinische Fakultät Klinik für Andrologie und Gynäkologie Universität Zürich  ->  ZH
# Abteilung für Angiologie Medizinische Universitätsklinik A Universitätsspital Basel  ->  BS
# Laboratoire de Virologie Service des Maladies Infectieuses Hôpitaux Universitaires de Genève  ->  GE
# Institut für Epidemiologie, Biostatistik und Prävention Universität Zürich  ->  ZH
# Laboratoire de Biotechnologie moléculaire Université de Lausanne EPFL - LBTM  ->  VD
# Institut für Veterinär-Virologie Vetsuisse-Fakultät Universität Bern  ->  BE
# Institut für Infektionskrankheiten Universität Bern  ->  BE
# Veterinärmedizinisches Labor Universität Zürich  ->  ZH
# Klinik für Herz- und Gefässchirurgie Departement Chirurgie Universitätsspital Zürich  ->  ZH
# Departement Klinische Forschung Universität Bern  ->  BE
# Département Gynécologie et Obstétrique Maternité Hôpitaux Universitaires de Genève  ->  GE
# Klinik für Geburtshilfe Departement Frauenheilkunde Universitätsspital Zürich  ->  ZH
# Institut für Sozial- und Präventivmedizin Universität Basel Swiss TPH  ->  BS
# Division de Biochimie Département de Biologie Université de Fribourg  ->  FR
# Klinik für Hämatologie Departement Innere Medizin Universitätsspital Zürich  ->  ZH
# Histologie et Embryologie générale Département de médecine Université de Fribourg  ->  FR
# Geriatrische Universitätsklinik Kantonsspital Basel  ->  BS
# Regionalspital Burgdorf Medizinische Abteilung  ->  BE
# Abteilung für Neuropsychologie Neurologische Klinik Universitätsspital Zürich  ->  ZH
# Kantonsspital Liestal Chirurgische Klinik Abt. Orthopädie & Traumatologie  ->  BL
# Veterinärmedizinisches Labor Departement für Nutztiere Vetsuisse-Fakultät der Universität Zürich  ->  ZH
# Division d'Anesthésiologie Hôpitaux universitaires de Genève  ->  GE
# Limnologische Station Institut für Pflanzenbiologie Universität Zürich  ->  ZH
# Division d'Hématologie Département de Médecine Interne Hôpitaux Universitaires de Genève  ->  GE
# Sukkulentensammlung Zürich  ->  ZH
# Anatomisches Institut Universität Basel  ->  BS
# Klinik für Kardiologie Bereich Medizin Universitätsspital Basel  ->  BS
# Institut für Veterinärpharmakologie und -toxikologie Universität Zürich  ->  ZH
# Abt. für Infektiologie und Spitalhygiene Universitätsspital Zürich  ->  ZH
# Gesundheitsdienst der Stadt Bern  ->  BE
# Unité d'Investigation Clinique Hôpitaux Universitaires de Genève  ->  GE
# Anatomisches Institut Universität Zürich  ->  ZH
# Abteilung Mikrobiologie Institut für Pflanzenbiologie Universität Zürich  ->  ZH
# Abt. für Zell- und Molekularpathologie Departement für Pathologie Universität Zürich  ->  ZH
# Institut für Neuropathologie Departement für Pathologie Universitätsspital Zürich  ->  ZH
# Division d'Oncologie Département de Médecine Interne Hôpital Universitaires de Genève  ->  GE
# Zahnmedizinische Kliniken Universität Bern  ->  BE
# Génie biochimique IGE EPFL Ecublens  ->  VD
# Lindenhofspital Bern  ->  BE
# Dept. de Microbiologie & Médecin Moléculaire CMU Université de Genève  ->  GE
# Institut für Parasitologie Universität Bern  ->  BE
# Institut für chirurgische Technologien und Biomechanik (ISTB) Universität Bern  ->  BE
# Laboratoire de Biochimie Institut de Botanique Université de Neuchâtel  ->  NE
# Universitätsspital Basel  ->  BS
# Sozialpsychiatrische Dienste Universitätsklinik Zürich  ->  ZH
# Medizinische Poliklinik Departement Innere Medizin Universitätsspital Zürich  ->  ZH
# Département d'anthropologie et d'écologie Faculté des sciences Université de Genève  ->  GE
# Augenklinik Universitätsspital Basel  ->  BS
# Klinik für Orthopädische Chirurgie Inselspital Universität Bern  ->  BE
# Klinik für Klinische Pharmakologie und Toxikologie Universitätsspital Zürich  ->  ZH
# Abteilung Neurobiologie Departement Forschung Universitätsspital Basel  ->  BS
# Département de Biologie Végétale Faculté des Sciences Université de Genève  ->  GE
# Institut für Integrative Biologie (IBZ) Departement Umweltwissenschaften ETH Zürich  ->  ZH
# Groupe de Pharmacologie Section de Pharmacie Université de Lausanne  ->  VD
# Kantonsspital Basel Departement Medizinische Radiologie  ->  BS
# Institut für medizinische Lehre Medizinische Fakultät Universität Bern  ->  BE
# Kantonsspital Aarau Kinderklinik  ->  AG
# Hôpitaux universitaires de Genève (HUG) Secrétariat général  ->  GE
# Kinderspital Basel Traumatologische Abteilung  ->  BS
# Departement Innere Medizin Universitätsspital Zürich  ->  ZH
# Zytogenetisches Diagnostik-& Forschungslabor Institut für Medizinische Genetik der Universität Zürich  ->  ZH
# Département de Psychiatrie Unité de Psychopharmacologie Clinique Hôpitaux Universitaires de Genève  ->  GE
# Institut de Microbiologie Université de Lausanne  ->  VD
# Departement Frauenheilkunde Universitätsspital Zürich  ->  ZH
# Klinik für Kardiologie Departement Innere Medizin Universitätsspital Zürich  ->  ZH
# Departement Medizinische Radiologie MR-Zentrum Universitätsspital Zürich  ->  ZH
# Département de Radiologie Clinique de psychiatrie infantile Hôpitaux Universitaires de Genève  ->  GE
# Institut Universitaire de Médecine Légale Université de Lausanne  ->  VD
# Service d'Oto-rhino-laryngologie et de chirurgie cervico-faciale Hôpitaux Universitaires de Genève  ->  GE
# Div. de Gastroentérologie et Hépatologie Département de Médecine Interne Hôpitaux Universitaires de Genève  ->  GE
# Sozialmedizinische Beratungsstelle für Jugendliche Integrative Psych. Winterthur  ->  ZH
# Kinderspital Luzern Pädiatrische Klinik  ->  LU
# Abteilung für Pneumologie Medizinische Universitätsklinik A Universitätsspital Basel  ->  BS
# Département de Psychiatrie Hôpitaux Universitaires de Genève HUG  ->  GE
# Institut für Sportwissenschaft Universität Bern  ->  BE
# Institut für Veterinärbakteriologie Universität Zürich  ->  ZH
# Division de Pneumologie Département de Médecine Interne Hôpitaux Universitaires de Genève  ->  GE
# Laboratoire d'écologie végétale Institut de botanique Université de Neuchâtel  ->  NE
# Gastroenterologie-Zentrum Hirslanden Zürich  ->  ZH
# Abteilung Kardiologie Medizinische Klinik Kantonsspital Luzern  ->  LU
# Institut für Genetik Veterinär-medizinische Fakultät Universität Bern  ->  BE
# Service Universitaire de Psycho- gériatrie de Lausanne Hôpital de Prilly  ->  VD
# Service Universitaire de Psycho- gériatrie de Lausanne Hôpital de Prilly  ->  VD
# Klinik für kleine Haustiere Universität Bern  ->  BE
# Klinische Psychologie und Psychotherapie Psychologisches Institut Universität Zürich  ->  ZH
# Abteilung für Onkologie Medizinische Universitätsklinik B Universitätsspital Basel  ->  BS
# Wasser- und Energiewirtschaftsamt des Kantons Bern  ->  BE
# Inst. de travaux hydrauliques (ITH) Département de Génie civil EPF - Ecublens  ->  VD
# Hôpital de Sion Service de Pédiatrie  ->  VS
# Psychologisches Institut Universität Zürich Klinische Psychologie  ->  ZH
# Institut für Verkehrsplanung und Transportsysteme ETH Zürich  ->  ZH
# BAK Konjunkturforschung Basel AG  ->  BS
# Oberforstamt des Kantons Zürich Abteilung Wald  ->  ZH
# Institut für Baustatik und Konstruktion IBK ETH Zürich  ->  ZH
# Institut für Politikwissenschaft Universität Bern  ->  BE
# Staatsarchiv des Kantons Bern  ->  BE
# Abteilung für Angewandte Mikroökonomie Universität Bern  ->  BE
# Laboratoire de Physiologie Végétale Laboratoire de Physiologie végé- Université de Genève  ->  GE
# Institut für Sprachwissenschaft Universität Bern  ->  BE
# Institut für Integrierte Systeme ETH Zürich  ->  ZH
# Seminar für Zeitgeschichte Universität Freiburg  ->  FR
# UNI: Archive in Freiburg   München D  ->  FR
# UNI: Zürich CH  ->  ZH
# UNI: Genf Bern  Basel CH  ->  GE
# UNI: Genf Bern  Basel CH  ->  BE
# UNI: Genf Bern  Basel CH  ->  BS
# UNI: Universität Basel Zoologisches Institut Basel CH  ->  BS
# UNI: Universität Basel Zoologisches Institut Basel CH  ->  BS
# UNI: Institut des Dicziunari Rumant   Chur C H  ->  GR
# UNI: Schüpfheim of British Columbia   Ruswil und Luzern CH  ->  LU
# UNI: Université de Genève Dépt. d'Economie P olitiqueue et de chimi  Genève GB  ->  GE
# UNI: Université de Genève Dépt. d'Economie P olitiqueue et de chimi  Genève GB  ->  GE
# UNI: Albert-Ludwigs-Universität Mathematisch es Institut  Freiburg i. Br. D  ->  FR
# UNI: Bern   Bern CH  ->  BE
# UNI: Bern   Bern CH  ->  BE
# UNI: Université de Genève    CH  ->  GE
# UNI: Theologische Fakultät   Luzern CH  ->  LU
# UNI: Luzern CH  ->  LU
# Institut für Computersysteme ETH Zürich  ->  ZH
# Staatsarchiv des Kantons Luzern  ->  LU
# Département de littérature comparée Faculté des lettres Université de Genève  ->  GE
# Departement für internationales Recht und Handelsrecht Universität Freiburg  ->  FR
# Abteilung für Krebsforschung Departement für Pathologie Universität Zürich  ->  ZH
# Zahnärztliches Institut Universität Basel  ->  BS
# Abteilung Experimentelle Klinische Forschung Vetsuisse-Fakultät Universität Bern  ->  BE
# UNI: Interzeag Medical Technology  Schlieren CH  ->  ZH
# Seminar für Kulturwissenschaft und Europäische Ethnologie Universität Basel  ->  BS
# UNI: Universität Basel Biozentrum  Basel CH  ->  BS
# UNI: Universität Basel Biozentrum  Basel CH  ->  BS
# UNI: ETH-Hönggerberg Institut für Biophysik Zürich CH  ->  ZH
# UNI: Friedrich-Miescher Institut   Basel CH  ->  BS
# UNI: ETH-Zürich Laboratorium für organische Chemie  Zürich CH  ->  ZH
# UNI: Basel Mission Archiv  Basel CH  ->  BS
# UNI: Basel Mission Archiv  Basel CH  ->  BS
# UNI: Friedrich Miescher-Institut  Basel CH  ->  BS
# UNI: Kantonsspital Basel Abt. Neurobiologie Basel CH  ->  BS
# UNI: Kantonsspital Basel Abt. Neurobiologie Basel CH  ->  BS
# UNI: Universitätsspital Zürich Departement f ür Frauenheilkunde Klinik und Poliklinik für Geburtshilfe Zürich CH  ->  ZH
# UNI: Universitätsspital Zürich Departement f ür Frauenheilkunde Klinik und Poliklinik für Geburtshilfe Zürich CH  ->  ZH
# UNI: Universität Zürich Physiologisches Inst itut  Zürich CH  ->  ZH
# UNI: Universität Zürich Physiologisches Inst itut  Zürich CH  ->  ZH
# UNI: Friedrich Miescher-Institut   Basel CH  ->  BS
# UNI: Universität Freiburg Physikalisches-che misches Institut  Freiburg CH  ->  FR
# UNI: Universität Freiburg Physikalisches-che misches Institut  Freiburg CH  ->  FR
# UNI: ETH-Zürich   Zürich CH  ->  ZH
# UNI: ETH-Zürich Lab. für Physikalische Chemi e  Zürich CH  ->  ZH
# UNI: ETH-Zürich Lab. für Organische Chemie Zürich CH  ->  ZH
# UNI: ETH-Zürich Lab. für Organische Chemie E TH-Zentrum Zürich CH  ->  ZH
# UNI: Universität Zürich Zoologisches Institu t  Zürich CH  ->  ZH
# UNI: Universität Zürich Zoologisches Institu t  Zürich CH  ->  ZH
# UNI: Universität Bern   Bern CH  ->  BE
# UNI: Universität Bern   Bern CH  ->  BE
# UNI: Universität Basel Institut für Rechtswi ssenschaft  Basel CH  ->  BS
# UNI: Universität Basel Institut für Rechtswi ssenschaft  Basel CH  ->  BS
# UNI: Chur CH  ->  GR
# ...
# Institut für Öffentliches Recht Rechtswissenschaftliche Fakultät Albert-Ludwigs-Universität Freiburg  ->  FR
# Dekanat Philosophische Fakultät Universität Zürich  ->  ZH
# Unité de Japonais Faculté des lettres Université de Genève  ->  GE
# Zentrum für Gender Research u. Früherkennung Universitäre Psychiatrische Kliniken Basel Universitätsspital Basel  ->  BS
# Zentrum für Gender Research u. Früherkennung Universitäre Psychiatrische Kliniken Basel Universitätsspital Basel  ->  BS
# Département de Microbiologie Fondamentale Biophore Université de Lausanne  ->  VD
# Numerische Vorhersagen Analyse und Prognose - Zürich MeteoSchweiz  ->  ZH
# Institut für Pflanzenwissenschaften Departement Biologie ETH Zürich  ->  ZH
# Geneva Centre for the Democratic Control of Armed Forces (DCAF)  ->  GE
# NCCR Iconic Criticism eikones Universität Basel  ->  BS
# Pädagogische Hochschule Zug  ->  ZG
# Schweiz. Institut für Entrepreneurship SIFE Hochschule für Technik und Wirtschaft HTW Chur  ->  GR
# Chair of Architecture and Urban Design D-ARCH ETH Zurich  ->  ZH
# Fachbereich Medien- und Kommunikationswissenschaften Universität Freiburg  ->  FR
# Klinik für Kleintiermedizin Vetsuisse-Fakultät der Universität Zürich  ->  ZH
# Département de génétique médicale Université de Lausanne  ->  VD
# CRAFT FAPSE Université de Genève  ->  GE
# Center for Law and Economics DGESS ETH Zürich  ->  ZH
# IPMZ – Institut für Publizistikwissenschaft und Medienforschung Universität Zürich  ->  ZH
# Abteilung Qualitätsmanagement und Patientensicherheit USZ UniversitätsSpital Zürich  ->  ZH
# Section de Philosophie Université de Lausanne BFSH 2  ->  VD
# Politikwissenschaftliches Seminar der Universität Luzern  ->  LU
# Département de Biologie moléculaire Université de Genève Sciences III  ->  GE
# Plastizitäts- und Lernforschung Psychologisches Institut Universität Zürich  ->  ZH
# Centre de recherches en environnement terrestre (CRET) Université de Lausanne  ->  VD
# Fachbereich Pädagogische Psychologie Pädagogische Hochschule Zürich  ->  ZH
# Kompetenzzentrum für Public Management  Universität Bern  ->  BE
# Unité des études chinoises Faculté des Lettres Université de Genève  ->  GE
# Kantonsspital Aarau Neurologische Klinik  ->  AG
# Institut für Medizinische Mikrobiologie Zentrum für Mykobakteriologie Universität Zürich  ->  ZH
# Institut für Biomedizinische Technik Universität Zürich und ETH Zürich  ->  ZH
# Institut für Biomedizinische Technik Universität Zürich und ETH Zürich  ->  ZH
# Universität Bern Bibliothek Exakte Wissenschaften  ->  BE
# Laboratoire Sol & Végétation Institut de Biologie Université de Neuchâtel  ->  NE
# Université de Lausanne Institut des Sciences du Sport (ISSUL)  ->  VD
# Ökonomisches Seminar Universität Luzern  ->  LU
# Institut Tourismuswirtschaft (ITW) Hochschule Luzern  ->  LU
# English Department University of Zurich  ->  ZH
# Geschichte der modernen Welt ETH Zürich  ->  ZH
# Faculté des géosciences et de l'environnement Université de Lausanne  ->  VD
# Energy Science Center (ESC)  ETH Zürich  ->  ZH
# Economie et politique de l'énergie Institut des sciences de l'environnement Université de Genève  ->  GE
# Institut für Nachhaltige Entwicklung Zürcher Hochschule Winterthur ZHAW  ->  ZH
# Forschungsstelle Energienetze ETH Zürich  ->  ZH
# Departement für Hochspannungstechnologie D-ITET ETH Zurich  ->  ZH
# Departement für Maschinenbau und Verfahrenstechnik ETH Zürich  ->  ZH
# Institute for Environmental Decisions Natural and Social Science Interface ETH Zürich  ->  ZH
# Professur Bauphysik Institut für Technologie in der Architektur ETH Zürich  ->  ZH
# Zentum für wirtschaftspolitische Forschung HTW Chur  ->  GR
# Systematische Theologie/Ethik Universität Basel  ->  BS
# Archäologischer Dienst Kanton Bern  ->  BE
# Institut für Lehren und Lernen Pädagogische Hochschule Zentralschweiz Hochschule Luzern  ->  LU
# Institut universitaire en finance - GFRI Université de Genève  ->  GE
# Swisspeace - Schweizerische Friedenstiftung Universität Basel  ->  BS
# Domaine Sciences des sociétés des cultures Département des Sciences sociales Université de Fribourg  ->  FR
# Linguistique française Sciences du langage et de la communication Université de Neuchâtel  ->  NE
# Gerontechnology and Rehabilitation Group ARTORG Center Universität Bern  ->  BE
# Department of Economics Universität Zürich  ->  ZH
# Fondation Guy de Pourtalès Université de Lausanne  ->  VD
# Departement für Kunstwissenschaften Institut für Kunstgeschichte Universität Bern  ->  BE
# Institut für Psychologie Universität Freiburg  ->  FR
# Insitut fuer Biochemie ETH Zurich  ->  ZH
# Biozentrum Universität Basel  ->  BS
# Abteilung für Infektionskrankheiten Medizinische Poliklinik Universitätsspital Zürich  ->  ZH
# Ecole Polytechnique Fédérale de Lausanne  ->  VD
# Neurochirurgische Klinik Kantonsspital Luzern  ->  LU
# Labor für Energiestoffwechsel D-HEST ETH Zürich  ->  ZH
# Chaire Médecine et société Faculté des sciences Université de Fribourg  ->  FR
# Département de Psychologie Université de Genève  ->  GE
# Institut für Evolutionäre Medizin IEM Medizinische Fakultät Universität Zürich  ->  ZH
# Institut für Judaistik Theologische Fakultät Universität Bern  ->  BE
# Inselspital Bern Diagnostische, Interventionelle und Pädiatrische Radiologie  ->  BE
# Applied and Environmental Geophysics Group CRET University of Lausanne  ->  VD
# Rehabilitationszentrum für Kinder Kinderspital Zürich Universität Zürich  ->  ZH
# Rehabilitationszentrum für Kinder Kinderspital Zürich Universität Zürich  ->  ZH
# Institut für Historische Theologie Universität Bern  ->  BE
# Abteilung Schul- und Unterrichtsforschung Institut für Erziehungswissenschaft Universität Bern  ->  BE
# Arbeitsgruppe Human Genomics Department Biomedizin Universität Basel  ->  BS
# Service des Spécialités Psychiatriques Département de Santé Mentale et Psychiatrie Hôpitaux Universitaires de Genève  ->  GE
# Angewandte Mechanobiologie Gesundheitswissenschaften und Technologie ETH Zürich  ->  ZH
# Faculté des Hautes Etudes Commerciales Université de Lausanne  ->  VD
# Dept. of Biosystems Science and Engineering ETH Zürich  ->  ZH
# Département d'anglais et slavistique Langues et Littératures slaves Université de Fribourg  ->  FR
# Theologische Fakultät Universität Freiburg  ->  FR
# Burgerbibliothek Bern  ->  BE
# Sciences du langage et de l'information Faculté des lettres Université de Lausanne  ->  VD
# Seminar für Griechische und Lateinische Philologie Universität Zürich  ->  ZH
# Center for Integrative Genomics Génopode Building University of Lausanne  ->  VD
# Euresearch Genève Université de Genève  ->  GE
# Euresearch Genève Université de Genève  ->  GE
# Institut de Philosophie Faculté des Lettres et Sciences Humaines Université de Neuchâtel  ->  NE
# Département multilingue de traduction Ecole de traduction et d'interprétation Université de Genève  ->  GE
# ETH Zurich NCCR MUST  ->  ZH
# Asien-Orient-Institut Universität Zürich  ->  ZH
# Hochschule für Technik und Wirtschaft HTW Chur Schweiz. Institut für Infowissenschaft SII  ->  GR
# Christkatholisch-theologische Fakultät Universität Bern  ->  BE
# Institut d'Archéologie Université de Neuchâtel  ->  NE
# Institut für Kommunikation und Marketing Hochschule Luzern - Wirtschaft Fachhochschule Zentralschweiz  ->  LU
# Center for Global Studies Philosophisch-historische Fakultät Universität Bern  ->  BE
# Institut Sozialmanagement und Sozialpolitik Hochschule Luzern - Soziale Arbeit  ->  LU
# Laboratory of Cognitive Neuroscience (LNCO) Brain-Mind Institute Ecole Polytechnique Fédérale de Lausanne (EP  ->  VD
# Institut des Sciences de l'Antiquité  Université de Fribourg  ->  FR
# Historisches Seminar Universität Basel  ->  BS
# Unité d'Égyptologie et Copte Département des Sciences de l'Antiquité Université de Genève  ->  GE
# Chair of Cognitive Science D-GESS ETH Zurich  ->  ZH
# Faculté d'économie et de management Université de Genève  ->  GE
# Professur für Material-Engineering ETH Zürich  ->  ZH
# Hydrology and Climate Unit Department of Geography University of Zurich  ->  ZH
# Institut für Schule und Heterogenität Pädagogische Hochschule Luzern  ->  LU
# Lehrstuhl für Internationales Management Institut für Betriebswirtschaftslehre Universität Zürich  ->  ZH
# Chair of Entrepreneurial Risks D-MTEC ETH Zürich  ->  ZH
# Lab. de chimie analytique pharmaceutique (LCAP) Université de Genève  ->  GE
# SIK-ISEA Antenne romande Université de Lausanne  ->  VD
# Universitätsspital Zürich Hämatologie  ->  ZH
# Department of Business Law School of Management and Law Zurich University of Applied Sciences (ZHAW)  ->  ZH
# Inselspital Bern Neurochirurgie  ->  BE
# FSP Materialität in Kunst und Kultur HKB Forschung Hochschule der Künste Bern  ->  BE
# Laboratoire d'Anthropologie (AGP) Département d'Anthropologie et d'Ecologie Université de Genève  ->  GE
# Tierphysiologie Institut für Agrarwissenschaften ETH Zürich  ->  ZH
# ETH Zürich Knorpeltechnologie und -regeneration  ->  ZH
# Institut für komplementäre und integrative Medizin Universitätsspital Zürich  ->  ZH
# Ecole Polytechnique Federale de Lausanne EPFL  ->  VD
# Interdisziplinäre Notfallstation Innere Medizin Universitätsspital Basel  ->  BS
# Abteilung Geowissenschaften Naturhistorisches Museum Basel  ->  BS
# Behandlungszentrum Bewegungsapparat Orthopädische Chirurgie Unispital Basel  ->  BS
# Service des Maladies Osseuses Département des spécialités de médecine Hôpital Universitaire de Genève  ->  GE
# Institut Forel et Institut des Sciences de l'Environnement (ISE) Université de Genève  ->  GE
# Laboratoire de recherche Département de chirurgie et anesthésiologie Université de Lausanne  ->  VD
# Dep. Medien- & Kommunikationswissenschaft Universität Freiburg  ->  FR
# Departement Biologie Grundlagenforschung ETH Zurich  ->  ZH
# Institut für Robotik und Intelligente Systeme (IRIS) ETH Zürich  ->  ZH
# Département de l'Imagerie et Sciences de l'Information Médicale Hôpitaux Universitaires de Genève  ->  GE
# Hôpitaux Universitaires de Genève Division of Tropical and Humanitarian Medicine  ->  GE
# Chair of Photogrammetry and Remote Sensing Institute of Geodesy and Photogrammetry ETH Zurich  ->  ZH
# Transdisciplinarity Lab - USYS TdLab Departement Umweltsystemwissenschaften ETH Zürich  ->  ZH
# PRN LIVES Université de Lausanne  ->  VD
# Idiap Research Institute Martigny  ->  VS
# Abteilung II Institut für Sportwissenschaft Universität Bern  ->  BE
# Allgemeine Sprachwissenschaft Universität Basel  ->  BS
# Group Pinschewer Departement Biomedizin Universität Basel  ->  BS
# Language Technology Laboratory Department of Linguistics University of Geneva  ->  GE
# Institute of Science, Technology & Policy ETH Zürich  ->  ZH
# Institut d'économie et d'économétrie (IEE) Faculté des sciences économiques et sociales Université de Genève  ->  GE
# Center for Molecular Cardiology Universität Zürich  ->  ZH
# Kompetenzzentrum Kulturelle Topographien Universität Basel  ->  BS
# Institut d'histoire économique Paul Bairoch Faculté des sciences économiques et sociales Université de Genève  ->  GE
# Sozialpsychologie Universität Zürich  ->  ZH
# Jurassica Museum Service sc. auxiliaire en géosciences Antenne universitaire de l'univ. de Fribourg  ->  FR
# Departement Gesellschaftswissenschaften Universität Basel  ->  BS
# Romanistisches Institut Rechtswissenschaftliche Fakultät Universität Bern  ->  BE
# Universität Basel Institut für Rechtswissenschaft  ->  BS
# Section de Psychologie / FAPSE Université de Genève  ->  GE
# Interactive Geometry Lab ETH Zürich  ->  ZH
# Departement für Volkswirtschaftslehre Universität Fribourg  ->  FR
# Professur für Magnetismus und Grenzflächenphysik ETH Zürich  ->  ZH
# Abteilung für Zoo- und Heimtiere Veterinär-medizinische Fakultät Universität Zürich  ->  ZH
# Departement Architektur DARCH ETH Zürich  ->  ZH
# Molekular und Mikrobiologie Departement Medizin Université de Fribourg  ->  FR
# Neurocenter-Abt exp. Klinische Forschung Vetsuisse Universität Bern  ->  BE
# Haute école de travail social de Genève HETS-IES  ->  GE
# Faculté des sciences Université de Neuchâtel  ->  NE
# Institut für Biomechanik D-HEST ETH Zürich  ->  ZH
# Institut für Psychologie Universität Bern  ->  BE
# Centre Walras-Pareto IEPHI / SSP Université de Lausanne  ->  VD
# Département de psychiatrie Faculté de médecine Université de Genève  ->  GE
# Institut für Nuklearmedizin Universitätsspital Zürich  ->  ZH
# Zentrum für Weltraumforschung und Habitabilität Universität Bern  ->  BE
# Labor zur Erforschung Sozialer und Neuronaler Systeme (SNS Lab) UniversitätsSpital Zürich  ->  ZH
# Zentrum für Religion, Wirtschaft und Politik Theologische Fakultät Universität Basel  ->  BS
# Schweizer Zentrum für Islam und Gesellschaft  Universität Freiburg  ->  FR
# Geneva Academy of International Humanitarian Law and Human Rights  ->  GE
# Institut für Bewegungswissenschaften und Sport - D-HEST ETH Zürich  ->  ZH
# UFSP Dynamik Gesunden Alterns Universität Zürich  ->  ZH
# Laboratoire d'immunologie des tumeurs Service d'oncologie, Dpt de médecine interne Université de Genève  ->  GE
# Arbeits- und Organisationspsychologie D-MTEC ETH Zürich  ->  ZH
# Laboratoire d'Anthropologie Culturelle et Sociale (LACS) Université de Lausanne  ->  VD
# Bündner Kunstmuseum Chur  ->  GR
# Albert-Ludwigs-Universität Freiburg Institut für neuere deutsche Literatur  ->  FR
# Institute for Environmental Social Sciences and Geography Albert-Ludwig University of Freiburg  ->  FR
# Ecole des sciences criminelles Faculté de droit et des sciences criminelles Université de Lausanne  ->  VD
# Internationale Konfliktforschung ETH Zürich  ->  ZH
# Abteilung Prähistorische Archäologie Institut für Archäologische Wissenschaften Universität Bern  ->  BE
# Departement Mathematik und Informatik Universität Basel  ->  BS
# Professur für Philosophie ETH Zürich  ->  ZH
# Histoire Moderne Faculté des Lettres Université de Fribourg  ->  FR
# Professur für Photonik ETH Zürich  ->  ZH
# Religionswissenschaft Universität Basel  ->  BS
# Klinik für Kardiologie und Kardiovaskuläre Physiologie Universitätsspital Zürich  ->  ZH
# Sozialpsychologie und soziale Neurowiss. Institut für Psychologie Universität Bern  ->  BE
# UFSP Asien und Europa Universität Zürich  ->  ZH
# Institut für Sozialanthropologie und Empiris Universität Zürich  ->  ZH
# Faculté des sciences sociales et politiques Décanat Université de Lausanne  ->  VD
# Department of Chemistry A University of Zurich  ->  ZH
# Faculté des lettres Décanat Université de Lausanne  ->  VD
# Zentrum für Geschichtsdidaktik und Erinnerungskulturen Pädagogische Hochschule Luzern  ->  LU
# Institute for Biomedical Ethics University of Basel  ->  BS
# Brain and Sound Lab Departement Biomedizin Universität Basel  ->  BS
# Centre interfacultaire en droits de l'enfant  Université de Genève  ->  GE
# UFSP Sprache und Raum Universität Zürich  ->  ZH
# Istituto di Studi Filosofici Facoltà di Teologia di Lugano  ->  TI
# Professur für Energiepolitik D-GESS ETH Zürich  ->  ZH
# Département de Philosophie  Université de Genève  ->  GE
# Division of Cognitive Neuroscience Institut für Psychologie Universität Basel  ->  BS
# Institut für Tieranatomie Universität Bern  ->  BE
# Departement Geographie, SIE Universität Zürich  ->  ZH
# Institut Religions, Cultures, Modernité FTSR Université de Lausanne  ->  VD
# Université de Genève - GE  ->  GE
# Universität Basel - BS  ->  BS
# Université de Fribourg - FR  ->  FR
# Universität Zürich - ZH  ->  ZH
# Université de Lausanne - LA  ->  VD
# Universität Bern - BE  ->  BE
# Université de Neuchâtel - NE  ->  NE
# ETH Zürich - ETHZ  ->  ZH
# EPF Lausanne - EPFL  ->  VD
# Pädagogische Hochschule Zürich - PHZFH  ->  ZH
# Universität Luzern - LU  ->  LU
# Robert Walser-Stiftung Bern - RWS  ->  BE
# Physikal.-Meteorolog. Observatorium Davos - PMOD  ->  GR
# Pädagogische Hochschule Bern - PHBern  ->  BE
# Hochschule Luzern - HSLU  ->  LU
# Pädagogische Hochschule Luzern - PHLU  ->  LU
# Pädagogische Hochschule Schwyz - PHSZ  ->  SZ
# Schweiz. Hochschule für Logopädie Rorschach - SHLR  ->  SG
# Pädagogische Hochschule Zug - PHZG  ->  ZG
# Instituto Ricerche Solari Locarno - IRSOL  ->  TI
# Pädagogische Hochschule Schaffhausen - PHSH  ->  SH
# Staatsunabh. Theologische Hochschule Basel - STHB  ->  BS
# Facoltà di Teologia di Lugano - FTL  ->  TI

# %%
clean_cantons = has_info.dropna(subset = ['Canton'])
clean_cantons.head(30)
#has_info.describe()
clean_cantons.shape
# Out:
# (43540, 4)

# %%
print("Dropped from has_info", get_dropped_perc(has_info, clean_cantons))
print(clean_cantons.shape)
print(has_info.shape)
# Out:
# Dropped from has_info 30.314815703974006
# (43540, 4)
# (62481, 4)

# %%
clean_cantons['Canton'].unique()
# Out:
# array(['GE', 'BS', 'FR', 'ZH', 'VD', 'BE', 'NE', 'SG', 'LU', 'AI', 'AG',
#        'TI', 'ZG', 'SZ', 'SH', 'GR', 'VS', 'BL', 'SO'], dtype=object)

# %%
grouped_cantons = clean_cantons.groupby('Canton')['Approved Amount'].sum()
#grouped_cantons.first()
grants_cantons = pd.DataFrame(grouped_cantons)
grants_cantons = grants_cantons.reset_index()
grants_cantons.head(26)
# Out:
#    Canton  Approved Amount
# 0      AG     2.924342e+06
# 1      AI     1.400000e+05
# 2      BE     1.567640e+09
# 3      BL     2.195180e+05
# 4      BS     1.375805e+09
# 5      FR     4.615955e+08
# 6      GE     1.863555e+09
# 7      GR     1.277846e+07
# 8      LU     5.471542e+07
# 9      NE     3.863420e+08
# 10     SG     7.431340e+05
# 11     SH     9.415650e+05
# 12     SO     1.156941e+06
# 13     SZ     1.074747e+06
# 14     TI     3.369681e+06
# 15     VD     2.400857e+09
# 16     VS     7.535870e+05
# 17     ZG     8.689150e+05
# 18     ZH     3.504244e+09

# %%
# Load data for swiss towns
columns = ['Name', 'Canton']
swiss_cantons = pd.read_csv("swiss_cantons.csv", delimiter='\t', usecols=columns, na_values=['Not there', 'nan'])
swiss_cantons.set_index('Canton', inplace=True)
swiss_cantons = swiss_cantons.reset_index()
swiss_cantons.head(26)
# Out:
#    Canton                    Name
# 0      ZH                  Zürich
# 1      BE                    Bern
# 2      LU                  Luzern
# 3      UR                     Uri
# 4      SZ                  Schwyz
# 5      OW                Obwalden
# 6      NW               Nidwalden
# 7      GL                  Glarus
# 8      ZG                     Zug
# 9      FR                Fribourg
# 10     SO               Solothurn
# 11     BS              Basel-City
# 12     BL           Basel-Country
# 13     SH            Schaffhausen
# 14     AR  Appenzell Ausserrhoden
# 15     AI   Appenzell Innerrhoden
# 16     SG              St. Gallen
# 17     GR              Graubünden
# 18     AG                  Aargau
# 19     TG                 Thurgau
# 20     TI                  Ticino
# 21     VD                    Vaud
# 22     VS                  Valais
# 23     NE               Neuchâtel
# 24     GE                  Geneva
# 25     JU                    Jura

# %%
grants_cantons = swiss_cantons.merge(grants_cantons, how='left')
grants_cantons.head(26)
# Out:
#    Canton                    Name  Approved Amount
# 0      ZH                  Zürich     3.504244e+09
# 1      BE                    Bern     1.567640e+09
# 2      LU                  Luzern     5.471542e+07
# 3      UR                     Uri              NaN
# 4      SZ                  Schwyz     1.074747e+06
# 5      OW                Obwalden              NaN
# 6      NW               Nidwalden              NaN
# 7      GL                  Glarus              NaN
# 8      ZG                     Zug     8.689150e+05
# 9      FR                Fribourg     4.615955e+08
# 10     SO               Solothurn     1.156941e+06
# 11     BS              Basel-City     1.375805e+09
# 12     BL           Basel-Country     2.195180e+05
# 13     SH            Schaffhausen     9.415650e+05
# 14     AR  Appenzell Ausserrhoden              NaN
# 15     AI   Appenzell Innerrhoden     1.400000e+05
# 16     SG              St. Gallen     7.431340e+05
# 17     GR              Graubünden     1.277846e+07
# 18     AG                  Aargau     2.924342e+06
# 19     TG                 Thurgau              NaN
# 20     TI                  Ticino     3.369681e+06
# 21     VD                    Vaud     2.400857e+09
# 22     VS                  Valais     7.535870e+05
# 23     NE               Neuchâtel     3.863420e+08
# 24     GE                  Geneva     1.863555e+09
# 25     JU                    Jura              NaN

# %%
grants_cantons.fillna(0, inplace=True)

# %%
grants_cantons_df = grants_cantons.reset_index()

# %%
main_map = folium.Map(location=[46.50,8.20], zoom_start=8)
main_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
#topo_json = pd.read_json('ch-cantons.topojson.json') might not be needed
cantons_topo = 'ch-cantons.topojson.json'

# %%
#TODO cantons columns needed in dataframe

main_map.choropleth(geo_path=cantons_topo, 
                     data=grants_cantons_df,
                     columns=['Canton', 'Approved Amount'],
                     key_on='feature.id',
                     topojson='objects.cantons',
                     fill_color='YlGnBu',
                     legend_name = 'Random numbers'
                    )
main_map
# Out:
# /home/raccct/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:9: FutureWarning: 'threshold_scale' default behavior has changed. Now you get a linear scale between the 'min' and the 'max' of your data. To get former behavior, use folium.utilities.split_six.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
pprint(canton_dict)
# Out:
# ''

# %%
grants_with_has_code = university_grants.join(has_canton_code)
grants_with_has_code.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-ee9451bcced4> in <module>()
# ----> 1 grants_with_has_code = university_grants.join(has_canton_code)
#       2 grants_with_has_code.head()
#
# NameError: name 'university_grants' is not defined

# %%
university_grants.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-70d6e9ca8458> in <module>()
# ----> 1 university_grants.head()
#
# NameError: name 'university_grants' is not defined

# %%
extracts = university_grants['University'].str.extract('(?P<University>.*-)(?P<Code>.*)', expand=True)
has_code = pd.DataFrame( extracts['Code'] )
has_code.Code.apply(is_canton_code)
grouped_has_code = has_code.groupby('Code')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-9ec6ddae102b> in <module>()
# ----> 1 extracts = university_grants['University'].str.extract('(?P<University>.*-)(?P<Code>.*)', expand=True)
#       2 has_code = pd.DataFrame( extracts['Code'] )
#       3 has_code.Code.apply(is_canton_code)
#       4 grouped_has_code = has_code.groupby('Code')
#
# NameError: name 'university_grants' is not defined

# %%
only_institution_data = grants_data[grants_data[['University']].isnull().all(axis=1)].index

# %% [markdown]
# ## TODO:
#
# 1. clean up this mess (:
#
# 1. make one function for mapping a row to a canton
#    Suggested strategy:
#
#    (we can only make 200 req. pr hour to the api, so we should try to keep the number down)
#
#    1. Unique institutions, unique universities
#    2. Lookup institution name, place result in hashmap: institution -> canton
#    3. Parse university. If no canton code is given, lookup. Place result in the hashmap
#    4. In the function, do a query in our hashmap for each column. If conflict, return (?)
#
# 1. apply the function to all rows in the data, add canton as a column
# 1. make a df of Canton, Approved Amount
# 1. Groupby canton, sum approved_amount, add a count column
# 1. Plot the results on the map etc
# 1 Bonus
