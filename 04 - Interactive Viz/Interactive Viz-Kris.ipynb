# %% [markdown]
# # Interactive Visualization

# %%
#WARNING guys! In order to use folium you are gonna need to run
# pip install folium
#in your terminal.
import folium

#Probably gonna use this:
ext
# Normal stack of pandas, numpy, matplotlib and seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# For handeling the web requests
import requests
from collections import defaultdict
from pprint import *

# Statistical test library
import scipy.stats as stats
from helpers import *

# %matplotlib inline

# %% [markdown]
# Folium: https://github.com/python-visualization/folium
#
#  Documentation:
#  1. https://folium.readthedocs.io/en/latest/
#  2. https://media.readthedocs.org/pdf/folium/latest/folium.pdf

# %%
#Folium test
map_osm = folium.Map(location=[46.8076878,7.1004592], zoom_start=10)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# # Data wrangeling

# %% [markdown]
# Data source (P3_GrantExport.csv)
# and description of the columns: http://p3.snf.ch/Pages/DataAndDocumentation.aspx

# %%
# Load the data we need. (Columns: Insti)
columns = ['Institution', 'University','Approved Amount']
p3 = pd.read_csv("P3_GrantExport.csv", delimiter=';', usecols=columns, na_values=['data not included in P3', 'nan'])

# %% [markdown]
# To be able to work with the data, we have to filter out the values where we have enough information.
#
# We start by filtering out the projects where we know at least the University or the institution related to the project

# %%
missing__info = p3[p3[['Institution', 'University']].isnull().all(axis=1)].index
has_info = p3.drop(missing__info, axis=0)

print('Dropped from original:', get_dropped_perc(p3, has_info))
# Out:
# Dropped from original: 2.3261267176288514

# %% [markdown]
# As we can see, this leaves out 2.33% of the original data.

# %%
grant_info = has_info[has_info[['Approved Amount']].isnull().all(axis=1) == False]
grants_data = has_info.loc[grant_info.index]
grants_data.head()
# Out:
#                                          Institution  \
# 0                                                NaN
# 1  Faculté de Psychologie et des Sciences de l'Ed...
# 2  Kommission für das Corpus philosophorum medii ...
# 3  Abt. Handschriften und Alte Drucke Bibliothek ...
# 4                       Schweiz. Thesauruskommission
#
#                                 University  Approved Amount
# 0                     Nicht zuteilbar - NA          11619.0
# 1                Université de Genève - GE          41022.0
# 2  NPO (Biblioth., Museen, Verwalt.) - NPO          79732.0
# 3                   Universität Basel - BS          52627.0
# 4  NPO (Biblioth., Museen, Verwalt.) - NPO         120042.0

# %%
print('Dropped from original:', get_dropped_perc(p3, grants_data))
print('Dropped from last step:', get_dropped_perc(has_info, grants_data))
# Out:
# Dropped from original: 18.340133502165113
# Dropped from last step: 16.395384196795824

# %% [markdown]
# So, for about 16.4% of the data, we don't have any information about the grant given.

# %% [markdown]
# # Get the geo info
#
# From the description of the dataset, we have the folloring description:
# > ### Institution
# > According to the information submitted by the responsible applicant, this is the research institution where the project will largely be carried out. Typically, this is the institution or specific lab where the responsible applicant works. The institution is therefore linked to the application. This field is not structured, but its content is consolidated internally. There is no link in the database to the field University.
#
# > ### University
# > This is the institution where the project will largely be carried out according to the application. Pick list. This field is only filled if the research is carried out at a Swiss institution, otherwise the field remains blank. In the case of mobility fellowships, it is generally left empty.
#
#
# So, we know that for the rows where the university is given, the grant was awarded to a swizz university. However, we do not know much about the cases where we only have the institution information. We descided to look into these cases further.

# %%
has_uni = has_info[has_info['University'].isnull() == False]
has_uni.head()
has_uni.shape
# Out:
# (50988, 3)

# %%
# Out:
# defaultdict(str, {})

# %%
uni_grouped = has_uni.groupby(['University'])
for group in uni_grouped:
    print(group)
# Out:
# ('AO Research Institute - AORI',                                              Institution  \
# 4900                         AO Forschungsinstitut (ARI)
# 5026                         AO Forschungsinstitut (ARI)
# 5103                         AO Forschungsinstitut (ARI)
# 5554                         AO Forschungsinstitut (ARI)
# 5629                         AO Forschungsinstitut (ARI)
# 6777                         AO Forschungsinstitut (ARI)
# 7621                         AO Forschungsinstitut (ARI)
# 13833                        AO Forschungsinstitut (ARI)
# 21745                        AO Forschungsinstitut (ARI)
# 36018                        AO Forschungsinstitut (ARI)
# 39633  Biomaterials & Tissue Engineering Program AO R...
# 39648  Biomaterials & Tissue Engineering Program AO R...
# 47171  Biomaterials & Tissue Engineering Program AO R...
# 48067  Biomaterials & Tissue Engineering Program AO R...
# 54679  Biomaterials & Tissue Engineering Program AO R...
# 57368  Biomaterials & Tissue Engineering Program AO R...
# 59234  Biomaterials & Tissue Engineering Program AO R...
#
#                          University  Approved Amount
# 4900   AO Research Institute - AORI         367063.0
# 5026   AO Research Institute - AORI          72271.0
# 5103   AO Research Institute - AORI         100000.0
# 5554   AO Research Institute - AORI         651159.0
# 5629   AO Research Institute - AORI         105353.0
# 6777   AO Research Institute - AORI         333893.0
# 7621   AO Research Institute - AORI         120375.0
# 13833  AO Research Institute - AORI          42339.0
# 21745  AO Research Institute - AORI         108000.0
# 36018  AO Research Institute - AORI         227000.0
# 39633  AO Research Institute - AORI         197000.0
# 39648  AO Research Institute - AORI         260000.0
# 47171  AO Research Institute - AORI           5000.0
# 48067  AO Research Institute - AORI           5000.0
# 54679  AO Research Institute - AORI         356250.0
# 57368  AO Research Institute - AORI         235000.0
# 59234  AO Research Institute - AORI         249918.0  )
# ('Allergie- und Asthmaforschung - SIAF',                                              Institution  \
# 4961   Schweizerisches Institut für Allergie- und Ast...
# 5335   Schweizerisches Institut für Allergie- und Ast...
# 5726   Schweizerisches Institut für Allergie- und Ast...
# 5862   Schweizerisches Institut für Allergie- und Ast...
# 6162   Schweizerisches Institut für Allergie- und Ast...
# 6442   Schweizerisches Institut für Allergie- und Ast...
# 6586   Schweizerisches Institut für Allergie- und Ast...
# 7186   Schweizerisches Institut für Allergie- und Ast...
# 10862  Schweizerisches Institut für Allergie- und Ast...
# 10994  Schweizerisches Institut für Allergie- und Ast...
# 12504  Schweizerisches Institut für Allergie- und Ast...
# 13182  Schweizerisches Institut für Allergie- und Ast...
# 13347  Schweizerisches Institut für Allergie- und Ast...
# 17022  Schweizerisches Institut für Allergie- und Ast...
# 17067  Schweizerisches Institut für Allergie- und Ast...
# 17229  Schweizerisches Institut für Allergie- und Ast...
# 21674  Schweizerisches Institut für Allergie- und Ast...
# 22330  Schweizerisches Institut für Allergie- und Ast...
# 22383  Schweizerisches Institut für Allergie- und Ast...
# 23456  Schweizerisches Institut für Allergie- und Ast...
# 27563  Schweizerisches Institut für Allergie- und Ast...
# 28755  Schweizerisches Institut für Allergie- und Ast...
# 28880  Schweizerisches Institut für Allergie- und Ast...
# 30995  Schweizerisches Institut für Allergie- und Ast...
# 31060  Schweizerisches Institut für Allergie- und Ast...
# 34084  Schweizerisches Institut für Allergie- und Ast...
# 37306  Schweizerisches Institut für Allergie- und Ast...
# 37320  Imperial College of Science, Technology and Me...
# 37791  Schweizerisches Institut für Allergie- und Ast...
# 38574  Schweizerisches Institut für Allergie- und Ast...
# 40506  Schweizerisches Institut für Allergie- und Ast...
# 44151  Schweizerisches Institut für Allergie- und Ast...
# 45217  Schweizerisches Institut für Allergie- und Ast...
# 45344  Schweizerisches Institut für Allergie- und Ast...
# 45895  Schweizerisches Institut für Allergie- und Ast...
# 47924  Schweizerisches Institut für Allergie- und Ast...
# 49605  Schweizerisches Institut für Allergie- und Ast...
# 50665  Schweizerisches Institut für Allergie- und Ast...
# 51946  Schweizerisches Institut für Allergie- und Ast...
# 53574  Schweizerisches Institut für Allergie- und Ast...
# 56522  Schweizerisches Institut für Allergie- und Ast...
# 57369  Schweizerisches Institut für Allergie- und Ast...
# 59431  Schweizerisches Institut für Allergie- und Ast...
# 60784  Schweizerisches Institut für Allergie- und Ast...
#
#                                  University  Approved Amount
# 4961   Allergie- und Asthmaforschung - SIAF        1161184.0
# 5335   Allergie- und Asthmaforschung - SIAF        1665894.0
# 5726   Allergie- und Asthmaforschung - SIAF         114308.0
# 5862   Allergie- und Asthmaforschung - SIAF        1791129.0
# 6162   Allergie- und Asthmaforschung - SIAF           3000.0
# 6442   Allergie- und Asthmaforschung - SIAF         113442.0
# 6586   Allergie- und Asthmaforschung - SIAF        1080132.0
# 7186   Allergie- und Asthmaforschung - SIAF         131379.0
# 10862  Allergie- und Asthmaforschung - SIAF         249912.0
# 10994  Allergie- und Asthmaforschung - SIAF         170522.0
# 12504  Allergie- und Asthmaforschung - SIAF         350384.0
# 13182  Allergie- und Asthmaforschung - SIAF         212004.0
# 13347  Allergie- und Asthmaforschung - SIAF         212532.0
# 17022  Allergie- und Asthmaforschung - SIAF         210000.0
# 17067  Allergie- und Asthmaforschung - SIAF         450000.0
# 17229  Allergie- und Asthmaforschung - SIAF         330268.0
# 21674  Allergie- und Asthmaforschung - SIAF         500000.0
# 22330  Allergie- und Asthmaforschung - SIAF         297000.0
# 22383  Allergie- und Asthmaforschung - SIAF         189000.0
# 23456  Allergie- und Asthmaforschung - SIAF         550000.0
# 27563  Allergie- und Asthmaforschung - SIAF         850173.0
# 28755  Allergie- und Asthmaforschung - SIAF        1007375.0
# 28880  Allergie- und Asthmaforschung - SIAF         296000.0
# 30995  Allergie- und Asthmaforschung - SIAF         244212.0
# 31060  Allergie- und Asthmaforschung - SIAF         107960.0
# 34084  Allergie- und Asthmaforschung - SIAF         335000.0
# 37306  Allergie- und Asthmaforschung - SIAF         296000.0
# 37320  Allergie- und Asthmaforschung - SIAF         377000.0
# 37791  Allergie- und Asthmaforschung - SIAF          95972.0
# 38574  Allergie- und Asthmaforschung - SIAF         425000.0
# 40506  Allergie- und Asthmaforschung - SIAF         377000.0
# 44151  Allergie- und Asthmaforschung - SIAF         375000.0
# 45217  Allergie- und Asthmaforschung - SIAF         331000.0
# 45344  Allergie- und Asthmaforschung - SIAF         375000.0
# 45895  Allergie- und Asthmaforschung - SIAF         119500.0
# 47924  Allergie- und Asthmaforschung - SIAF         537000.0
# 49605  Allergie- und Asthmaforschung - SIAF         300000.0
# 50665  Allergie- und Asthmaforschung - SIAF         269110.0
# 51946  Allergie- und Asthmaforschung - SIAF         337000.0
# 53574  Allergie- und Asthmaforschung - SIAF         471500.0
# 56522  Allergie- und Asthmaforschung - SIAF         219000.0
# 57369  Allergie- und Asthmaforschung - SIAF         362875.0
# 59431  Allergie- und Asthmaforschung - SIAF         679198.0
# 60784  Allergie- und Asthmaforschung - SIAF         600000.0  )
# ('Berner Fachhochschule - BFH',                                              Institution  \
# 2471                            Ingenieurschule Burgdorf
# 15241  Berner Fachhochschule Hochschule für Technik u...
# 27711  Inst. für Sozialplan. und Soz.managem. (ISS) H...
# 28820    Hochschule der Künste HKB Berner Fachhochschule
# 29133  Inst. für Sozialplan. und Soz.managem. (ISS) H...
# 29207  Hochschule für Gestaltung, Kunst und Konservie...
# 29219  Hochschule für Gestaltung, Kunst und Konservie...
# 29230    Hochschule der Künste HKB Berner Fachhochschule
# 31465  Inst. für Sozialplan. und Soz.managem. (ISS) H...
# 31606    Hochschule der Künste HKB Berner Fachhochschule
# 35153  Institut für Transdisziplinarität Hochschule d...
# 35209  Inst. für Sozialplan. und Soz.managem. (ISS) H...
# 36070  Inst. für Sozialplan. und Soz.managem. (ISS) H...
# 36108    Architektur, Holz und Bau Berner Fachhochschule
# 36457  Hochschule für Agrar-, Forst- und Lebensmittel...
# 37305  Konservierung und Restaurierung Hochschule der...
# 37394    Hochschule der Künste HKB Berner Fachhochschule
# 38328  Institut für Transdisziplinarität Hochschule d...
# 38330   Hochschule der Künste Bern Berner Fachhochschule
# 39231  Hochschule für Gestaltung, Kunst und Konservie...
# 39267  Forschungsschwerpunkt Kommunikationsdesign Y (...
# 39312    Hochschule der Künste HKB Berner Fachhochschule
# 39349  Konservierung und Restaurierung Hochschule der...
# 41659    Hochschule der Künste HKB Berner Fachhochschule
# 42636  Hochschule für Gestaltung, Kunst und Konservie...
# 42749    Berner Fachhochschule Architektur, Holz und Bau
# 43190  Institut für Transdisziplinarität Hochschule d...
# 43425    Hochschule der Künste HKB Berner Fachhochschule
# 43507  Institut für Transdisziplinarität Hochschule d...
# 43778  FSP Kommunikationsdesign Hochschule der Künste...
# ...                                                  ...
# 58222                                 HAFL Agronomie BFH
# 58827  Fachstelle Forschung Hochschule der Künste Ber...
# 59076  Konservierung und Restaurierung Hochschule der...
# 59127  FSP Kommunikationsdesign Hochschule der Künste...
# 59209  Forschungsschwerpunkt Interpretation Hochschul...
# 59354  Fachbereich Sportpsychologie Leistungssport Ei...
# 59368  Hochschule für Agrar-, Forst- und Lebensmittel...
# 59931  Hochschule für Musik und Theater Hochschule de...
# 60495  Forschungsschwerpunkt Interpretation Hochschul...
# 60635  Wirtschaft Gesundheit und Soziales Berner Fach...
# 60676  FSP Materialität in Kunst und Kultur HKB Forsc...
# 60737  Forschungsschwerpunkt Interpretation Hochschul...
# 61167  Forschungsschwerpunkt Interpretation Hochschul...
# 61168  Forschungsschwerpunkt Interpretation Hochschul...
# 61272  Forschungsschwerpunkt Kommunikationsdesign Y (...
# 61275                                             PHBern
# 61371   Hochschule der Künste Bern Berner Fachhochschule
# 61556  Fachstelle Forschung Hochschule der Künste Ber...
# 62067  Forschungsschwerpunkt Interpretation Hochschul...
# 62115  Forschungsschwerpunkt Interpretation Hochschul...
# 62168  Institut Y Hochschule der Künste Bern Berner F...
# 62177   Hochschule der Künste Bern Berner Fachhochschule
# 62212               Institut Alter Berner Fachhochschule
# 62388                                  transcript Verlag
# 62416  Verlag Peter Lang AG Europäischer Verlag der W...
# 62735  Forschungsschwerpunkt Interpretation Hochschul...
# 62824  Wirtschaft Gesundheit und Soziales Berner Fach...
# 63305       Berner Fachhochschule Technik und Informatik
# 63366  Fachstelle Forschung Hochschule der Künste Ber...
# 63616  Fachstelle Forschung Hochschule der Künste Ber...
#
#                         University  Approved Amount
# 2471   Berner Fachhochschule - BFH           6000.0
# 15241  Berner Fachhochschule - BFH         364680.0
# 27711  Berner Fachhochschule - BFH         330678.0
# 28820  Berner Fachhochschule - BFH          15000.0
# 29133  Berner Fachhochschule - BFH          34675.0
# 29207  Berner Fachhochschule - BFH          17500.0
# 29219  Berner Fachhochschule - BFH          12562.0
# 29230  Berner Fachhochschule - BFH          24000.0
# 31465  Berner Fachhochschule - BFH          19213.0
# 31606  Berner Fachhochschule - BFH          12500.0
# 35153  Berner Fachhochschule - BFH         110728.0
# 35209  Berner Fachhochschule - BFH         200000.0
# 36070  Berner Fachhochschule - BFH         150996.0
# 36108  Berner Fachhochschule - BFH         393000.0
# 36457  Berner Fachhochschule - BFH          71945.0
# 37305  Berner Fachhochschule - BFH          42840.0
# 37394  Berner Fachhochschule - BFH         103356.0
# 38328  Berner Fachhochschule - BFH         111673.0
# 38330  Berner Fachhochschule - BFH         118182.0
# 39231  Berner Fachhochschule - BFH          72704.0
# 39267  Berner Fachhochschule - BFH         116841.0
# 39312  Berner Fachhochschule - BFH         111180.0
# 39349  Berner Fachhochschule - BFH          45148.0
# 41659  Berner Fachhochschule - BFH         136340.0
# 42636  Berner Fachhochschule - BFH         135000.0
# 42749  Berner Fachhochschule - BFH         440000.0
# 43190  Berner Fachhochschule - BFH         972103.0
# 43425  Berner Fachhochschule - BFH           7150.0
# 43507  Berner Fachhochschule - BFH           2600.0
# 43778  Berner Fachhochschule - BFH         112181.0
# ...                            ...              ...
# 58222  Berner Fachhochschule - BFH         125924.0
# 58827  Berner Fachhochschule - BFH           2000.0
# 59076  Berner Fachhochschule - BFH         300000.0
# 59127  Berner Fachhochschule - BFH         176876.0
# 59209  Berner Fachhochschule - BFH         180897.0
# 59354  Berner Fachhochschule - BFH         139896.0
# 59368  Berner Fachhochschule - BFH         603774.0
# 59931  Berner Fachhochschule - BFH           8700.0
# 60495  Berner Fachhochschule - BFH         110419.0
# 60635  Berner Fachhochschule - BFH         334831.0
# 60676  Berner Fachhochschule - BFH         300000.0
# 60737  Berner Fachhochschule - BFH         219598.0
# 61167  Berner Fachhochschule - BFH           8600.0
# 61168  Berner Fachhochschule - BFH           9700.0
# 61272  Berner Fachhochschule - BFH        1595328.0
# 61275  Berner Fachhochschule - BFH           7000.0
# 61371  Berner Fachhochschule - BFH           5000.0
# 61556  Berner Fachhochschule - BFH           5800.0
# 62067  Berner Fachhochschule - BFH         247509.0
# 62115  Berner Fachhochschule - BFH         373862.0
# 62168  Berner Fachhochschule - BFH         209909.0
# 62177  Berner Fachhochschule - BFH         344695.0
# 62212  Berner Fachhochschule - BFH         163771.0
# 62388  Berner Fachhochschule - BFH           2500.0
# 62416  Berner Fachhochschule - BFH          20560.0
# 62735  Berner Fachhochschule - BFH          11610.0
# 62824  Berner Fachhochschule - BFH           1116.0
# 63305  Berner Fachhochschule - BFH         667437.0
# 63366  Berner Fachhochschule - BFH         629112.0
# 63616  Berner Fachhochschule - BFH           6000.0
#
# [136 rows x 3 columns])
# ('Biotechnologie Institut Thurgau - BITG',                                              Institution  \
# 37364  Biotechnologie Institut Thurgau an der Univers...
# 41208  Biotechnologie Institut Thurgau an der Univers...
# 45265  Biotechnologie Institut Thurgau an der Univers...
# 48382  Biotechnologie Institut Thurgau an der Univers...
# 49358  Biotechnologie Institut Thurgau an der Univers...
# 50761  Biotechnologie Institut Thurgau an der Univers...
# 53362  Biotechnologie Institut Thurgau an der Univers...
# 59466  Biotechnologie Institut Thurgau an der Univers...
#
#                                    University  Approved Amount
# 37364  Biotechnologie Institut Thurgau - BITG         197000.0
# 41208  Biotechnologie Institut Thurgau - BITG         382961.0
# 45265  Biotechnologie Institut Thurgau - BITG         376152.0
# 48382  Biotechnologie Institut Thurgau - BITG         209256.0
# 49358  Biotechnologie Institut Thurgau - BITG         205110.0
# 50761  Biotechnologie Institut Thurgau - BITG         378870.0
# 53362  Biotechnologie Institut Thurgau - BITG         426222.0
# 59466  Biotechnologie Institut Thurgau - BITG         316964.0  )
# ("Centre de rech. sur l'environnement alpin - CREALP",                                              Institution  \
# 11071  Centre de recherches scientifiques fondamental...
# 12668  Centre de recherches scientifiques fondamental...
# 13954  Centre de recherches scientifiques fondamental...
# 16695  Centre de recherches scientifiques fondamental...
# 17183  Centre de recherches scientifiques fondamental...
# 21001  Centre de recherches scientifiques fondamental...
# 22509  Centre de recherches scientifiques fondamental...
# 31002  Centre de recherches scientifiques fondamental...
#
#                                               University  Approved Amount
# 11071  Centre de rech. sur l'environnement alpin - CR...         292924.0
# 12668  Centre de rech. sur l'environnement alpin - CR...         227126.0
# 13954  Centre de rech. sur l'environnement alpin - CR...         145918.0
# 16695  Centre de rech. sur l'environnement alpin - CR...         290000.0
# 17183  Centre de rech. sur l'environnement alpin - CR...         199980.0
# 21001  Centre de rech. sur l'environnement alpin - CR...         216086.0
# 22509  Centre de rech. sur l'environnement alpin - CR...         144481.0
# 31002  Centre de rech. sur l'environnement alpin - CR...          51163.0  )
# ('EPF Lausanne - EPFL',                                              Institution           University  \
# 174    Laboratoire d'intermodalité des transports et ...  EPF Lausanne - EPFL
#
# 63402  Institut Suisse de Recherche Expérimentale sur...  EPF Lausanne - EPFL
# 63437  Institut des sciences et ingénierie chimiques ...  EPF Lausanne - EPFL
# 63478  Laboratoire de traitement sensoriel EPFL - SV ...  EPF Lausanne - EPFL
# 63498  Chaire IRP en réparation de la moëlle épinière...  EPF Lausanne - EPFL
# 63499                                EPFL SV ISREC UPLIN  EPF Lausanne - EPFL
# 63502  Institut suisse de recherche expérimentale sur...  EPF Lausanne - EPFL
# 63507  Institut interfacultaire de Bioingénierie EPFL...  EPF Lausanne - EPFL
# 63516                            VPAI - Coopération EPFL  EPF Lausanne - EPFL
# 63556  Laboratoire de machines hydrauliques EPFL - ST...  EPF Lausanne - EPFL
# 63557  Laboratoire d'ingénierie moléculaire des nanom...  EPF Lausanne - EPFL
# 63559  Laboratoire de simulation moléculaire EPFL - S...  EPF Lausanne - EPFL
# 63561  Power and Wide-band-gap Electronics Research L...  EPF Lausanne - EPFL
# 63565  Laboratoire de physique des hautes énergies 2 ...  EPF Lausanne - EPFL
# 63566  Laboratoire de physique des hautes énergies 2 ...  EPF Lausanne - EPFL
# 63582                          Brain Mind Institute EPFL  EPF Lausanne - EPFL
# 63600  Laboratoire de bio- et nano-instrumentation EP...  EPF Lausanne - EPFL
# 63602                 Laboratoire Chôros INTER-ENAC EPFL  EPF Lausanne - EPFL
# 63643  Laboratoire des matériaux pour les énergies re...  EPF Lausanne - EPFL
# 63710  Laboratoire pour la microscopie et la diffusio...  EPF Lausanne - EPFL
# 63756  Laboratoire pour la topologie et les neuroscie...  EPF Lausanne - EPFL
# 63852                                 ALICE ENAC/IA EPFL  EPF Lausanne - EPFL
#
#        Approved Amount
# 174           109417.0
# 360           216537.0
# 535           188793.0
# 669            70178.0
# 752            94280.0
# 902           192161.0
# 1009           80833.0
# 1127           75689.0
# 1149          119102.0
# 1196          112027.0
# 1238           73038.0
# 1431           74898.0
# 1542          172723.0
# 1599            7000.0
# 1870           54887.0
# 1877          173452.0
# 1882          228250.0
# 1890           69539.0
# 1891           75004.0
# 1894          268118.0
# 1899          118850.0
# 1914           62060.0
# 1915          216426.0
# 1916          162654.0
# 1928           42400.0
# 1958           90317.0
# 1982           96522.0
# 1991           36974.0
# 2000          135316.0
# 2001          419492.0
# ...                ...
# 63324         337836.0
# 63325         256168.0
# 63337         631548.0
# 63354        2050000.0
# 63370         206368.0
# 63383         720000.0
# 63385         355836.0
# 63387         469839.0
# 63388         631990.0
# 63402         995317.0
# 63437         487836.0
# 63478         834000.0
# 63498         834000.0
# 63499         885550.0
# 63502         826305.0
# 63507         544800.0
# 63516          11000.0
# 63556         837106.0
# 63557         774192.0
# 63559         716027.0
# 63561         999892.0
# 63565         946400.0
# 63566         709185.0
# 63582         274718.0
# 63600           7000.0
# 63602           3400.0
# 63643          16000.0
# 63710         393242.0
# 63756          16200.0
# 63852         127189.0
#
# [4428 rows x 3 columns])
# ('ETH Zürich - ETHZ',                                              Institution         University  \
# 47               Chair of English Literature ETH-Zentrum  ETH Zürich - ETHZ
# 74           Fachrichtung Rechtswissenschaft ETH-Zentrum  ETH Zürich - ETHZ
# 77     Abt. für Architektur Vorstehersekretariat EHT-...  ETH Zürich - ETHZ
# 93          Institut für Wirtschaftsforschung ETH-Zürich  ETH Zürich - ETHZ
# 193    Institut für Geschichte & Theorie der Architek...  ETH Zürich - ETHZ
#
# 63568                 Institut für Astronomie ETH Zürich  ETH Zürich - ETHZ
# 63569             Institut für Teilchenphysik ETH Zürich  ETH Zürich - ETHZ
# 63572             Institut für Teilchenphysik ETH Zürich  ETH Zürich - ETHZ
# 63589   Institut für Geochemie und Petrologie ETH Zürich  ETH Zürich - ETHZ
# 63608  Departement Management, Technologie und Ökonom...  ETH Zürich - ETHZ
# 63614  Institut für Geschichte & Theorie der Architek...  ETH Zürich - ETHZ
# 63684    Laboratorium für Anorganische Chemie ETH Zürich  ETH Zürich - ETHZ
# 63709  Institut für Lebensmittelwissenschaften, Ernäh...  ETH Zürich - ETHZ
# 63755                   Geologisches Institut ETH Zürich  ETH Zürich - ETHZ
# 63757           Departement Architektur DARCH ETH Zürich  ETH Zürich - ETHZ
# 63790                   Seminar für Statistik ETH Zürich  ETH Zürich - ETHZ
# 63899  Institut für Biomedizinische Technik Universit...  ETH Zürich - ETHZ
# 63917                     Centro Stefano Franscini (CSF)  ETH Zürich - ETHZ
# 63951  Planning of Landscape and Urban Systems Instit...  ETH Zürich - ETHZ
#
#        Approved Amount
# 47             46200.0
# 74            144814.0
# 77             41872.0
# 93             99995.0
# 193           180059.0
# 315            66887.0
# 373           244740.0
# 437           278174.0
# 499            31800.0
# 646           128287.0
# 686           115739.0
# 754            94833.0
# 785           120435.0
# 834            82565.0
# 893           360865.0
# 913            79310.0
# 993            97937.0
# 1004           84938.0
# 1012           60308.0
# 1060           63823.0
# 1101           85895.0
# 1335           87034.0
# 1424           97429.0
# 1472           34476.0
# 1588            8400.0
# 1629          117173.0
# 1649          270701.0
# 1684          285000.0
# 1692           98415.0
# 1805           57021.0
# ...                ...
# 63377         220158.0
# 63379         452803.0
# 63380         880000.0
# 63430         879901.0
# 63443         332461.0
# 63448         648688.0
# 63450         824108.0
# 63454         305040.0
# 63466         756000.0
# 63474         167446.0
# 63496         918000.0
# 63512           5100.0
# 63517         190007.0
# 63542           9000.0
# 63558         575367.0
# 63562        1198381.0
# 63568         269190.0
# 63569         575750.0
# 63572         785443.0
# 63589          10000.0
# 63608           6500.0
# 63614           4600.0
# 63684          98000.0
# 63709         600093.0
# 63755          12990.0
# 63757           6400.0
# 63790          22745.0
# 63899          16000.0
# 63917         120000.0
# 63951          99952.0
#
# [6153 rows x 3 columns])
# ('Eidg. Anstalt für Wasserversorgung - EAWAG',                                              Institution  \
# 1793                                               Eawag
# 1931                                               Eawag
# 2077                                               Eawag
# 2449                                               Eawag
# 2862                                               Eawag
# 3209   Institut für Gewässerschutz und Wassertechnolo...
# 3308                                               Eawag
# 3432                 Abteilung Oberflächengewässer EAWAG
# 3686                                               Eawag
# 3868   Institut für Gewässerschutz und Wassertechnolo...
# 4019                                               Eawag
# 4230                                               Eawag
# 4627   Institut für Gewässerschutz und Wassertechnolo...
# 4751                                               Eawag
# 4792                                               Eawag
# 4804                                               Eawag
# 5169                                               Eawag
# 5213                                               Eawag
# 5667                                               Eawag
# 6166                                               Eawag
# 6280                                               Eawag
# 6408                                               Eawag
# 6652                                               Eawag
# 6831                                               Eawag
# 7014                                               Eawag
# 7148                                               Eawag
# 7784                                               Eawag
# 7993                                               Eawag
# 8094                                               Eawag
# 8120                                               Eawag
# ...                                                  ...
# 57812                         EAWAG Dept. Surface Waters
# 58005                    Aquatische Umweltanalytik EAWAG
# 58033                                              Eawag
# 58264                                              Eawag
# 58408  Institut für Integrative Biologie ETH Zürich +...
# 58998             Wasserressourcen und Trinkwasser Eawag
# 59113                                 Biogeochemie EAWAG
# 59249                  Fischökologie und Evolution Eawag
# 59330                                              Eawag
# 59383                                              Eawag
# 59404                Abteilung Oberflächengewässer EAWAG
# 59538            Abteilung für Umweltmikrobiologie EAWAG
# 59553                                              Eawag
# 59575                                              Eawag
# 60508                                              Eawag
# 60675                                              Eawag
# 60836                            Umwelttoxikologie EAWAG
# 60885                                              Eawag
# 60911                Abteilung Oberflächengewässer EAWAG
# 61267                  Fischökologie und Evolution Eawag
# 61823            Abteilung für Umweltmikrobiologie EAWAG
# 61852                                              Eawag
# 61898             Wasserressourcen und Trinkwasser Eawag
# 62283                                              Eawag
# 62284                                              Eawag
# 62302            Abteilung für Umweltmikrobiologie EAWAG
# 63281                                 Umweltchemie Eawag
# 63309                            Umwelttoxikologie EAWAG
# 63425                                              Eawag
# 63475                         EAWAG Dept. Surface Waters
#
#                                        University  Approved Amount
# 1793   Eidg. Anstalt für Wasserversorgung - EAWAG          66379.0
# 1931   Eidg. Anstalt für Wasserversorgung - EAWAG         112377.0
# 2077   Eidg. Anstalt für Wasserversorgung - EAWAG         299201.0
# 2449   Eidg. Anstalt für Wasserversorgung - EAWAG         262845.0
# 2862   Eidg. Anstalt für Wasserversorgung - EAWAG         243309.0
# 3209   Eidg. Anstalt für Wasserversorgung - EAWAG         152221.0
# 3308   Eidg. Anstalt für Wasserversorgung - EAWAG         230711.0
# 3432   Eidg. Anstalt für Wasserversorgung - EAWAG         123954.0
# 3686   Eidg. Anstalt für Wasserversorgung - EAWAG         232264.0
# 3868   Eidg. Anstalt für Wasserversorgung - EAWAG          65432.0
# 4019   Eidg. Anstalt für Wasserversorgung - EAWAG         161455.0
# 4230   Eidg. Anstalt für Wasserversorgung - EAWAG         238017.0
# 4627   Eidg. Anstalt für Wasserversorgung - EAWAG         192492.0
# 4751   Eidg. Anstalt für Wasserversorgung - EAWAG         290518.0
# 4792   Eidg. Anstalt für Wasserversorgung - EAWAG         131872.0
# 4804   Eidg. Anstalt für Wasserversorgung - EAWAG         101230.0
# 5169   Eidg. Anstalt für Wasserversorgung - EAWAG         248646.0
# 5213   Eidg. Anstalt für Wasserversorgung - EAWAG         115717.0
# 5667   Eidg. Anstalt für Wasserversorgung - EAWAG         150713.0
# 6166   Eidg. Anstalt für Wasserversorgung - EAWAG         102043.0
# 6280   Eidg. Anstalt für Wasserversorgung - EAWAG         113725.0
# 6408   Eidg. Anstalt für Wasserversorgung - EAWAG          88323.0
# 6652   Eidg. Anstalt für Wasserversorgung - EAWAG          79448.0
# 6831   Eidg. Anstalt für Wasserversorgung - EAWAG         176196.0
# 7014   Eidg. Anstalt für Wasserversorgung - EAWAG         110640.0
# 7148   Eidg. Anstalt für Wasserversorgung - EAWAG         101712.0
# 7784   Eidg. Anstalt für Wasserversorgung - EAWAG         135649.0
# 7993   Eidg. Anstalt für Wasserversorgung - EAWAG          65195.0
# 8094   Eidg. Anstalt für Wasserversorgung - EAWAG          48768.0
# 8120   Eidg. Anstalt für Wasserversorgung - EAWAG         366662.0
# ...                                           ...              ...
# 57812  Eidg. Anstalt für Wasserversorgung - EAWAG         259197.0
# 58005  Eidg. Anstalt für Wasserversorgung - EAWAG         372000.0
# 58033  Eidg. Anstalt für Wasserversorgung - EAWAG         210650.0
# 58264  Eidg. Anstalt für Wasserversorgung - EAWAG           5550.0
# 58408  Eidg. Anstalt für Wasserversorgung - EAWAG        1654584.0
# 58998  Eidg. Anstalt für Wasserversorgung - EAWAG         249550.0
# 59113  Eidg. Anstalt für Wasserversorgung - EAWAG         228200.0
# 59249  Eidg. Anstalt für Wasserversorgung - EAWAG         275050.0
# 59330  Eidg. Anstalt für Wasserversorgung - EAWAG         246821.0
# 59383  Eidg. Anstalt für Wasserversorgung - EAWAG         210050.0
# 59404  Eidg. Anstalt für Wasserversorgung - EAWAG         460100.0
# 59538  Eidg. Anstalt für Wasserversorgung - EAWAG         397000.0
# 59553  Eidg. Anstalt für Wasserversorgung - EAWAG         219550.0
# 59575  Eidg. Anstalt für Wasserversorgung - EAWAG         283544.0
# 60508  Eidg. Anstalt für Wasserversorgung - EAWAG         181008.0
# 60675  Eidg. Anstalt für Wasserversorgung - EAWAG         170000.0
# 60836  Eidg. Anstalt für Wasserversorgung - EAWAG         190007.0
# 60885  Eidg. Anstalt für Wasserversorgung - EAWAG         236007.0
# 60911  Eidg. Anstalt für Wasserversorgung - EAWAG         320000.0
# 61267  Eidg. Anstalt für Wasserversorgung - EAWAG         193876.0
# 61823  Eidg. Anstalt für Wasserversorgung - EAWAG           5000.0
# 61852  Eidg. Anstalt für Wasserversorgung - EAWAG         204608.0
# 61898  Eidg. Anstalt für Wasserversorgung - EAWAG         275558.0
# 62283  Eidg. Anstalt für Wasserversorgung - EAWAG          65876.0
# 62284  Eidg. Anstalt für Wasserversorgung - EAWAG         176508.0
# 62302  Eidg. Anstalt für Wasserversorgung - EAWAG         372000.0
# 63281  Eidg. Anstalt für Wasserversorgung - EAWAG         600000.0
# 63309  Eidg. Anstalt für Wasserversorgung - EAWAG          79046.0
# 63425  Eidg. Anstalt für Wasserversorgung - EAWAG          21160.0
# 63475  Eidg. Anstalt für Wasserversorgung - EAWAG         593924.0
#
# [333 rows x 3 columns])
# ('Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',                                              Institution  \
# 29     Eidg. Forschungsanstalt für Wald, Schnee und L...
# 407    Eidg. Forschungsanstalt für Wald, Schnee und L...
# 632    Eidg. Forschungsanstalt für Wald, Schnee und L...
# 929    Eidg. Forschungsanstalt für Wald, Schnee und L...
# 1155   Eidg. Forschungsanstalt für Wald, Schnee und L...
#
Eidg. Forschungsanstalt für Wald,Schnee,Land -...         238013.0
# 57563  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         380530.0
# 57654  Eidg. Forschungsanstalt für Wald,Schnee,Land -...          98074.0
# 57716  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         213394.0
# 57725  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         194383.0
# 58038  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         177551.0
# 58148  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         375482.0
# 58184  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         249985.0
# 58345  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         553377.0
# 59114  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         245470.0
# 59202  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         476038.0
# 59565  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         272318.0
# 59779  Eidg. Forschungsanstalt für Wald,Schnee,Land -...          80000.0
# 59786  Eidg. Forschungsanstalt für Wald,Schnee,Land -...        1999902.0
# 59991  Eidg. Forschungsanstalt für Wald,Schnee,Land -...          96344.0
# 60009  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         239910.0
# 60011  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         229765.0
# 60478  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         404016.0
# 60780  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         387733.0
# 60891  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         103460.0
# 61098  Eidg. Forschungsanstalt für Wald,Schnee,Land -...          70000.0
# 62070  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         189008.0
# 62247  Eidg. Forschungsanstalt für Wald,Schnee,Land -...         190576.0
#
# [223 rows x 3 columns])
# ('Eidg. Hochschulinstitut für Berufsbildung - EHB',                                              Institution  \
# 8266   Eidgenössische Hochschule für Berufsbildung Bi...
# 8415   Istituto Universitario Federale per la Formazi...
# 8484   Eidgenössische Hochschule für Berufsbildung Bi...
# 8580   Istituto Universitario Federale per la Formazi...
# 21286  Istituto Universitario Federale per la Formazi...
# 22862  Istituto Universitario Federale per la Formazi...
# 49545  EHB Eidgenössisches Hochschulinstitut für Beru...
# 54661  Recherche et Développement Institut Fédéral de...
# 57933  EHB Eidgenössisches Hochschulinstitut für Beru...
# 59164  EHB Eidgenössisches Hochschulinstitut für Beru...
# 59658                                               IFFP
# 61032  EHB Eidgenössisches Hochschulinstitut für Beru...
#
#                                             University  Approved Amount
# 8266   Eidg. Hochschulinstitut für Berufsbildung - EHB         571190.0
# ...
# 25596  Weitere Institute - FINST           5000.0
# 27681  Weitere Institute - FINST         318714.0
# 29835  Weitere Institute - FINST          14400.0
# 34186  Weitere Institute - FINST         450000.0
# 34201  Weitere Institute - FINST         111894.0
# 34463  Weitere Institute - FINST           2000.0
# 38984  Weitere Institute - FINST         237426.0
# 40257  Weitere Institute - FINST         480000.0
# 43980  Weitere Institute - FINST         349608.0
# 47207  Weitere Institute - FINST         299992.0
# 47420  Weitere Institute - FINST         525000.0
# 50308  Weitere Institute - FINST         194810.0
# 56107  Weitere Institute - FINST         555000.0
# 56289  Weitere Institute - FINST         128812.0
# 56307  Weitere Institute - FINST         214540.0
# 56463  Weitere Institute - FINST         171000.0
# 57127  Weitere Institute - FINST          64316.0
# 57616  Weitere Institute - FINST          12272.0
# 59079  Weitere Institute - FINST         189079.0
# 59917  Weitere Institute - FINST           1845.0
# 61255  Weitere Institute - FINST        1846550.0
# 63300  Weitere Institute - FINST         374279.0
# 63615  Weitere Institute - FINST           4600.0  )
# ('Weitere Spitäler - ASPIT',                                              Institution  \
# 4872            Kantonsspital Luzern Medizinische Klinik
# 4880   ORL-Klinik Paedo-Audiologische Station Kantons...
# 4884                Medizinische Klinik C Kantonssspital
# 4915                        Regionalspital Biel Urologie
# 4936                          Frauenklinik Kantonsspital
# 63964  Departement Design Zürcher Hochschule der Küns...
# 63965  Institute Performing Arts and Film Zürcher Hoc...
#
#                                    University  Approved Amount
# 8470   Zürcher Fachhochschule (ohne PH) - ZFH          11000.0
# 16623  Zürcher Fachhochschule (ohne PH) - ZFH         579563.0
# 17525  Zürcher Fachhochschule (ohne PH) - ZFH         596000.0
# 19729  Zürcher Fachhochschule (ohne PH) - ZFH         298572.0
# 20478  Zürcher Fachhochschule (ohne PH) - ZFH         185643.0
# 21312  Zürcher Fachhochschule (ohne PH) - ZFH         270964.0
# 21552  Zürcher Fachhochschule (ohne PH) - ZFH         279236.0
# 24144  Zürcher Fachhochschule (ohne PH) - ZFH          12000.0
# 25660  Zürcher Fachhochschule (ohne PH) - ZFH          90160.0
# 28066  Zürcher Fachhochschule (ohne PH) - ZFH          30000.0
# 28172  Zürcher Fachhochschule (ohne PH) - ZFH          19663.0
# 28177  Zürcher Fachhochschule (ohne PH) - ZFH          10440.0
# 28811  Zürcher Fachhochschule (ohne PH) - ZFH          17200.0
# 28936  Zürcher Fachhochschule (ohne PH) - ZFH          78987.0
# 29202  Zürcher Fachhochschule (ohne PH) - ZFH          18000.0
# 29204  Zürcher Fachhochschule (ohne PH) - ZFH          32700.0
# 29211  Zürcher Fachhochschule (ohne PH) - ZFH           7750.0
# 29222  Zürcher Fachhochschule (ohne PH) - ZFH          14000.0
# 31447  Zürcher Fachhochschule (ohne PH) - ZFH           7375.0
# 31458  Zürcher Fachhochschule (ohne PH) - ZFH          34580.0
# 31466  Zürcher Fachhochschule (ohne PH) - ZFH          12500.0
# 31494  Zürcher Fachhochschule (ohne PH) - ZFH          50000.0
# 31601  Zürcher Fachhochschule (ohne PH) - ZFH          49097.0
# 31609  Zürcher Fachhochschule (ohne PH) - ZFH          50000.0
# 31610  Zürcher Fachhochschule (ohne PH) - ZFH          47323.0
# 31617  Zürcher Fachhochschule (ohne PH) - ZFH          25925.0
# 31619  Zürcher Fachhochschule (ohne PH) - ZFH          50000.0
# 31623  Zürcher Fachhochschule (ohne PH) - ZFH          49822.0
# 31635  Zürcher Fachhochschule (ohne PH) - ZFH          10000.0
# 31872  Zürcher Fachhochschule (ohne PH) - ZFH           5000.0
# ...                                       ...              ...
# 61070  Zürcher Fachhochschule (ohne PH) - ZFH           7008.0
# 61169  Zürcher Fachhochschule (ohne PH) - ZFH           2700.0
# 61187  Zürcher Fachhochschule (ohne PH) - ZFH           1300.0
# 61188  Zürcher Fachhochschule (ohne PH) - ZFH           1400.0
# 61209  Zürcher Fachhochschule (ohne PH) - ZFH         266527.0
# 61447  Zürcher Fachhochschule (ohne PH) - ZFH         224250.0
# 61450  Zürcher Fachhochschule (ohne PH) - ZFH         498550.0
# 61533  Zürcher Fachhochschule (ohne PH) - ZFH           3000.0
# 61777  Zürcher Fachhochschule (ohne PH) - ZFH         237706.0
# 61861  Zürcher Fachhochschule (ohne PH) - ZFH         257032.0
# 61868  Zürcher Fachhochschule (ohne PH) - ZFH         587438.0
# 61884  Zürcher Fachhochschule (ohne PH) - ZFH         367639.0
# 62236  Zürcher Fachhochschule (ohne PH) - ZFH         245952.0
# 62337  Zürcher Fachhochschule (ohne PH) - ZFH         231484.0
# 62368  Zürcher Fachhochschule (ohne PH) - ZFH           5783.0
# 62381  Zürcher Fachhochschule (ohne PH) - ZFH          18213.0
# 62429  Zürcher Fachhochschule (ohne PH) - ZFH           1200.0
# 62498  Zürcher Fachhochschule (ohne PH) - ZFH         248388.0
# 62614  Zürcher Fachhochschule (ohne PH) - ZFH           9270.0
# 63181  Zürcher Fachhochschule (ohne PH) - ZFH         234904.0
# 63228  Zürcher Fachhochschule (ohne PH) - ZFH         347103.0
# 63319  Zürcher Fachhochschule (ohne PH) - ZFH         294026.0
# 63419  Zürcher Fachhochschule (ohne PH) - ZFH         552591.0
# 63420  Zürcher Fachhochschule (ohne PH) - ZFH         512844.0
# 63609  Zürcher Fachhochschule (ohne PH) - ZFH           6300.0
# 63610  Zürcher Fachhochschule (ohne PH) - ZFH           4000.0
# 63634  Zürcher Fachhochschule (ohne PH) - ZFH           8000.0
# 63800  Zürcher Fachhochschule (ohne PH) - ZFH           2200.0
# 63964  Zürcher Fachhochschule (ohne PH) - ZFH           1000.0
# 63965  Zürcher Fachhochschule (ohne PH) - ZFH           2000.0
#
# [260 rows x 3 columns])

# %%
username = 'user1'
url = r'http://api.geonames.org/searchJSON?'
geo_cache = defaultdict(str)

''' Do a lookup on geonames.org for name. Returns the first query result. '''
def query_geonames(name):
    # Insert username
    try:
        encoded_args = urlencode({'name': name, 'country':'ch', 'maxRows':'10', 'username': username} )
        r = requests.get(url + encoded_args)
        result = r.json()
        
        if result['totalResultsCount'] > 0:
            geonames = result['geonames']
            geo = geonames[0]
            
            canton = geo['adminCode1']
            lat = geo['lat']
            long = geo['lng']
            
            return {'canton': canton, 'lat': lat, 'long': long}
        else:
            return -1
    except BaseException as e:
        print('For name:', name)
        pprint(e)
        return -1
        
def geo_lookup(name):
    if geo_cache[name] != '':
        result = geo_cache[name]
    else:
        result = query_geonames(name)
        geo_cache[name] = result
    return result

def get_geo_dict(group):
    geo_res = {}
    geo_err = set()
    
    for ind, group in group:
        name = ind.split(' - ')[0]

        res = geo_lookup(name)

        if res != -1:
            geo_res[name] = res
        else:
            second_try = name.split(' ')[-1].strip(')')
            res = geo_lookup(second_try)
            if res != -1:
                geo_res[name] = res
            else:
                geo_err.add(ind)
    
    return geo_res, geo_err

# %%
res, err = get_geo_dict(uni_grouped)

count = 0
for e in err:
    try:
        print(e, has_info[has_info['University'] == e].size)
    except:
        count += 1
#has_info['University'].value_counts()
# Out:
# Allergie- und Asthmaforschung - SIAF 132
# Istituto Svizzero di Roma - ISR 18
# Forschungsinstitut für biologischen Landbau - FIBL 51
# Schweizer Kompetenzzentrum Sozialwissensch. - FORS 93
# Inst. universit. romand de Santé au Travail - IST 105
# NPO (Biblioth., Museen, Verwalt.) - NPO 4419
# HES de Suisse occidentale - HES-SO 813
# Eidg. Anstalt für Wasserversorgung - EAWAG 999
# Schweizer Paraplegiker Forschung - SPF 30
# Eidg. Material und Prüfungsanstalt - EMPA 714
# Swiss Center for Electronics and Microtech. - CSEM 84
# Forschungsinstitut für Opthalmologie - IRO 42
# Forschungskommission SAGW 3
# Weitere Spitäler - ASPIT 243
# Nicht zuteilbar - NA 7785
# Firmen/Privatwirtschaft - FP 1476
# Schweiz. Institut für Kunstwissenschaft - SIK-ISEA 60
# Inst. Suisse de Spéléologie et Karstologie - ISSKA 9
# Inst. de Hautes Etudes Internat. et du Dév - IHEID 594
# Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL 669
# Fachhochschule Kalaidos - FHKD 9
# Haute école pédagogique fribourgeoise - HEPFR 21
# Swiss Institute of Bioinformatics - SIB 93
# Eidg. Hochschulinstitut für Berufsbildung - EHB 36

# %%
geo_res = {}

for name, group in uni_grouped:
    name = name.split(' - ')[0]
    
    res = geo_lookup(name)
    
    if res != -1:
        geo_res[name] = res
    else:
        second_try = name.split(' ')[-1].strip(')')
        res = geo_lookup(second_try)
        if res != -1:
            geo_res[name] = res
        else:
            print('-', name, '/', second_try)
               
for key in geo_res.keys():
    print(key, geo_res[key])
# Out:
# - Allergie- und Asthmaforschung / Asthmaforschung
# - Eidg. Anstalt für Wasserversorgung / Wasserversorgung
# - Eidg. Forschungsanstalt für Wald,Schnee,Land / Wald,Schnee,Land
# - Eidg. Hochschulinstitut für Berufsbildung / Berufsbildung
# - Eidg. Material und Prüfungsanstalt / Prüfungsanstalt
# - Fachhochschule Kalaidos / Kalaidos
# - Firmen/Privatwirtschaft / Firmen/Privatwirtschaft
# - Forschungsinstitut für Opthalmologie / Opthalmologie
# - Forschungsinstitut für biologischen Landbau / Landbau
# - Forschungskommission SAGW / SAGW
# For name: occidentale
# KeyError('adminCode1',)
# - HES de Suisse occidentale / occidentale
# - Haute école pédagogique fribourgeoise / fribourgeoise
# - Inst. Suisse de Spéléologie et Karstologie / Karstologie
# - Inst. de Hautes Etudes Internat. et du Dév / Dév
# - Inst. universit. romand de Santé au Travail / Travail
# - Istituto Svizzero di Roma / Roma
# - NPO (Biblioth., Museen, Verwalt.) / Verwalt.
# - Nicht zuteilbar / zuteilbar
# - Schweiz. Institut für Kunstwissenschaft / Kunstwissenschaft
# - Schweizer Kompetenzzentrum Sozialwissensch. / Sozialwissensch.
# - Schweizer Paraplegiker Forschung / Forschung
# - Swiss Center for Electronics and Microtech. / Microtech.
# - Swiss Institute of Bioinformatics / Bioinformatics
# - Weitere Spitäler / Spitäler
# Pädagogische Hochschule Nordwestschweiz {'canton': 'BL', 'long': '7.63856', 'lat': '47.53378'}
# Institut Universitaire Kurt Bösch {'canton': 'ZH', 'long': '8.69742', 'lat': '47.36164'}
# Pädagogische Hochschule Schaffhausen {'canton': 'SH', 'long': '8.63493', 'lat': '47.69732'}
# Idiap Research Institute {'canton': 'BS', 'long': '7.60247', 'lat': '47.56639'}
# Pädagogische Hochschule Luzern {'canton': 'LU', 'long': '8.30635', 'lat': '47.05048'}
# Franklin University Switzerland {'canton': '00', 'long': '8.01427', 'lat': '47.00016'}
# Pädagogische Hochschule Thurgau {'canton': 'TG', 'long': '9.07686', 'lat': '47.5562'}
# Pädagogische Hochschule Bern {'canton': 'BE', 'long': '7.44744', 'lat': '46.94809'}
# Pädagogische Hochschule Wallis {'canton': 'VS', 'long': '7.45972', 'lat': '46.22925'}
# Institut für Kulturforschung Graubünden {'canton': 'GR', 'long': '9.62296', 'lat': '46.6587'}
# Centre de rech. sur l'environnement alpin {'canton': 'BE', 'long': '8.18586', 'lat': '46.72809'}
# Pädagogische Hochschule Zürich {'canton': 'ZH', 'long': '8.55', 'lat': '47.36667'}
# Interkant. Hochschule für Heilpädagogik ZH {'canton': 'ZH', 'long': '8.58401', 'lat': '47.31805'}
# Kantonsspital St. Gallen {'canton': 'SG', 'long': '9.38826', 'lat': '47.42925'}
# EPF Lausanne {'canton': 'VD', 'long': '6.63282', 'lat': '46.516'}
# Universität St. Gallen {'canton': 'SG', 'long': '9.37477', 'lat': '47.42391'}
# SUP della Svizzera italiana {'canton': 'TI', 'long': '8.91741', 'lat': '46.02394'}
# Universität Bern {'canton': 'BE', 'long': '7.43548', 'lat': '46.95096'}
# Universität Basel {'canton': 'BS', 'long': '7.58403', 'lat': '47.55832'}
# Facoltà di Teologia di Lugano {'canton': 'TI', 'long': '8.96004', 'lat': '46.01008'}
# Fachhochschule Ostschweiz {'canton': 'SG', 'long': '9.03625', 'lat': '47.41322'}
# Université de Neuchâtel {'canton': 'NE', 'long': '6.931', 'lat': '46.99179'}
# Université de Genève {'canton': 'GE', 'long': '6.14569', 'lat': '46.20222'}
# Weitere Institute {'canton': 'BS', 'long': '7.60247', 'lat': '47.56639'}
# Haute école pédagogique BE, JU, NE {'canton': 'NE', 'long': '6.97147', 'lat': '47.07506'}
# Università della Svizzera italiana {'canton': 'TI', 'long': '8.91741', 'lat': '46.02394'}
# Fernfachhochschule Schweiz (Mitglied SUPSI) {'canton': 'TI', 'long': '8.91741', 'lat': '46.02394'}
# Physikal.-Meteorolog. Observatorium Davos {'canton': 'GR', 'long': '9.83723', 'lat': '46.80429'}
# Pädagogische Hochschule Zug {'canton': 'ZG', 'long': '8.51745', 'lat': '47.17242'}
# Universität Zürich {'canton': 'ZH', 'long': '8.53434', 'lat': '47.37092'}
# Biotechnologie Institut Thurgau {'canton': 'TG', 'long': '9.07686', 'lat': '47.5562'}
# Ente Ospedaliero Cantonale {'canton': 'BE', 'long': '7.37399', 'lat': '47.27954'}
# Pädagogische Hochschule Graubünden {'canton': 'GR', 'long': '9.62296', 'lat': '46.6587'}
# Université de Fribourg {'canton': 'FR', 'long': '7.15128', 'lat': '46.80237'}
# Schweiz. Hochschule für Logopädie Rorschach {'canton': 'SG', 'long': '9.44246', 'lat': '47.46647'}
# Université de Lausanne {'canton': 'VD', 'long': '6.58409', 'lat': '46.52376'}
# Fachhochschule Nordwestschweiz (ohne PH) {'canton': 'VS', 'long': '7.92741', 'lat': '46.10805'}
# Forschungsanstalten Agroscope {'canton': 'FR', 'long': '7.10525', 'lat': '46.77051'}
# Friedrich Miescher Institute {'canton': 'BS', 'long': '7.60247', 'lat': '47.56639'}
# Pädag. Hochschule Tessin (Teilschule SUPSI) {'canton': 'TI', 'long': '8.91741', 'lat': '46.02394'}
# AO Research Institute {'canton': 'BS', 'long': '7.60247', 'lat': '47.56639'}
# Pädagogische Hochschule St. Gallen {'canton': 'SG', 'long': '9.37477', 'lat': '47.42391'}
# Paul Scherrer Institut {'canton': 'ZG', 'long': '8.58842', 'lat': '47.17838'}
# ETH Zürich {'canton': 'ZH', 'long': '8.54805', 'lat': '47.3763'}
# Robert Walser-Stiftung Bern {'canton': 'BE', 'long': '7.44744', 'lat': '46.94809'}
# Haute école pédagogique du canton de Vaud {'canton': 'VD', 'long': '6.64496', 'lat': '46.61671'}
# Berner Fachhochschule {'canton': 'BL', 'long': '7.63886', 'lat': '47.53443'}
# Zürcher Fachhochschule (ohne PH) {'canton': 'VS', 'long': '7.92741', 'lat': '46.10805'}
# Hochschule Luzern {'canton': 'LU', 'long': '8.30635', 'lat': '47.05048'}
# Staatsunabh. Theologische Hochschule Basel {'canton': 'BS', 'long': '7.57327', 'lat': '47.55839'}
# Instituto Ricerche Solari Locarno {'canton': 'TI', 'long': '8.79953', 'lat': '46.17086'}
# Universität Luzern {'canton': 'LU', 'long': '8.30635', 'lat': '47.05048'}
# Pädagogische Hochschule Schwyz {'canton': 'SZ', 'long': '8.65414', 'lat': '47.02076'}

# %%
df = pd.DataFrame.from_dict(geo_res).T
df.describe()

df[['lat','long']] = df[['lat','long']].apply(pd.to_numeric)
df.describe()
# Out:
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#              lat       long
# count  53.000000  53.000000
# mean   46.979823   8.183785
# std     0.530679   0.900651
# min    46.010080   6.145690
# 25%          NaN        NaN
# 50%          NaN        NaN
# 75%          NaN        NaN
# max    47.697320   9.837230

# %%
df.pivot(index='')

# %%
has_uni.head(100)

# %%
p = geo_lookup('University of Geneve')

# %%
print(p)

# %%
print('Dropped from original:', get_dropped_perc(p3, has_uni))
print('Dropped from last step:', get_dropped_perc(grants_data, has_uni))

# %% [markdown]
# Lets extract country code from University name and make a column out of it

# %%
has_code = has_uni['University'].str.extract('(?P<University>.*?(?= -))(?P<delim>\ -\ )(?P<Code>.*)', expand=True).drop('delim', axis=1)
has_code.head()

# %%
# Drop NAs and NPOs in Canton Codes (not avaialable and NGOs)
has_code = has_code[has_code["Code"] != 'NPO']
has_code = has_code[has_code["Code"] != 'NA']
has_code.head()

# %%
# For these rows, we allready have the canton code
has_canton_code = has_code['Code'][has_code['Code'].apply(is_canton_code)].rename('Canton code')

has_canton_code.index

# %%
# For the rest, we will try to get the canton code by requesting the GeoNames web service
has_uni_code = has_code['Code'][has_code['Code'].apply(is_canton_code) == False]

has_uni_no_cantoncode = has_uni.loc[has_uni_code.index]
has_uni_no_cantoncode.head()

# %% [markdown]
# We don't want to be banned from GeoLookup so first lets check how many missing values are we considering:

# %%
has_uni_no_cantoncode['University'].unique().shape

# %%
## Whats the point of this loop?

for place in has_uni_no_cantoncode['University'].unique():
    if place:
        p = geo_lookup(place)
    if p:
        print(place)
        pprint(p)

# %%
has_info['Institution'].unique().shape

# %%
'''
def map_institution_canton(df):
    for place in df['Institution'].unique():
        if str(place) == 'nan':
            continue
        if str(place).startswith('Uni'):
            continue
        #c = get_canton(place)
        #if c == '':
        p = geo_lookup(place)
        if p:
            print('found', p, 'in the api')
            canton_dict[place] = p
        else:
            has_looked_up[place] = True
            print(place, p)


map_institution_canton(has_info)
'''

canton_dict['Université de Genève'] = 'GE'

# %%
# Load data for swiss cities
columns = ['Name', 'Kanton']
swiss_cities = pd.read_csv("swiss_cities.csv", delimiter='\t', usecols=columns, na_values=['data not included in P3', 'nan'])
swiss_cities.head(10)

# %%
# Clean Kantons up
#swiss_cities['Kanton'] = swiss_cities['Kanton'].apply(lambda x:get_canton_code(x.rsplit()[-1])) #str.rsplit(None, 1)[0]) # = swiss_cities['Kanton'].map(.str.rsplit(None, 1)[0]
#swiss_cities.head(20)
# Broken since German names

# %%
# Load data for swiss towns
columns = ['Town', 'Canton']
swiss_towns = pd.read_csv("swiss_towns.csv", delimiter='\t', usecols=columns, na_values=['data not included in P3', 'nan'])
swiss_towns.set_index('Town', inplace=True)
swiss_towns.head(10)

# %%
# Test for particular town
#swiss_towns.loc[swiss_towns.Town == 'Basel']
swiss_towns.loc['Basel']['Canton']

# %%
# Direct mapping of canton with Switzerland town list from wikipedia https://en.wikipedia.org/wiki/List_of_cities_in_Switzerland

def map_inst_canton(df):
    for place in df['Institution'].unique():
        if str(place) == 'nan':
            continue
        for word in place.split():
            #print(word)
            if word in swiss_towns.index:
                p = swiss_towns.loc[word]['Canton']
                print(place, " -> ", p)
                df['Canton'] = p

map_inst_canton(has_info)

# %%
has_info.head(200)

# %%
pprint(canton_dict)

# %%
grants_with_has_code = university_grants.join(has_canton_code)
grants_with_has_code.head()

# %%
university_grants.head()

# %%
extracts = university_grants['University'].str.extract('(?P<University>.*-)(?P<Code>.*)', expand=True)
has_code = pd.DataFrame( extracts['Code'] )
has_code.Code.apply(is_canton_code)
grouped_has_code = has_code.groupby('Code')

# %%
only_institution_data = grants_data[grants_data[['University']].isnull().all(axis=1)].index

# %% [markdown]
# ## TODO:
#
# 1. clean up this mess (:
#
# 1. make one function for mapping a row to a canton
#    Suggested strategy:
#
#    (we can only make 200 req. pr hour to the api, so we should try to keep the number down)
#
#    1. Unique institutions, unique universities
#    2. Lookup institution name, place result in hashmap: institution -> canton
#    3. Parse university. If no canton code is given, lookup. Place result in the hashmap
#    4. In the function, do a query in our hashmap for each column. If conflict, return (?)
#
# 1. apply the function to all rows in the data, add canton as a column
# 1. make a df of Canton, Approved Amount
# 1. Groupby canton, sum approved_amount, add a count column
# 1. Plot the results on the map etc
# 1 Bonus
