# %% [markdown]
# # Fetching the data from the IS Academia API
#
# We start by getting the HTML response of the tabular student data from ISAcademia.
# For this, we use the [Requests](http://docs.python-requests.org/en/master/) library.

# %%
# We are going to use requests to do the HTTP-calls for gathering data, and BeautifulSoup for parsing the 
# HTML that we recieve
import requests
from bs4 import BeautifulSoup

# re will help us parse the html by using regular expressions
import re

# Furthermore, we will use the normal stack of pandas, numpy, matplotlib and seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as pls
import seaborn as sb

# Statistical test library
import scipy.stats as stats

# %% [markdown]
# ## Making the reqest
#
# *Warning*: we are loading a lot of data, thus the loading takes quite a long time. Therefore, don't run this unless it's needed
#
# To not spam the API too much, we collect all the data in one try, and filter it afterwords.
#
# We use the following parameters:
#
# ## TODO: Update this
# ~~~~~~~~~~~~~~~~
# - ww_x_GPS:-1
# - ww_i_reportModel:133685247
# - ww_i_reportModelXsl:133685270
# - ww_x_UNITE_ACAD:249847
# - ww_x_PERIODE_ACAD:null
# - ww_x_PERIODE_PEDAGO:null
# - ww_x_HIVERETE:null
#
#
# Which leads to the folloring request:
# http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.html?ww_x_GPS=-1&ww_i_reportModel=133685247&ww_i_reportModelXsl=133685270&ww_x_UNITE_ACAD=249847&ww_x_PERIODE_ACAD=null&ww_x_PERIODE_PEDAGO=null&ww_x_HIVERETE=null
# ~~~~~~~~~~~~~~~~

# %%
DEBUG = True

# TODO: make the request by using parameters to the function call, instead of coding it in the URI.
# TODO: verify that the uri is correct, and that we get all the data that we want

if DEBUG:
    # For testing and development we use the test_uri, which only loads data from 2016-2017
    uri = "http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.html?ww_x_GPS=-1&ww_i_reportModel=133685247&ww_i_reportModelXsl=133685270&ww_x_UNITE_ACAD=249847&ww_x_PERIODE_ACAD=355925344&ww_x_PERIODE_PEDAGO=null&ww_x_HIVERETE=null"
else:
    # For 'production', collect all the data available from ISAcademia, for students at the IC-section
    uri = "http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.html?ww_x_GPS=-1&ww_i_reportModel=133685247&ww_i_reportModelXsl=133685270&ww_x_UNITE_ACAD=249847&ww_x_PERIODE_ACAD=null&ww_x_PERIODE_PEDAGO=null&ww_x_HIVERETE=null"

req = requests.get(uri)

# %% [markdown]
# ## Parsing the result

# %%
# Defining some helper functions, for clarity
def clean(string):
    return string.strip().lower().replace(' ', '_')

def is_semester_info(data):
    return len(data) <= 2

def is_header(data):
    return not ((len(data) > 2) and data[-2].isdigit())

def parse_table(table):
    students = []
    header = ''
    semester = ''

    for tr in table:
        row_data = []
        for td in tr:
            value = td.get_text().strip().replace('\xa0', ' ')
            row_data.append(value)

                     
        if is_semester_info(row_data):
            info = [clean(value) for value in row_data[0].split(', ')]
            section = info[0]
            year = info[1]
            semester, wat = info[2].split('\n_')
        elif(is_header(row_data)):
            header = [ clean(val) for val  in  row_data] 
        else:
            person = {'year': year, 'semester': semester, 'section': section, 'wat': wat}
            for i, key in enumerate(header):
                val = row_data[i].strip()
                if val: 
                    person[key] = val
                    
            students.append(person)
    
    return students

# %%
soup = BeautifulSoup(req.text, 'html.parser')
students_table = soup.find('table')

students = parse_table(students_table)

df = pd.DataFrame(students)
df.set_index(['no_sciper'], inplace=True)

original = df.copy()

# %%
#this here is for debug only if I mess up df somewhere down below in the code
df = original
#Lets list some basic info about parsed data
print(df.shape)
print(df.dtypes)
df.head()
# Out:
# (20102, 14)
# civilité          object
# ecole_echange     object
# filière_opt.      object
# mineur            object
# nom_prénom        object
# section           object
# semester          object
# spécialisation    object
# statut            object
# type_echange      object
# wat               object
# year              object
# year_start         int64
# year_end           int64
# dtype: object
#            civilité                                      ecole_echange  \
# no_sciper
# 170337     Monsieur                             Universidad de Granada
# 171585     Monsieur  Ecole Supérieure de Chimie Physique Electroniq...
# 170200       Madame                               Linköping University
# 171880     Monsieur  Ecole Supérieure de Chimie Physique Electroniq...
# 171505     Monsieur  Ecole Supérieure de Chimie Physique Electroniq...
#
#           filière_opt. mineur             nom_prénom     section  \
# no_sciper
# 170337             NaN    NaN  Arco Arredondo Rafael  echange_in
# 171585             NaN    NaN             Balas Marc  echange_in
# 170200             NaN    NaN         Bergendal Anna  echange_in
# 171880             NaN    NaN    Bret Jean-Sébastien  echange_in
# 171505             NaN    NaN         Burret Nicolas  echange_in
#
#                    semester spécialisation   statut type_echange       wat  \
# no_sciper
# 170337     semestre_automne            NaN  Présent      Erasmus  (24_ét.)
# 171585     semestre_automne            NaN  Présent      Erasmus  (24_ét.)
# 170200     semestre_automne            NaN  Présent      Erasmus  (24_ét.)
# 171880     semestre_automne            NaN  Présent      Erasmus  (24_ét.)
# 171505     semestre_automne            NaN  Présent      Erasmus  (24_ét.)
#
#                 year  year_start  year_end
# no_sciper
# 170337     2005-2006        2005      2006
# 171585     2005-2006        2005      2006
# 170200     2005-2006        2005      2006
# 171880     2005-2006        2005      2006
# 171505     2005-2006        2005      2006

# %%
# Well first of all we noticed that parsing all data without specifing date 
# also resulted in data of students from years before 2007 and we don't want that.

# Lets split year column into year_start and year_end
df['year_start'], df['year_end'] = df['year'].str.split('-', 1).str
# Cast from object to int
df[['year_start','year_end']] = df[['year_start','year_end']].apply(pd.to_numeric)
# Drop year column 
new_df = df.drop("year", axis=1)

# Verify
print(new_df.dtypes)
new_df.head()
# Out:
# civilité          object
# ecole_echange     object
# filière_opt.      object
# mineur            object
# nom_prénom        object
# section           object
# semester          object
# spécialisation    object
# statut            object
# type_echange      object
# wat               object
# year_start         int64
# year_end           int64
# dtype: object
#            civilité                                      ecole_echange  \
# no_sciper
# 170337     Monsieur                             Universidad de Granada
# 171585     Monsieur  Ecole Supérieure de Chimie Physique Electroniq...
# 170200       Madame                               Linköping University
# 171880     Monsieur  Ecole Supérieure de Chimie Physique Electroniq...
# 171505     Monsieur  Ecole Supérieure de Chimie Physique Electroniq...
#
#           filière_opt. mineur             nom_prénom     section  \
# no_sciper
# 170337             NaN    NaN  Arco Arredondo Rafael  echange_in
# 171585             NaN    NaN             Balas Marc  echange_in
# 170200             NaN    NaN         Bergendal Anna  echange_in
# 171880             NaN    NaN    Bret Jean-Sébastien  echange_in
# 171505             NaN    NaN         Burret Nicolas  echange_in
#
#                    semester spécialisation   statut type_echange       wat  \
# no_sciper
# 170337     semestre_automne            NaN  Présent      Erasmus  (24_ét.)
# 171585     semestre_automne            NaN  Présent      Erasmus  (24_ét.)
# 170200     semestre_automne            NaN  Présent      Erasmus  (24_ét.)
# 171880     semestre_automne            NaN  Présent      Erasmus  (24_ét.)
# 171505     semestre_automne            NaN  Présent      Erasmus  (24_ét.)
#
#            year_start  year_end
# no_sciper
# 170337           2005      2006
# 171585           2005      2006
# 170200           2005      2006
# 171880           2005      2006
# 171505           2005      2006

# %%
# Get bachelor students...
bachelor_df = new_df[new_df["semester"].str.contains("bachelor_semestre")]
print(bachelor_df.shape)
bachelor_df.head()
# Out:
# (7272, 13)
#            civilité ecole_echange filière_opt. mineur  \
# no_sciper
# 154168     Monsieur           NaN          NaN    NaN
# 160104     Monsieur           NaN          NaN    NaN
# 154157       Madame           NaN          NaN    NaN
# 166876     Monsieur           NaN          NaN    NaN
# 166258     Monsieur           NaN          NaN    NaN
#
#                                  nom_prénom       section  \
# no_sciper
# 154168           Aghamahdi Mohammad Hossein  informatique
# 160104                         Alves Sergio  informatique
# 154157     Andriambololona Riana Miarantsoa  informatique
# 166876                           Aslan Unal  informatique
# 166258                            Balet Ken  informatique
#
#                       semester spécialisation   statut type_echange  \
# no_sciper
# 154168     bachelor_semestre_1            NaN  Présent          NaN
# 160104     bachelor_semestre_1            NaN  Présent          NaN
# 154157     bachelor_semestre_1            NaN  Présent          NaN
# 166876     bachelor_semestre_1            NaN  Présent          NaN
# 166258     bachelor_semestre_1            NaN  Présent          NaN
#
#                  wat  year_start  year_end
# no_sciper
# 154168     (107_ét.)        2004      2005
# 160104     (107_ét.)        2004      2005
# 154157     (107_ét.)        2004      2005
# 166876     (107_ét.)        2004      2005
# 166258     (107_ét.)        2004      2005

# %%
# ...from year 2007 and above
bachelor_from_2007_df = bachelor_df[bachelor_df["year_start"] >= 2007]
print(bachelor_from_2007_df.shape)
bachelor_from_2007_df.head()
# Out:
# (5808, 13)
#            civilité ecole_echange filière_opt. mineur          nom_prénom  \
# no_sciper
# 169569     Monsieur           NaN          NaN    NaN   Arévalo Christian
# 174905     Monsieur           NaN          NaN    NaN     Aubelle Flavien
# 173922     Monsieur           NaN          NaN    NaN       Badoud Morgan
# 179406     Monsieur           NaN          NaN    NaN  Baeriswyl Jonathan
# 179428     Monsieur           NaN          NaN    NaN     Barroco Michael
#
#                 section             semester spécialisation   statut  \
# no_sciper
# 169569     informatique  bachelor_semestre_1            NaN  Présent
# 174905     informatique  bachelor_semestre_1            NaN  Présent
# 173922     informatique  bachelor_semestre_1            NaN  Présent
# 179406     informatique  bachelor_semestre_1            NaN  Présent
# 179428     informatique  bachelor_semestre_1            NaN  Présent
#
#           type_echange       wat  year_start  year_end
# no_sciper
# 169569             NaN  (90_ét.)        2007      2008
# 174905             NaN  (90_ét.)        2007      2008
# 173922             NaN  (90_ét.)        2007      2008
# 179406             NaN  (90_ét.)        2007      2008
# 179428             NaN  (90_ét.)        2007      2008

# %%
# count how many semesters each student completed
counts = pd.DataFrame(bachelor_from_2007_df.groupby(['nom_prénom']).size(), columns=['semester_count'])

# merge with previous dataframe (add semester_count column)
students_df = bachelor_from_2007_df.merge(counts, left_on=['nom_prénom'], right_index=True)

# filter out students who didnt complete 6 semeters
students_df = students_df[students_df["semester_count"] == 6]

print(students_df.shape)
students_df.head()
# Out:
# (1554, 14)
#            civilité ecole_echange filière_opt. mineur         nom_prénom  \
# no_sciper
# 169569     Monsieur           NaN          NaN    NaN  Arévalo Christian
# 169569     Monsieur           NaN          NaN    NaN  Arévalo Christian
# 169569     Monsieur           NaN          NaN    NaN  Arévalo Christian
# 169569     Monsieur           NaN          NaN    NaN  Arévalo Christian
# 169569     Monsieur           NaN          NaN    NaN  Arévalo Christian
#
#                 section             semester spécialisation   statut  \
# no_sciper
# 169569     informatique  bachelor_semestre_1            NaN  Présent
# 169569     informatique  bachelor_semestre_2            NaN  Présent
# 169569     informatique  bachelor_semestre_3            NaN  Présent
# 169569     informatique  bachelor_semestre_4            NaN  Présent
# 169569     informatique  bachelor_semestre_5            NaN  Présent
#
#           type_echange       wat  year_start  year_end  semester_count
# no_sciper
# 169569             NaN  (90_ét.)        2007      2008               6
# 169569             NaN  (72_ét.)        2007      2008               6
# 169569             NaN  (53_ét.)        2008      2009               6
# 169569             NaN  (51_ét.)        2008      2009               6
# 169569             NaN  (75_ét.)        2009      2010               6

# %%
by_name = students_df.groupby(['nom_prénom', 'semester'])
by_name.first()
# Out:
#                                                    civilité  \
# nom_prénom                    semester
# Abate Bryan Jeremy            bachelor_semestre_1  Monsieur
#                               bachelor_semestre_2  Monsieur
#                               bachelor_semestre_3  Monsieur
#                               bachelor_semestre_4  Monsieur
#                               bachelor_semestre_5  Monsieur
#                               bachelor_semestre_6  Monsieur
# Alami-Idrissi Ali             bachelor_semestre_1  Monsieur
#                               bachelor_semestre_2  Monsieur
#                               bachelor_semestre_3  Monsieur
#                               bachelor_semestre_4  Monsieur
#                               bachelor_semestre_5  Monsieur
#                               bachelor_semestre_6  Monsieur
# Alfonso Peterssen Alfonso     bachelor_semestre_1  Monsieur
#                               bachelor_semestre_2  Monsieur
#                               bachelor_semestre_3  Monsieur
#                               bachelor_semestre_4  Monsieur
#                               bachelor_semestre_5  Monsieur
#                               bachelor_semestre_6  Monsieur
# Angel Axel                    bachelor_semestre_1  Monsieur
#                               bachelor_semestre_2  Monsieur
#                               bachelor_semestre_3  Monsieur
#                               bachelor_semestre_4  Monsieur
#                               bachelor_semestre_5  Monsieur
#                               bachelor_semestre_6  Monsieur
# Aoun Leonardo                 bachelor_semestre_1  Monsieur
#                               bachelor_semestre_2  Monsieur
#                               bachelor_semestre_3  Monsieur
#                               bachelor_semestre_4  Monsieur
#                               bachelor_semestre_5  Monsieur
#                               bachelor_semestre_6  Monsieur
# ...                                                     ...
# Zhou Yunpeng                  bachelor_semestre_1  Monsieur
#                               bachelor_semestre_2  Monsieur
#                               bachelor_semestre_3  Monsieur
#                               bachelor_semestre_4  Monsieur
#                               bachelor_semestre_5  Monsieur
#                               bachelor_semestre_6  Monsieur
# Zimmermann Marc               bachelor_semestre_1  Monsieur
#                               bachelor_semestre_2  Monsieur
#                               bachelor_semestre_3  Monsieur
#                               bachelor_semestre_4  Monsieur
#                               bachelor_semestre_5  Monsieur
#                               bachelor_semestre_6  Monsieur
# Zoller Roman                  bachelor_semestre_1  Monsieur
#                               bachelor_semestre_2  Monsieur
#                               bachelor_semestre_3  Monsieur
#                               bachelor_semestre_4  Monsieur
#                               bachelor_semestre_5  Monsieur
#                               bachelor_semestre_6  Monsieur
# Zommerfelds Christian Georges bachelor_semestre_1  Monsieur
#                               bachelor_semestre_2  Monsieur
#                               bachelor_semestre_3  Monsieur
#                               bachelor_semestre_4  Monsieur
#                               bachelor_semestre_5  Monsieur
#                               bachelor_semestre_6  Monsieur
# Zürn Christophe               bachelor_semestre_1  Monsieur
#                               bachelor_semestre_2  Monsieur
#                               bachelor_semestre_3  Monsieur
#                               bachelor_semestre_4  Monsieur
#                               bachelor_semestre_5  Monsieur
#                               bachelor_semestre_6  Monsieur
#
#                                                                                     ecole_echange  \
# nom_prénom                    semester
# Abate Bryan Jeremy            bachelor_semestre_1                                             NaN
#                               bachelor_semestre_2                                             NaN
#                               bachelor_semestre_3                                             NaN
#                               bachelor_semestre_4                                             NaN
#                               bachelor_semestre_5                           University of Bristol
#                               bachelor_semestre_6                           University of Bristol
# Alami-Idrissi Ali             bachelor_semestre_1                                             NaN
#                               bachelor_semestre_2                                             NaN
#                               bachelor_semestre_3                                             NaN
#                               bachelor_semestre_4                                             NaN
#                               bachelor_semestre_5                            Linköping University
#                               bachelor_semestre_6                            Linköping University
# Alfonso Peterssen Alfonso     bachelor_semestre_1                                             NaN
#                               bachelor_semestre_2                                             NaN
#                               bachelor_semestre_3                                             NaN
#                               bachelor_semestre_4                                             NaN
#                               bachelor_semestre_5                                             NaN
#                               bachelor_semestre_6                                             NaN
# Angel Axel                    bachelor_semestre_1                                             NaN
#                               bachelor_semestre_2                                             NaN
#                               bachelor_semestre_3                                             NaN
#                               bachelor_semestre_4                                             NaN
#                               bachelor_semestre_5                                             NaN
#                               bachelor_semestre_6                                             NaN
# Aoun Leonardo                 bachelor_semestre_1                                             NaN
#                               bachelor_semestre_2                                             NaN
#                               bachelor_semestre_3                                             NaN
#                               bachelor_semestre_4                                             NaN
#                               bachelor_semestre_5               University of Washington, Seattle
#                               bachelor_semestre_6               University of Washington, Seattle
# ...                                                                                           ...
# Zhou Yunpeng                  bachelor_semestre_1                                             NaN
#                               bachelor_semestre_2                                             NaN
#                               bachelor_semestre_3                                             NaN
#                               bachelor_semestre_4                                             NaN
#                               bachelor_semestre_5                                             NaN
#                               bachelor_semestre_6                                             NaN
# Zimmermann Marc               bachelor_semestre_1                                             NaN
#                               bachelor_semestre_2                                             NaN
#                               bachelor_semestre_3                                             NaN
#                               bachelor_semestre_4                                             NaN
#                               bachelor_semestre_5                 Chinese University of Hong Kong
#                               bachelor_semestre_6                 Chinese University of Hong Kong
# Zoller Roman                  bachelor_semestre_1                                             NaN
#                               bachelor_semestre_2                                             NaN
#                               bachelor_semestre_3                                             NaN
#                               bachelor_semestre_4                                             NaN
#                               bachelor_semestre_5  Royal Institute of Technology, (KTH) Stockholm
#                               bachelor_semestre_6  Royal Institute of Technology, (KTH) Stockholm
# Zommerfelds Christian Georges bachelor_semestre_1                                             NaN
#                               bachelor_semestre_2                                             NaN
#                               bachelor_semestre_3                                             NaN
#                               bachelor_semestre_4                                             NaN
#                               bachelor_semestre_5                          University of Waterloo
#                               bachelor_semestre_6                          University of Waterloo
# Zürn Christophe               bachelor_semestre_1                                             NaN
#                               bachelor_semestre_2                                             NaN
#                               bachelor_semestre_3                                             NaN
#                               bachelor_semestre_4                                             NaN
#                               bachelor_semestre_5                                             NaN
#                               bachelor_semestre_6                                             NaN
#
#                                                                       filière_opt.  \
# nom_prénom                    semester
# Abate Bryan Jeremy            bachelor_semestre_1                              NaN
#                               bachelor_semestre_2                              NaN
#                               bachelor_semestre_3                              NaN
#                               bachelor_semestre_4                              NaN
#                               bachelor_semestre_5             6 - Visual computing
#                               bachelor_semestre_6                              NaN
# Alami-Idrissi Ali             bachelor_semestre_1                              NaN
#                               bachelor_semestre_2                              NaN
#                               bachelor_semestre_3                              NaN
#                               bachelor_semestre_4                              NaN
#                               bachelor_semestre_5  5 - Signal and Image Processing
#                               bachelor_semestre_6  5 - Signal and Image Processing
# Alfonso Peterssen Alfonso     bachelor_semestre_1                              NaN
#                               bachelor_semestre_2                              NaN
#                               bachelor_semestre_3                              NaN
#                               bachelor_semestre_4                              NaN
#                               bachelor_semestre_5             6 - Visual computing
#                               bachelor_semestre_6             6 - Visual computing
# Angel Axel                    bachelor_semestre_1                              NaN
#                               bachelor_semestre_2                              NaN
#                               bachelor_semestre_3                              NaN
#                               bachelor_semestre_4                              NaN
#                               bachelor_semestre_5                              NaN
#                               bachelor_semestre_6                              NaN
# Aoun Leonardo                 bachelor_semestre_1                              NaN
#                               bachelor_semestre_2                              NaN
#                               bachelor_semestre_3                              NaN
#                               bachelor_semestre_4                              NaN
#                               bachelor_semestre_5             6 - Visual computing
#                               bachelor_semestre_6                              NaN
# ...                                                                            ...
# Zhou Yunpeng                  bachelor_semestre_1                              NaN
#                               bachelor_semestre_2                              NaN
#                               bachelor_semestre_3                              NaN
#                               bachelor_semestre_4                              NaN
#                               bachelor_semestre_5                              NaN
#                               bachelor_semestre_6                              NaN
# Zimmermann Marc               bachelor_semestre_1                              NaN
#                               bachelor_semestre_2                              NaN
#                               bachelor_semestre_3                              NaN
#                               bachelor_semestre_4                              NaN
#                               bachelor_semestre_5                              NaN
#                               bachelor_semestre_6                              NaN
# Zoller Roman                  bachelor_semestre_1                              NaN
#                               bachelor_semestre_2                              NaN
#                               bachelor_semestre_3                              NaN
#                               bachelor_semestre_4                              NaN
#                               bachelor_semestre_5                              NaN
#                               bachelor_semestre_6                              NaN
# Zommerfelds Christian Georges bachelor_semestre_1                              NaN
#                               bachelor_semestre_2                              NaN
#                               bachelor_semestre_3                              NaN
#                               bachelor_semestre_4                              NaN
#                               bachelor_semestre_5                              NaN
#                               bachelor_semestre_6                              NaN
# Zürn Christophe               bachelor_semestre_1                              NaN
#                               bachelor_semestre_2                              NaN
#                               bachelor_semestre_3                              NaN
#                               bachelor_semestre_4                              NaN
#                               bachelor_semestre_5                              NaN
#                               bachelor_semestre_6                              NaN
#
#                                                    mineur       section  \
# nom_prénom                    semester
# Abate Bryan Jeremy            bachelor_semestre_1     NaN  informatique
#                               bachelor_semestre_2     NaN  informatique
#                               bachelor_semestre_3     NaN  informatique
#                               bachelor_semestre_4     NaN  informatique
#                               bachelor_semestre_5     NaN  informatique
#                               bachelor_semestre_6     NaN  informatique
# Alami-Idrissi Ali             bachelor_semestre_1     NaN  informatique
#                               bachelor_semestre_2     NaN  informatique
#                               bachelor_semestre_3     NaN  informatique
#                               bachelor_semestre_4     NaN  informatique
#                               bachelor_semestre_5     NaN  informatique
#                               bachelor_semestre_6     NaN  informatique
# Alfonso Peterssen Alfonso     bachelor_semestre_1     NaN  informatique
#                               bachelor_semestre_2     NaN  informatique
#                               bachelor_semestre_3     NaN  informatique
#                               bachelor_semestre_4     NaN  informatique
#                               bachelor_semestre_5     NaN  informatique
#                               bachelor_semestre_6     NaN  informatique
# Angel Axel                    bachelor_semestre_1     NaN  informatique
#                               bachelor_semestre_2     NaN  informatique
#                               bachelor_semestre_3     NaN  informatique
#                               bachelor_semestre_4     NaN  informatique
#                               bachelor_semestre_5     NaN  informatique
#                               bachelor_semestre_6     NaN  informatique
# Aoun Leonardo                 bachelor_semestre_1     NaN  informatique
#                               bachelor_semestre_2     NaN  informatique
#                               bachelor_semestre_3     NaN  informatique
#                               bachelor_semestre_4     NaN  informatique
#                               bachelor_semestre_5     NaN  informatique
#                               bachelor_semestre_6     NaN  informatique
# ...                                                   ...           ...
# Zhou Yunpeng                  bachelor_semestre_1     NaN  informatique
#                               bachelor_semestre_2     NaN  informatique
#                               bachelor_semestre_3     NaN  informatique
#                               bachelor_semestre_4     NaN  informatique
#                               bachelor_semestre_5     NaN  informatique
#                               bachelor_semestre_6     NaN  informatique
# Zimmermann Marc               bachelor_semestre_1     NaN  informatique
#                               bachelor_semestre_2     NaN  informatique
#                               bachelor_semestre_3     NaN  informatique
#                               bachelor_semestre_4     NaN  informatique
#                               bachelor_semestre_5     NaN  informatique
#                               bachelor_semestre_6     NaN  informatique
# Zoller Roman                  bachelor_semestre_1     NaN  informatique
#                               bachelor_semestre_2     NaN  informatique
#                               bachelor_semestre_3     NaN  informatique
#                               bachelor_semestre_4     NaN  informatique
#                               bachelor_semestre_5     NaN  informatique
#                               bachelor_semestre_6     NaN  informatique
# Zommerfelds Christian Georges bachelor_semestre_1     NaN  informatique
#                               bachelor_semestre_2     NaN  informatique
#                               bachelor_semestre_3     NaN  informatique
#                               bachelor_semestre_4     NaN  informatique
#                               bachelor_semestre_5     NaN  informatique
#                               bachelor_semestre_6     NaN  informatique
# Zürn Christophe               bachelor_semestre_1     NaN  informatique
#                               bachelor_semestre_2     NaN  informatique
#                               bachelor_semestre_3     NaN  informatique
#                               bachelor_semestre_4     NaN  informatique
#                               bachelor_semestre_5     NaN  informatique
#                               bachelor_semestre_6     NaN  informatique
#
#                                                    spécialisation   statut  \
# nom_prénom                    semester
# Abate Bryan Jeremy            bachelor_semestre_1             NaN  Présent
#                               bachelor_semestre_2             NaN  Présent
#                               bachelor_semestre_3             NaN  Présent
#                               bachelor_semestre_4             NaN  Présent
#                               bachelor_semestre_5             NaN    Congé
#                               bachelor_semestre_6             NaN    Congé
# Alami-Idrissi Ali             bachelor_semestre_1             NaN  Présent
#                               bachelor_semestre_2             NaN  Présent
#                               bachelor_semestre_3             NaN  Présent
#                               bachelor_semestre_4             NaN  Présent
#                               bachelor_semestre_5             NaN    Congé
#                               bachelor_semestre_6             NaN    Congé
# Alfonso Peterssen Alfonso     bachelor_semestre_1             NaN  Présent
#                               bachelor_semestre_2             NaN  Présent
#                               bachelor_semestre_3             NaN  Présent
#                               bachelor_semestre_4             NaN  Présent
#                               bachelor_semestre_5             NaN  Présent
#                               bachelor_semestre_6             NaN  Présent
# Angel Axel                    bachelor_semestre_1             NaN  Présent
#                               bachelor_semestre_2             NaN  Présent
#                               bachelor_semestre_3             NaN  Présent
#                               bachelor_semestre_4             NaN  Présent
#                               bachelor_semestre_5             NaN  Présent
#                               bachelor_semestre_6             NaN  Présent
# Aoun Leonardo                 bachelor_semestre_1             NaN  Présent
#                               bachelor_semestre_2             NaN  Présent
#                               bachelor_semestre_3             NaN  Présent
#                               bachelor_semestre_4             NaN  Présent
#                               bachelor_semestre_5             NaN    Congé
#                               bachelor_semestre_6             NaN    Congé
# ...                                                           ...      ...
# Zhou Yunpeng                  bachelor_semestre_1             NaN  Présent
#                               bachelor_semestre_2             NaN  Présent
#                               bachelor_semestre_3             NaN  Présent
#                               bachelor_semestre_4             NaN  Présent
#                               bachelor_semestre_5             NaN  Présent
#                               bachelor_semestre_6             NaN  Présent
# Zimmermann Marc               bachelor_semestre_1             NaN  Présent
#                               bachelor_semestre_2             NaN  Présent
#                               bachelor_semestre_3             NaN  Présent
#                               bachelor_semestre_4             NaN  Présent
#                               bachelor_semestre_5             NaN    Congé
#                               bachelor_semestre_6             NaN    Congé
# Zoller Roman                  bachelor_semestre_1             NaN  Présent
#                               bachelor_semestre_2             NaN  Présent
#                               bachelor_semestre_3             NaN  Présent
#                               bachelor_semestre_4             NaN  Présent
#                               bachelor_semestre_5             NaN    Congé
#                               bachelor_semestre_6             NaN    Congé
# Zommerfelds Christian Georges bachelor_semestre_1             NaN  Présent
#                               bachelor_semestre_2             NaN  Présent
#                               bachelor_semestre_3             NaN  Présent
#                               bachelor_semestre_4             NaN  Présent
#                               bachelor_semestre_5             NaN    Congé
#                               bachelor_semestre_6             NaN    Congé
# Zürn Christophe               bachelor_semestre_1             NaN  Présent
#                               bachelor_semestre_2             NaN  Présent
#                               bachelor_semestre_3             NaN  Présent
#                               bachelor_semestre_4             NaN  Présent
#                               bachelor_semestre_5             NaN  Présent
#                               bachelor_semestre_6             NaN  Présent
#
#                                                   type_echange        wat  \
# nom_prénom                    semester
# Abate Bryan Jeremy            bachelor_semestre_1          NaN  (242_ét.)
#                               bachelor_semestre_2          NaN  (164_ét.)
#                               bachelor_semestre_3          NaN   (92_ét.)
#                               bachelor_semestre_4          NaN   (89_ét.)
#                               bachelor_semestre_5      Erasmus  (120_ét.)
#                               bachelor_semestre_6      Erasmus   (24_ét.)
# Alami-Idrissi Ali             bachelor_semestre_1          NaN  (242_ét.)
#                               bachelor_semestre_2          NaN  (164_ét.)
#                               bachelor_semestre_3          NaN   (92_ét.)
#                               bachelor_semestre_4          NaN   (89_ét.)
#                               bachelor_semestre_5      Erasmus  (120_ét.)
#                               bachelor_semestre_6      Erasmus   (24_ét.)
# Alfonso Peterssen Alfonso     bachelor_semestre_1          NaN  (206_ét.)
#                               bachelor_semestre_2          NaN  (157_ét.)
#                               bachelor_semestre_3          NaN   (81_ét.)
#                               bachelor_semestre_4          NaN   (81_ét.)
#                               bachelor_semestre_5          NaN  (128_ét.)
#                               bachelor_semestre_6          NaN  (104_ét.)
# Angel Axel                    bachelor_semestre_1          NaN  (153_ét.)
#                               bachelor_semestre_2          NaN  (125_ét.)
#                               bachelor_semestre_3          NaN   (77_ét.)
#                               bachelor_semestre_4          NaN   (75_ét.)
#                               bachelor_semestre_5          NaN   (96_ét.)
#                               bachelor_semestre_6          NaN   (81_ét.)
# Aoun Leonardo                 bachelor_semestre_1          NaN  (242_ét.)
#                               bachelor_semestre_2          NaN  (164_ét.)
#                               bachelor_semestre_3          NaN   (92_ét.)
#                               bachelor_semestre_4          NaN   (89_ét.)
#                               bachelor_semestre_5    Bilatéral  (120_ét.)
#                               bachelor_semestre_6    Bilatéral   (24_ét.)
# ...                                                        ...        ...
# Zhou Yunpeng                  bachelor_semestre_1          NaN   (96_ét.)
#                               bachelor_semestre_2          NaN   (74_ét.)
#                               bachelor_semestre_3          NaN   (54_ét.)
#                               bachelor_semestre_4          NaN   (52_ét.)
#                               bachelor_semestre_5          NaN   (62_ét.)
#                               bachelor_semestre_6          NaN   (52_ét.)
# Zimmermann Marc               bachelor_semestre_1          NaN   (96_ét.)
#                               bachelor_semestre_2          NaN   (74_ét.)
#                               bachelor_semestre_3          NaN   (54_ét.)
#                               bachelor_semestre_4          NaN   (52_ét.)
#                               bachelor_semestre_5    Bilatéral   (62_ét.)
#                               bachelor_semestre_6    Bilatéral   (52_ét.)
# Zoller Roman                  bachelor_semestre_1          NaN   (90_ét.)
#                               bachelor_semestre_2          NaN   (72_ét.)
#                               bachelor_semestre_3          NaN   (53_ét.)
#                               bachelor_semestre_4          NaN   (51_ét.)
#                               bachelor_semestre_5      Erasmus   (75_ét.)
#                               bachelor_semestre_6      Erasmus   (60_ét.)
# Zommerfelds Christian Georges bachelor_semestre_1          NaN  (153_ét.)
#                               bachelor_semestre_2          NaN  (125_ét.)
#                               bachelor_semestre_3          NaN   (77_ét.)
#                               bachelor_semestre_4          NaN   (75_ét.)
#                               bachelor_semestre_5    Bilatéral   (96_ét.)
#                               bachelor_semestre_6    Bilatéral   (81_ét.)
# Zürn Christophe               bachelor_semestre_1          NaN   (96_ét.)
#                               bachelor_semestre_2          NaN   (74_ét.)
#                               bachelor_semestre_3          NaN   (54_ét.)
#                               bachelor_semestre_4          NaN   (52_ét.)
#                               bachelor_semestre_5          NaN   (62_ét.)
#                               bachelor_semestre_6          NaN   (52_ét.)
#
#                                                    year_start  year_end  \
# nom_prénom                    semester
# Abate Bryan Jeremy            bachelor_semestre_1        2014      2015
#                               bachelor_semestre_2        2014      2015
#                               bachelor_semestre_3        2015      2016
#                               bachelor_semestre_4        2015      2016
#                               bachelor_semestre_5        2016      2017
#                               bachelor_semestre_6        2016      2017
# Alami-Idrissi Ali             bachelor_semestre_1        2014      2015
#                               bachelor_semestre_2        2014      2015
#                               bachelor_semestre_3        2015      2016
#                               bachelor_semestre_4        2015      2016
#                               bachelor_semestre_5        2016      2017
#                               bachelor_semestre_6        2016      2017
# Alfonso Peterssen Alfonso     bachelor_semestre_1        2013      2014
#                               bachelor_semestre_2        2013      2014
#                               bachelor_semestre_3        2014      2015
#                               bachelor_semestre_4        2014      2015
#                               bachelor_semestre_5        2015      2016
#                               bachelor_semestre_6        2015      2016
# Angel Axel                    bachelor_semestre_1        2010      2011
#                               bachelor_semestre_2        2010      2011
#                               bachelor_semestre_3        2011      2012
#                               bachelor_semestre_4        2011      2012
#                               bachelor_semestre_5        2012      2013
#                               bachelor_semestre_6        2012      2013
# Aoun Leonardo                 bachelor_semestre_1        2014      2015
#                               bachelor_semestre_2        2014      2015
#                               bachelor_semestre_3        2015      2016
#                               bachelor_semestre_4        2015      2016
#                               bachelor_semestre_5        2016      2017
#                               bachelor_semestre_6        2016      2017
# ...                                                       ...       ...
# Zhou Yunpeng                  bachelor_semestre_1        2008      2009
#                               bachelor_semestre_2        2008      2009
#                               bachelor_semestre_3        2009      2010
#                               bachelor_semestre_4        2009      2010
#                               bachelor_semestre_5        2010      2011
#                               bachelor_semestre_6        2010      2011
# Zimmermann Marc               bachelor_semestre_1        2008      2009
#                               bachelor_semestre_2        2008      2009
#                               bachelor_semestre_3        2009      2010
#                               bachelor_semestre_4        2009      2010
#                               bachelor_semestre_5        2010      2011
#                               bachelor_semestre_6        2010      2011
# Zoller Roman                  bachelor_semestre_1        2007      2008
#                               bachelor_semestre_2        2007      2008
#                               bachelor_semestre_3        2008      2009
#                               bachelor_semestre_4        2008      2009
#                               bachelor_semestre_5        2009      2010
#                               bachelor_semestre_6        2009      2010
# Zommerfelds Christian Georges bachelor_semestre_1        2010      2011
#                               bachelor_semestre_2        2010      2011
#                               bachelor_semestre_3        2011      2012
#                               bachelor_semestre_4        2011      2012
#                               bachelor_semestre_5        2012      2013
#                               bachelor_semestre_6        2012      2013
# Zürn Christophe               bachelor_semestre_1        2008      2009
#                               bachelor_semestre_2        2008      2009
#                               bachelor_semestre_3        2009      2010
#                               bachelor_semestre_4        2009      2010
#                               bachelor_semestre_5        2010      2011
#                               bachelor_semestre_6        2010      2011
#
#                                                    semester_count
# nom_prénom                    semester
# Abate Bryan Jeremy            bachelor_semestre_1               6
#                               bachelor_semestre_2               6
#                               bachelor_semestre_3               6
#                               bachelor_semestre_4               6
#                               bachelor_semestre_5               6
#                               bachelor_semestre_6               6
# Alami-Idrissi Ali             bachelor_semestre_1               6
#                               bachelor_semestre_2               6
#                               bachelor_semestre_3               6
#                               bachelor_semestre_4               6
#                               bachelor_semestre_5               6
#                               bachelor_semestre_6               6
# Alfonso Peterssen Alfonso     bachelor_semestre_1               6
#                               bachelor_semestre_2               6
#                               bachelor_semestre_3               6
#                               bachelor_semestre_4               6
#                               bachelor_semestre_5               6
#                               bachelor_semestre_6               6
# Angel Axel                    bachelor_semestre_1               6
#                               bachelor_semestre_2               6
#                               bachelor_semestre_3               6
#                               bachelor_semestre_4               6
#                               bachelor_semestre_5               6
#                               bachelor_semestre_6               6
# Aoun Leonardo                 bachelor_semestre_1               6
#                               bachelor_semestre_2               6
#                               bachelor_semestre_3               6
#                               bachelor_semestre_4               6
#                               bachelor_semestre_5               6
#                               bachelor_semestre_6               6
# ...                                                           ...
# Zhou Yunpeng                  bachelor_semestre_1               6
#                               bachelor_semestre_2               6
#                               bachelor_semestre_3               6
#                               bachelor_semestre_4               6
#                               bachelor_semestre_5               6
#                               bachelor_semestre_6               6
# Zimmermann Marc               bachelor_semestre_1               6
#                               bachelor_semestre_2               6
#                               bachelor_semestre_3               6
#                               bachelor_semestre_4               6
#                               bachelor_semestre_5               6
#                               bachelor_semestre_6               6
# Zoller Roman                  bachelor_semestre_1               6
#                               bachelor_semestre_2               6
#                               bachelor_semestre_3               6
#                               bachelor_semestre_4               6
#                               bachelor_semestre_5               6
#                               bachelor_semestre_6               6
# Zommerfelds Christian Georges bachelor_semestre_1               6
#                               bachelor_semestre_2               6
#                               bachelor_semestre_3               6
#                               bachelor_semestre_4               6
#                               bachelor_semestre_5               6
#                               bachelor_semestre_6               6
# Zürn Christophe               bachelor_semestre_1               6
#                               bachelor_semestre_2               6
#                               bachelor_semestre_3               6
#                               bachelor_semestre_4               6
#                               bachelor_semestre_5               6
#                               bachelor_semestre_6               6
#
# [1483 rows x 12 columns]

# %%
# TO DO NEXT:
# - Compute how many months it took each student to go from the first to the sixth semester.
# - Partition the data between male and female students, and compute the average -- is the difference in average statistically significant?
# - Statistical test?
